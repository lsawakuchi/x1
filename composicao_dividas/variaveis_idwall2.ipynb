# %% [markdown]
# - Criando algumas features para o estudo de Behavior Analytics

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import json
import requests
from time import sleep
from datetime import datetime
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import warnings
warnings.filterwarnings('ignore')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# falencias : 24ffc4c7-7a5b-40dd-be93-f98b4b47e68f

# %%
engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
con = engine.connect()
df = pd.read_sql("select * from consultas_idwall_operacoes", con)

# %%
df.head()
# Out:
#    id        cnpj_cpf   data_ref data_inclusao data_ocorrencia  \
# 0   1     28399115827 2018-11-01    0000-00-00      0000-00-00
# 1   2     28399115827 2018-11-01          None      0000-00-00
# 2   3     28399115827 2018-11-01          None      0000-00-00
# 3   4     28399115827 2018-11-01          None      0000-00-00
# 4   5  19008188000142 2018-11-05    2015-06-05      2015-01-31
#
#                             natureza     valor        tipo  \
# 0  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO     42.17  pendencias
# 1                               None    827.64  pendencias
# 2                               None    839.87  pendencias
# 3                               None    849.62  pendencias
# 4  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  25397.60  pendencias
#
#                         numero_consulta  situacao_cadastral_cnpj  sancoes_onu  \
# 0  360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b                      NaN          NaN
# 1  360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b                      NaN          NaN
# 2  360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b                      NaN          NaN
# 3  360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b                      NaN          NaN
# 4  250a23e1-7797-4621-bdaf-e6c2d99d2dc8                      NaN          NaN
#
#    pep mun_fronteirico
# 0  NaN            None
# 1  NaN            None
# 2  NaN            None
# 3  NaN            None
# 4  NaN            None

# %%
# df['data_consulta'] = df.apply(lambda x : x['data_ref'].date(), axis=1)

# %%
fr = list()
for el in df['cnpj_cpf'].unique().tolist():
    dt = df[df['cnpj_cpf']==el]
    data_max = dt['data_ref'].max()
    dt = dt[dt['data_ref']==data_max]
    fr.append(dt)

# %%
dfCons = pd.concat(fr)

# %%
dfCons.shape
# Out:
# (12421, 13)

# %%
dfCons.head()
# Out:
#         id        cnpj_cpf   data_ref data_inclusao data_ocorrencia  \
# 0        1     28399115827 2018-11-01    0000-00-00      0000-00-00
# 1        2     28399115827 2018-11-01          None      0000-00-00
# 2        3     28399115827 2018-11-01          None      0000-00-00
# 3        4     28399115827 2018-11-01          None      0000-00-00
# 4999  6267  19008188000142 2018-12-03    2015-06-05      2015-01-31
#
#                                natureza     valor        tipo  \
# 0     CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO     42.17  pendencias
# 1                                  None    827.64  pendencias
# 2                                  None    839.87  pendencias
# 3                                  None    849.62  pendencias
# 4999  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  25397.60  pendencias
#
#                            numero_consulta  situacao_cadastral_cnpj  \
# 0     360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b                      NaN
# 1     360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b                      NaN
# 2     360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b                      NaN
# 3     360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b                      NaN
# 4999  ec23b694-37ea-4cbe-85b4-cfed79f90ae6                      NaN
#
#       sancoes_onu  pep mun_fronteirico
# 0             NaN  NaN            None
# 1             NaN  NaN            None
# 2             NaN  NaN            None
# 3             NaN  NaN            None
# 4999          NaN  NaN            None

# %%
dfCons.to_excel("../tabelas/base_idwall_201904.xlsx")

# %%
# dfCons = pd.read_excel("../tabelas/base_idwall.xlsx")

# %%
dfCons['flag_cnpj'] = dfCons.apply(lambda x : int(len(x['cnpj_cpf'])==14), axis=1)

# %%
dfCons[dfCons['cnpj_cpf']=='20604000000370']
# Out:
#           id        cnpj_cpf            data_ref data_inclusao  \
# 32330  33659  20604000000370 2019-04-09 16:16:43    2016-02-12
# 32331  33660  20604000000370 2019-04-09 16:16:43    2016-01-27
# 32332  33661  20604000000370 2019-04-09 16:16:43    2018-08-17
# 32333  33662  20604000000370 2019-04-09 16:16:43    2015-12-09
#
#       data_ocorrencia         natureza   valor       tipo  \
# 32330      2016-01-26  Falta Pagamento  1000.0  protestos
# 32331      2015-12-26  Falta Pagamento  1000.0  protestos
# 32332      2015-12-16  Falta Pagamento   566.0  protestos
# 32333      2015-11-26  Falta Pagamento  1012.0  protestos
#
#                             numero_consulta  situacao_cadastral_cnpj  \
# 32330  fab80e44-6dd3-4c8d-bbcc-a399f42fada7                      1.0
# 32331  fab80e44-6dd3-4c8d-bbcc-a399f42fada7                      1.0
# 32332  fab80e44-6dd3-4c8d-bbcc-a399f42fada7                      1.0
# 32333  fab80e44-6dd3-4c8d-bbcc-a399f42fada7                      1.0
#
#        sancoes_onu  pep mun_fronteirico  flag_cnpj
# 32330          1.0  NaN            None          1
# 32331          1.0  NaN            None          1
# 32332          1.0  NaN            None          1
# 32333          1.0  NaN            None          1

# %%
dfCons['natureza'].unique().tolist()
# Out:
# ['CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO',
#  None,
#  'Falta Pagamento',
#  'Empréstimos em contas - c/c garantidas, financiamentos de capital de giro, programas especiais, etc',
#  'Cartão de crédito',
#  'Execução de Título Judicial Trabalhista',
#  'Execução Fiscal Estadual',
#  'Execução',
#  'Créditos e financiamentos - empréstimos a pessoas físicas , financiamentos ao consumidor final , etc',
#  'Operações imobiliárias em geral, inclusive de sociedades de poupança',
#  'Execução Fiscal Federal',
#  'Adiantamento a depositantes - c/c devedores em geral',
#  'Empréstimos agrícolas e industriais - financiamentos de custeio de investimentos agrícolas e industriais',
#  'Execução Fiscal Municipal',
#  'Execução - Pequenas Causas',
#  'Arrendamentos, inclusive leasing',
#  'Operações ajuizadas ',
#  'Busca e Apreensão',
#  'Consórcio outros bens móveis',
#  'Consórcio veículos leves']

# %%
def get_validacoes(numero):
    URL = "https://api-v2.idwall.co/relatorios"
    authorization = "b3818f92-5807-4acf-ade8-78a1f6d7996b"
    url_details = URL + "/{}".format(numero) + "/validacoes"
    while True:
        dets = requests.get(url_details, headers={"authorization": authorization})
        djson = dets.json()
        sleep(1)
        if djson['result']['status'] == "CONCLUIDO":
            break

    return dets.json()

def get_details(numero):
    URL = "https://api-v2.idwall.co/relatorios"
    authorization = "b3818f92-5807-4acf-ade8-78a1f6d7996b"
    url_details = URL + "/{}".format(numero) + "/dados"
    while True:
        dets = requests.get(url_details, headers={"authorization": authorization})
        djson = dets.json()
        sleep(1)
        if djson['result']['status'] == "CONCLUIDO":
            break

    return dets.json()

# %%
## cnpj moip 
dfCons[dfCons['cnpj_cpf']=='18356074000120']
# Out:
#           id        cnpj_cpf            data_ref data_inclusao  \
# 26451  27779  18356074000120 2019-03-19 10:33:14    2018-01-09
# 26452  27780  18356074000120 2019-03-19 10:33:14    2017-12-18
# 26453  27781  18356074000120 2019-03-19 10:33:14    2017-12-18
# 26454  27782  18356074000120 2019-03-19 10:33:14    2018-01-09
# 26455  27783  18356074000120 2019-03-19 10:33:14    2015-12-19
# 26456  27784  18356074000120 2019-03-19 10:33:14    2017-06-20
# 26457  27785  18356074000120 2019-03-19 10:33:14    2018-02-26
# 26458  27786  18356074000120 2019-03-19 10:33:14    2017-10-24
# 26459  27787  18356074000120 2019-03-19 10:33:14    2017-10-24
# 26460  27788  18356074000120 2019-03-19 10:33:14    2016-01-20
# 26461  27789  18356074000120 2019-03-19 10:33:14    2015-12-18
# 26462  27790  18356074000120 2019-03-19 10:33:14    2015-11-18
# 26463  27791  18356074000120 2019-03-19 10:33:14    2015-10-22
# 26464  27792  18356074000120 2019-03-19 10:33:14    2015-05-07
# 26465  27793  18356074000120 2019-03-19 10:33:14    2015-04-10
#
#       data_ocorrencia                           natureza     valor  \
# 26451      2015-01-27  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  11421.00
# 26452      2015-01-26                  Cartão de crédito   2318.53
# 26453      2014-12-13                  Cartão de crédito   2590.85
# 26454      2014-05-09  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  56003.10
# 26455      2015-11-01  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO   1877.29
# 26456      2017-06-02                               None     13.00
# 26457      2018-02-07                    Falta Pagamento   5946.33
# 26458      2017-07-13                    Falta Pagamento    361.79
# 26459      2017-07-13                    Falta Pagamento    817.83
# 26460      2016-01-01                    Falta Pagamento    500.00
# 26461      2015-12-01                    Falta Pagamento    500.00
# 26462      2015-11-01                    Falta Pagamento    500.00
# 26463      2015-10-01                    Falta Pagamento    500.00
# 26464      2015-04-15                    Falta Pagamento    844.75
# 26465      2015-03-11                    Falta Pagamento    267.00
#
#                          tipo                       numero_consulta  \
# 26451  restricoes_financeiras  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26452  restricoes_financeiras  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26453  restricoes_financeiras  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26454  restricoes_financeiras  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26455              pendencias  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26456                 cheques  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26457               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26458               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26459               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26460               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26461               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26462               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26463               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26464               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
# 26465               protestos  c8711cf5-3181-443c-bd79-51fd18b519a6
#
#        situacao_cadastral_cnpj  sancoes_onu  pep mun_fronteirico  flag_cnpj
# 26451                      0.0          NaN  NaN            None          1
# 26452                      0.0          NaN  NaN            None          1
# 26453                      0.0          NaN  NaN            None          1
# 26454                      0.0          NaN  NaN            None          1
# 26455                      0.0          NaN  NaN            None          1
# 26456                      0.0          NaN  NaN            None          1
# 26457                      0.0          NaN  NaN            None          1
# 26458                      0.0          NaN  NaN            None          1
# 26459                      0.0          NaN  NaN            None          1
# 26460                      0.0          NaN  NaN            None          1
# 26461                      0.0          NaN  NaN            None          1
# 26462                      0.0          NaN  NaN            None          1
# 26463                      0.0          NaN  NaN            None          1
# 26464                      0.0          NaN  NaN            None          1
# 26465                      0.0          NaN  NaN            None          1

# %%
js = get_details('c8711cf5-3181-443c-bd79-51fd18b519a6')
js = js.get("result")

# %%
js.keys()
# Out:
# dict_keys(['atualizado_em', 'criado_em', 'mensagem', 'nome', 'numero', 'resultado', 'status', 'validado_em', 'validado_manualmente', 'bigboost', 'cnpj', 'ofac_sdn', 'restricoes_financeiras', 'protestos', 'pendencias', 'cheques'])

# %%
def get_cheques(js):
    res = js.get("cheques")
    if not res is None:
        df = pd.DataFrame(res.get("itens"))
        df = df[["data_ocorrencia", "uf", "quantidade_cheques"]]
        df["tipo"] = "cheques"
        return df
    else:
        return None

# %%
def get_restricoes_financeiras(js):
    res = js.get("restricoes_financeiras")
    if not res is None:
        df = pd.DataFrame(res.get("itens"))
        if "uf" in list(df.columns):
            df = df[["data_ocorrencia", "modalidade_natureza", "natureza", "uf", "valor"]]
        else:
            df = df[["data_ocorrencia", "modalidade_natureza", "natureza", "uf", "valor"]]
            df['uf'] = None
        
        df["tipo"] = "restricoes_financeiras"
        return df
    return None

# %%
def get_protestos(js):
    res = js.get("protestos")
    if not res is None:
        df = pd.DataFrame(res.get("itens"))
        if "uf" in list(df.columns):
            df = df[["data_anotacao", "natureza", "sub_judice_descricao", "uf", "valor"]]
            df.columns = ["data_ocorrencia", "natureza", "modalidade_natureza", "uf", "valor"]
        else:
            df = df[["data_anotacao", "natureza", "sub_judice_descricao", "valor"]]
            df.columns = ["data_ocorrencia", "natureza", "modalidade_natureza", "valor"]
            df["uf"] = None
        df['tipo'] = "protestos"
        return df
    return None

# %%
def get_pendencias(js):
    res = js.get("pendencias")
    if not res is None:
        df = pd.DataFrame(res.get("itens"))
        if "uf" in list(df.columns):
            df = df[["data_ocorrencia", "modalidade", "natureza", "valor", "uf"]]
            
        else:
            df = df[["data_ocorrencia", "modalidade", "natureza", "valor"]]
            df["uf"] = None
        df.rename(columns={"modalidade" : "modalidade_natureza"}, inplace=True)
        df['tipo'] = "pendencias"
        return df
    return None

# %%
def get_processos(js):
    res = js.get("processos")
    if not res is None:
        df = pd.DataFrame(res.get('itens'))
        if "uf" in list(df.columns):
            df = df[["data_ocorrencia", "descricao_natureza", "natureza", "uf", "valor"]]
        else:
            df = df[["data_ocorrencia", "descricao_natureza", "natureza", "valor"]]
            df["uf"] = None
        df.rename(columns = {"descricao_natureza" : "modalidade_natureza"})
        df["tipo"] = "processos"
        return df
    return None

# %%
get_restricoes_financeiras(js)
# Out:
#   data_ocorrencia             modalidade_natureza  \
# 0      27/01/2015  CREDITO E FINANCIAMENTO-FINANC
# 1      26/01/2015  CRED CARTAO
# 2      13/12/2014  CRED CARTAO
# 3      09/05/2014  CREDITO E FINANCIAMENTO-FINANC
#
#                             natureza  uf        valor                    tipo
# 0  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  SP  R$ 11420,97  restricoes_financeiras
# 1                  Cartão de crédito       R$ 2318,53  restricoes_financeiras
# 2                  Cartão de crédito       R$ 2590,85  restricoes_financeiras
# 3  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  SP  R$ 56003,05  restricoes_financeiras

# %%
get_protestos(js)
# Out:
#   data_ocorrencia         natureza     modalidade_natureza  uf       valor  \
# 0      07/02/2018  Falta Pagamento  Dívida não contestada.  SP  R$ 5946,33
# 1      13/07/2017  Falta Pagamento  Dívida não contestada.  SP   R$ 361,79
# 2      13/07/2017  Falta Pagamento  Dívida não contestada.  SP   R$ 817,83
# 3      01/01/2016  Falta Pagamento  Dívida não contestada.  SP   R$ 500,00
# 4      01/12/2015  Falta Pagamento  Dívida não contestada.  SP   R$ 500,00
# 5      01/11/2015  Falta Pagamento  Dívida não contestada.  SP   R$ 500,00
# 6      01/10/2015  Falta Pagamento  Dívida não contestada.  SP   R$ 500,00
# 7      15/04/2015  Falta Pagamento  Dívida não contestada.  SP   R$ 844,75
# 8      11/03/2015  Falta Pagamento  Dívida não contestada.  SP   R$ 267,00
#
#         tipo
# 0  protestos
# 1  protestos
# 2  protestos
# 3  protestos
# 4  protestos
# 5  protestos
# 6  protestos
# 7  protestos
# 8  protestos

# %%
get_processos(js)

# %%
get_pendencias(js)
# Out:
#   data_ocorrencia modalidade_natureza                           natureza  \
# 0      01/11/2015         OUTRAS OPER  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO
#
#         valor    uf        tipo
# 0  R$ 1877,29  None  pendencias

# %%
get_cheques(js)
# Out:
#   data_ocorrencia  uf quantidade_cheques     tipo
# 0      02/06/2017  SP                 13  cheques

# %%
js = get_details("24ffc4c7-7a5b-40dd-be93-f98b4b47e68f")
js = js.get("result")

# %%
get_processos(js)
# Out:
#   data_ocorrencia descricao_natureza                                 natureza  \
# 0      03/07/2017       EXC JUD TRAB  Execução de Título Judicial Trabalhista
# 1      24/01/2017       EXC JUD TRAB  Execução de Título Judicial Trabalhista
# 2      11/08/2016    FISCAL ESTADUAL                 Execução Fiscal Estadual
#
#    uf        valor       tipo
# 0  SC  R$ 17788,37  processos
# 1  RS  R$ 75143,93  processos
# 2  SC      R$ 0,00  processos

# %%
## cpf = 360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b

# %%
js = get_details("360ec7c5-ca6b-4adc-8b76-6e1fc4cf921b")

# %%
js = js.get("result")

# %%
js.keys()
# Out:
# dict_keys(['atualizado_em', 'criado_em', 'mensagem', 'nome', 'numero', 'resultado', 'status', 'validado_em', 'validado_manualmente', 'pep', 'cpf', 'ofac_sdn', 'pendencias', 'pessoas_relacionadas', 'enderecos', 'emails', 'participacao_empresas'])

# %%
get_cheques(js)

# %%
get_pendencias(js)
# Out:
#   data_ocorrencia modalidade_natureza                           natureza  \
# 0      10/11/2015           DUPLICATA  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO
# 1      10/12/2017                 NaN                                NaN
# 2      10/11/2017                 NaN                                NaN
# 3      10/10/2017                 NaN                                NaN
#
#        valor   uf        tipo
# 0   R$ 42,17  NaN  pendencias
# 1  R$ 827,64   SP  pendencias
# 2  R$ 839,87   SP  pendencias
# 3  R$ 849,62   SP  pendencias

# %%
df = dfCons[dfCons['flag_cnpj']==1]

# %%
df['cnpj_cpf'].unique().tolist().__len__()
# Out:
# 2281

# %%
el = '19008188000142'

# %%
from tqdm import tqdm_notebook

# %%
fr = list()
cheques = list()
err = list()

for el in tqdm_notebook(df["cnpj_cpf"].unique().tolist()):
    numero = df[df['cnpj_cpf']==el]['numero_consulta'].iloc[0]

    js = get_details(numero)

    js = js.get("result")

    
    try:
        df1 = get_restricoes_financeiras(js)
        if not df1 is None:
            df1['cnpj'] = el
            fr.append(df1)

        df1 = get_protestos(js)
        if not df1 is None:
            df1['cnpj'] = el
            fr.append(df1)

        df1 = get_pendencias(js)
        if not df1 is None:
            df1['cnpj'] = el
            fr.append(df1)

        df1 = get_processos(js)
        if not df1 is None:
            df1['cnpj'] = el
            fr.append(df1)
        df0 = get_cheques(js)
        if not df0 is None:
            df0['cnpj'] = el
            cheques.append(df0)
    except:
        err.append(el)
# Out:
# HBox(children=(IntProgress(value=0, max=2281), HTML(value='')))

# %%
err.__len__()
# Out:
# 29

# %%
df_cheques = pd.concat(cheques)

# %%
df_cheques.sort_values("quantidade_cheques", ascending=False).head()
# Out:
#   data_ocorrencia  uf quantidade_cheques     tipo            cnpj
# 0      13/10/2016  PE                  9  cheques  10727992000107
# 0      26/12/2016                      9  cheques  58126236000159
# 1      07/01/2019  SP                  9  cheques  06145688000184
# 0      27/09/2018  SP                  9  cheques  17189173000100
# 0      03/12/2018  SC                  8  cheques  30640876000163

# %%
df_cheques.to_excel("../tabelas/base_cheques_201904.xlsx")

# %%
df_cheques = pd.read_excel("../tabelas/base_cheques.xlsx")

# %%
dfDiv = pd.concat(fr)

# %%
dfDiv.shape
# Out:
# (9284, 8)

# %%
dfDiv['cnpj'].unique().tolist().__len__()
# Out:
# 717

# %%
dfDiv["descricao_natureza"].unique().tolist()
# Out:
# [nan,
#  'EXC JUD TRAB',
#  'FISCAL ESTADUAL',
#  'EXECUCAO',
#  'FISCAL FEDERAL',
#  'FISCAL MUNICIPAL',
#  'EXECUCAO - JE',
#  'BUSCA E APREENSAO']

# %%
dfDiv[dfDiv['cnpj']=='18356074000120']
# Out:
#              cnpj data_ocorrencia descricao_natureza  \
# 0  18356074000120      27/01/2015                NaN
# 1  18356074000120      26/01/2015                NaN
# 2  18356074000120      13/12/2014                NaN
# 3  18356074000120      09/05/2014                NaN
# 0  18356074000120      07/02/2018                NaN
# 1  18356074000120      13/07/2017                NaN
# 2  18356074000120      13/07/2017                NaN
# 3  18356074000120      01/01/2016                NaN
# 4  18356074000120      01/12/2015                NaN
# 5  18356074000120      01/11/2015                NaN
# 6  18356074000120      01/10/2015                NaN
# 7  18356074000120      15/04/2015                NaN
# 8  18356074000120      11/03/2015                NaN
# 0  18356074000120      01/11/2015                NaN
#
#               modalidade_natureza                           natureza  \
# 0  CREDITO E FINANCIAMENTO-FINANC  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO
# 1  CRED CARTAO                                     Cartão de crédito
# 2  CRED CARTAO                                     Cartão de crédito
# 3  CREDITO E FINANCIAMENTO-FINANC  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO
# 0          Dívida não contestada.                    Falta Pagamento
# 1          Dívida não contestada.                    Falta Pagamento
# 2          Dívida não contestada.                    Falta Pagamento
# 3          Dívida não contestada.                    Falta Pagamento
# 4          Dívida não contestada.                    Falta Pagamento
# 5          Dívida não contestada.                    Falta Pagamento
# 6          Dívida não contestada.                    Falta Pagamento
# 7          Dívida não contestada.                    Falta Pagamento
# 8          Dívida não contestada.                    Falta Pagamento
# 0                     OUTRAS OPER  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO
#
#                      tipo    uf        valor
# 0  restricoes_financeiras    SP  R$ 11420,97
# 1  restricoes_financeiras         R$ 2318,53
# 2  restricoes_financeiras         R$ 2590,85
# 3  restricoes_financeiras    SP  R$ 56003,05
# 0               protestos    SP   R$ 5946,33
# 1               protestos    SP    R$ 361,79
# 2               protestos    SP    R$ 817,83
# 3               protestos    SP    R$ 500,00
# 4               protestos    SP    R$ 500,00
# 5               protestos    SP    R$ 500,00
# 6               protestos    SP    R$ 500,00
# 7               protestos    SP    R$ 844,75
# 8               protestos    SP    R$ 267,00
# 0              pendencias  None   R$ 1877,29

# %%
dfDiv[dfDiv['natureza']=='CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO']["modalidade_natureza"].unique().tolist()
# Out:
# ['DUPLICATA',
#  'OUTRAS OPER',
#  'NOTA FISCAL',
#  'VENDA MERCAD',
#  'TIT DESCONTA',
#  'TIT DESCONTA                  ',
#  'SERV TELEFON',
#  'OUTRAS OPER                   ',
#  'ALUGUEL',
#  'ARRECADADOR',
#  'CONDOMINIO',
#  'ENERGIA ELET',
#  'CONFISS DIV',
#  'CREDITO E FINANCIAMENTO-FINANC',
#  'CREDIARIO',
#  'TITULOS DESCONTADOS-TURISMO   ',
#  'DIVIDAS CHEQ',
#  'REPASSES                      ',
#  'OUTRAS OPERACOES-FINANCEIRA   ',
#  'SEGURO SAUDE',
#  'CONSORCIO CO',
#  'CONSORCIO CONTEMPLADO         ',
#  'TELEF FX',
#  'TELEF FIXA',
#  'TELEF MOVEL',
#  'FAT AGUA']

# %%
dfDiv[dfDiv['modalidade_natureza']=='DIVIDAS CHEQ']
# Out:
#               cnpj data_ocorrencia descricao_natureza modalidade_natureza  \
# 0   26856710000101      30/11/2017                NaN        DIVIDAS CHEQ
# 7   03704136000170      09/03/2016                NaN        DIVIDAS CHEQ
# 8   03704136000170      11/02/2016                NaN        DIVIDAS CHEQ
# 9   03704136000170      06/01/2016                NaN        DIVIDAS CHEQ
# 0   28178160000144      30/06/2018                NaN        DIVIDAS CHEQ
# 13  11728613000166      07/04/2016                NaN        DIVIDAS CHEQ
# 0   15549133000199      12/04/2016                NaN        DIVIDAS CHEQ
# 1   15549133000199      12/03/2016                NaN        DIVIDAS CHEQ
# 0   09115820000101      10/03/2018                NaN        DIVIDAS CHEQ
# 2   20314546000124      01/07/2016                NaN        DIVIDAS CHEQ
#
#                              natureza        tipo    uf        valor
# 0   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None   R$ 3009,75
# 7   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None    R$ 580,00
# 8   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None    R$ 580,00
# 9   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None    R$ 580,00
# 0   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None    R$ 500,00
# 13  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None    R$ 264,99
# 0   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None    R$ 168,00
# 1   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None    R$ 168,00
# 0   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None  R$ 10000,00
# 2   CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  pendencias  None  R$ 10000,00

# %%
dfDiv[dfDiv['cnpj']=='11728613000166']["uf"].unique().tolist()
# Out:
# ['SP', None]

# %%
dfDiv.to_excel("../tabelas/base_dividas_201904.xlsx")

# %%
dfDiv = pd.read_excel("../tabelas/base_dividas.xlsx")

# %%
float(dfDiv["valor"].iloc[0].split("R$ ")[1].replace(",", "."))
# Out:
# 892.53

# %%
dfDiv["valor_divida"] = dfDiv.apply(lambda x : float(x["valor"].split("R$ ")[1].replace(",", ".")), axis=1)

# %%
dfDiv.head()
# Out:
#              cnpj data_ocorrencia descricao_natureza     modalidade_natureza  \
# 0  19008188000142      21/05/2018                NaN  Dívida não contestada.
# 1  19008188000142      22/03/2018                NaN  Dívida não contestada.
# 2  19008188000142      15/03/2018                NaN  Dívida não contestada.
# 3  19008188000142      01/03/2018                NaN  Dívida não contestada.
# 4  19008188000142      22/02/2018                NaN  Dívida não contestada.
#
#           natureza       tipo  uf      valor  valor_divida
# 0  Falta Pagamento  protestos  SP  R$ 892,53        892.53
# 1  Falta Pagamento  protestos  SP  R$ 560,00        560.00
# 2  Falta Pagamento  protestos  SP  R$ 560,80        560.80
# 3  Falta Pagamento  protestos  SP  R$ 452,50        452.50
# 4  Falta Pagamento  protestos  SP  R$ 452,50        452.50

# %%
dfDiv["data"] = dfDiv.apply(lambda x : datetime.strptime(x["data_ocorrencia"], "%d/%m/%Y").date(), axis=1)

# %%
dfDiv.drop(columns = ["data_ocorrencia"], axis=1, inplace=True)

# %%
dt = dfDiv[dfDiv["cnpj"]=='19008188000142']

# %%
## tempo medio entre dividas

# %%
(datetime.now().date() - dt["data"].iloc[0]).days
# Out:
# 325

# %%
trace = go.Bar(
    x = dt["data"],
    y = dt["valor_divida"]
)
layout = go.Layout()
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# <div id="7205bf82-b9ad-4264-86d8-e6fab3d29d79" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7205bf82-b9ad-4264-86d8-e6fab3d29d79", [{"x": ["2018-05-21", "2018-03-22", "2018-03-15", "2018-03-01", "2018-02-22", "2017-07-11", "2016-11-21", "2016-11-04", "2016-10-31", "2015-04-30", "2015-03-31", "2015-02-28", "2015-11-07", "2015-10-22", "2015-09-24", "2015-10-08", "2015-07-01", "2015-07-31", "2015-07-30", "2015-07-19", "2015-07-19", "2015-06-19", "2015-01-31"], "y": [892.53, 560.0, 560.8, 452.5, 452.5, 421.44, 769.65, 769.65, 681.5, 10880.22, 6184.94, 8332.48, 7019.17, 7019.17, 8381.92, 7019.17, 1165.5, 1165.5, 6492.76, 12123.28, 6492.78, 12129.45, 25397.64], "type": "bar", "uid": "5ac2a767-306d-4b08-849f-c8591834e6e6"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("7205bf82-b9ad-4264-86d8-e6fab3d29d79"));});</script>

# %%
dt2 = dfDiv[dfDiv['cnpj']=='20604000000370']

# %%
dt2
# Out:
#              cnpj descricao_natureza     modalidade_natureza         natureza  \
# 0  20604000000370                NaN  Dívida não contestada.  Falta Pagamento
# 1  20604000000370                NaN  Dívida não contestada.  Falta Pagamento
# 2  20604000000370                NaN  Dívida não contestada.  Falta Pagamento
# 3  20604000000370                NaN  Dívida não contestada.  Falta Pagamento
#
#         tipo  uf       valor  valor_divida        data
# 0  protestos  RS  R$ 1000,00        1000.0  2016-01-26
# 1  protestos  RS  R$ 1000,00        1000.0  2015-12-26
# 2  protestos  RS   R$ 566,00         566.0  2015-12-16
# 3  protestos  RS  R$ 1012,00        1012.0  2015-11-26

# %%
trace = go.Bar(
    x = dt2["data"],
    y = dt2["valor_divida"]
)
layout = go.Layout()
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# <div id="732759a8-bf28-46e4-b6b2-373234fdacbc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("732759a8-bf28-46e4-b6b2-373234fdacbc", [{"x": ["2016-01-26", "2015-12-26", "2015-12-16", "2015-11-26"], "y": [1000.0, 1000.0, 566.0, 1012.0], "type": "bar", "uid": "04a8d83b-e2e7-4904-a697-a34cbc438a0e"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("732759a8-bf28-46e4-b6b2-373234fdacbc"));});</script>

# %%
dt2
# Out:
#              cnpj descricao_natureza     modalidade_natureza         natureza  \
# 0  20604000000370                NaN  Dívida não contestada.  Falta Pagamento
# 1  20604000000370                NaN  Dívida não contestada.  Falta Pagamento
# 2  20604000000370                NaN  Dívida não contestada.  Falta Pagamento
# 3  20604000000370                NaN  Dívida não contestada.  Falta Pagamento
#
#         tipo  uf       valor  valor_divida        data
# 0  protestos  RS  R$ 1000,00        1000.0  2016-01-26
# 1  protestos  RS  R$ 1000,00        1000.0  2015-12-26
# 2  protestos  RS   R$ 566,00         566.0  2015-12-16
# 3  protestos  RS  R$ 1012,00        1012.0  2015-11-26

# %%
d = dt2.sort_values("data")[["data"]].diff().dropna()

# %%
d["data"].iloc[0].days
# Out:
# 20

# %%
lista_tempo = d["data"].tolist()

# %%
lista_tempo = [el.days for el in lista_tempo]

# %%
np.mean(lista_tempo)
# Out:
# 20.333333333333332

# %%
dfDiv.head(1)
# Out:
#              cnpj descricao_natureza     modalidade_natureza         natureza  \
# 0  19008188000142                NaN  Dívida não contestada.  Falta Pagamento
#
#         tipo  uf      valor  valor_divida        data
# 0  protestos  SP  R$ 892,53        892.53  2018-05-21

# %%
# variavel : tempo medio entre dividas

# %%
def tempo_medio_entre_dividas(cnpj, df_dividas):
    dt = df_dividas[df_dividas["cnpj"]==cnpj]
    dt = dt.drop_duplicates()
    d = dt.sort_values("data")[["data"]].diff().dropna()
    lista_tempo = d["data"].tolist()
    lista_tempo = [el.days for el in lista_tempo]
    return np.mean(lista_tempo)

# %%
tempo_medio_entre_dividas("29734727000184", dfDiv)
# Out:
# 23.0

# %%
tempo_medio_entre_dividas('19008188000142', dfDiv)
# Out:
# 54.81818181818182

# %%
fr = list()
for el in dfDiv["cnpj"].unique().tolist():
    t = tempo_medio_entre_dividas(el, dfDiv)
    fr.append(pd.DataFrame({"cnpj" : [el], "tempo_medio" : [t]}))

# %%
## tempo medio == 0 => todas as dividas adquiridas em uma data
## tempo medio == nan => apenas um registro de divida

# %%
df_tempo = pd.concat(fr)

# %%
df_tempo.sort_values("tempo_medio", ascending=False).head()
# Out:
#              cnpj  tempo_medio
# 0  04160069000133       1135.0
# 0  18058375000178       1035.0
# 0  04247535000112        973.0
# 0  08756051000150        913.0
# 0  03598113000129        891.0

# %%
el = '24667289000165'
dt = dfDiv[dfDiv['cnpj']==el]

# %%
trace = go.Bar(
    x = [el.strftime("%Y/%B/%d") for el in dt["data"].tolist()],
    y = dt["valor_divida"]
)
layout = go.Layout(bargap = 0.6)
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# <div id="ae41ab07-bc68-4354-993b-52606c406058" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ae41ab07-bc68-4354-993b-52606c406058", [{"x": ["2017/October/10", "2016/June/06"], "y": [3000.0, 8985.77], "type": "bar", "uid": "ff2b0d86-66b5-4c07-9b60-fa7999334417"}], {"bargap": 0.6}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("ae41ab07-bc68-4354-993b-52606c406058"));});</script>

# %%
## idade maxima de uma divida

# %%
df_idade = dfDiv.groupby("cnpj").min().reset_index()[["cnpj", "data"]]

# %%
dfDiv["data"].iloc[0]
# Out:
# datetime.date(2018, 5, 21)

# %%
# dfDiv['data'] = dfDiv.apply(lambda x : x['data'].date(), axis=1)

# %%
df_idade["idade_maxima"] = df_idade.apply(lambda x : (datetime.now().date() - x["data"]).days, axis=1)

# %%
df_idade.sort_values("idade_maxima", ascending=False).head()
# Out:
#                cnpj        data  idade_maxima
# 113  05265762000133  2014-01-15          1912
# 385  14903137000160  2014-01-21          1906
# 182  08211207000117  2014-01-22          1905
# 429  17151619000108  2014-02-01          1895
# 198  08791838000152  2014-02-12          1884

# %%
dfDiv[dfDiv['cnpj']=='14903137000160']
# Out:
#              cnpj descricao_natureza             modalidade_natureza  \
# 0  14903137000160                NaN  ADIANT CONTA
#
#                                             natureza                    tipo  \
# 0  Adiantamento a depositantes - c/c devedores em...  restricoes_financeiras
#
#    uf      valor  valor_divida        data
# 0  SP  R$ 121,98        121.98  2014-01-21

# %%
dfDiv[dfDiv['cnpj']=='5265762000133']
# Out:
# Empty DataFrame
# Columns: [cnpj, descricao_natureza, modalidade_natureza, natureza, tipo, uf, valor, valor_divida, data]
# Index: []

# %%
_df = dfDiv.groupby("cnpj").min().reset_index()[["cnpj", "data"]]

# %%
datetime.now().date() - _df[_df['cnpj']=='5265762000133']['data'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-101-48519f5af16b> in <module>()
# ----> 1 datetime.now().date() - _df[_df['cnpj']=='5265762000133']['data'].iloc[0]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
df_idade.shape
# Out:
# (717, 3)

# %%
df_idade.shape
# Out:
# (717, 3)

# %%
df_tempo.shape
# Out:
# (717, 2)

# %%
df_tempo.head()
# Out:
#              cnpj  tempo_medio
# 0  19008188000142    54.818182
# 0  00748390000182    20.370370
# 0  00272073000302    48.600000
# 0  03403405000169    21.914634
# 0  04501499000171     6.590643

# %%
# tempo máximo de duracao de uma dívida
df_idade.sort_values("idade_maxima", ascending=False).head()
# Out:
#                cnpj        data  idade_maxima
# 113  05265762000133  2014-01-15          1912
# 385  14903137000160  2014-01-21          1906
# 182  08211207000117  2014-01-22          1905
# 429  17151619000108  2014-02-01          1895
# 198  08791838000152  2014-02-12          1884

# %%
df_tempo.to_excel("../tabelas/tempo_medio_entre_dividas_201904.xlsx")

# %%
df_idade.to_excel("../tabelas/idade_maxima_divida_201904.xlsx")

# %%
## entendendo os tipos de dividas para criar uma segmentacao de risco

# %%
dfDiv['natureza'].unique().tolist()
# Out:
# ['Falta Pagamento',
#  'CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO',
#  nan,
#  'Execução de Título Judicial Trabalhista',
#  'Execução Fiscal Estadual',
#  'Empréstimos em contas - c/c garantidas, financiamentos de capital de giro, programas especiais, etc',
#  'Cartão de crédito',
#  'Créditos e financiamentos - empréstimos a pessoas físicas , financiamentos ao consumidor final , etc',
#  'Execução',
#  'Operações imobiliárias em geral, inclusive de sociedades de poupança',
#  'Execução Fiscal Federal',
#  'Adiantamento a depositantes - c/c devedores em geral',
#  'Empréstimos agrícolas e industriais - financiamentos de custeio de investimentos agrícolas e industriais',
#  'Execução Fiscal Municipal',
#  'Execução - Pequenas Causas',
#  'Operações ajuizadas ',
#  'Arrendamentos, inclusive leasing',
#  'Busca e Apreensão',
#  'Consórcio outros bens móveis',
#  'Consórcio veículos leves']

# %%
dfDiv[dfDiv['tipo']=='cheques']
# Out:
# Empty DataFrame
# Columns: [cnpj, descricao_natureza, modalidade_natureza, natureza, tipo, uf, valor, data, valor_divida]
# Index: []

# %% [markdown]
# #### Processos

# %% [markdown]
# -  Exemplos : Execuções e Busca e Apreensão

# %%
dfDiv[dfDiv['natureza'] == 'Busca e Apreensão']
# Out:
#              cnpj descricao_natureza modalidade_natureza           natureza  \
# 0  13231036000128  BUSCA E APREENSAO                 NaN  Busca e Apreensão
#
#         tipo  uf        valor        data  valor_divida
# 0  processos  SP  R$ 15769,07  2019-01-15      15769.07

# %%
dfDiv[dfDiv['tipo']=='processos']['descricao_natureza'].unique().tolist()
# Out:
# ['EXC JUD TRAB',
#  'FISCAL ESTADUAL',
#  'EXECUCAO',
#  'FISCAL FEDERAL',
#  'FISCAL MUNICIPAL',
#  'EXECUCAO - JE',
#  'BUSCA E APREENSAO']

# %%
dfDiv[dfDiv['tipo']=='processos']["natureza"].unique().tolist()
# Out:
# ['Execução de Título Judicial Trabalhista',
#  'Execução Fiscal Estadual',
#  'Execução',
#  'Execução Fiscal Federal',
#  'Execução Fiscal Municipal',
#  'Execução - Pequenas Causas',
#  'Busca e Apreensão']

# %% [markdown]
# #### Restrições Financeiras

# %%
dfDiv[dfDiv['tipo'] == 'restricoes_financeiras']['modalidade_natureza'].unique().tolist()
# Out:
# ['EMPRES CONTA                  ',
#  'CRED CARTAO                   ',
#  'FINANCIAMENT                  ',
#  'OPER IMOBILI                  ',
#  'ADIANT CONTA                  ',
#  'TIT DESCONTA                  ',
#  'OUTRAS OPER                   ',
#  'CREDITO E FINANCIAMENTO-FINANC',
#  'EMPRESTIMO                    ',
#  'TITULOS DESCONTADOS-TURISMO   ',
#  'OPER AJUIZAD                  ',
#  'REPASSES                      ',
#  'LEASING                       ',
#  'OUTRAS OPERACOES-FINANCEIRA   ',
#  'CONSORCIO CONTEMPLADO         ',
#  'CONS BENS                     ',
#  'CONS VEICULOS                 ']

# %% [markdown]
# #### Pendências

# %%
dfDiv[dfDiv['tipo']=='pendencias']['modalidade_natureza'].unique().tolist()
# Out:
# ['DUPLICATA',
#  'OUTRAS OPER',
#  nan,
#  'NOTA FISCAL',
#  'VENDA MERCAD',
#  'TIT DESCONTA',
#  'ADIANT CONTA',
#  'SERV TELEFON',
#  'EMPRESTIMO',
#  'ALUGUEL',
#  'ARRECADADOR',
#  'CONDOMINIO',
#  'ENERGIA ELET',
#  'CONFISS DIV',
#  'CRED CARTAO',
#  'EMPRES CONTA',
#  'CREDIARIO',
#  'DIVIDAS CHEQ',
#  'FINANCIAMENT',
#  'SEGURO SAUDE',
#  'CONSORCIO CO',
#  'TELEF FX',
#  'TELEF FIXA',
#  'TELEF MOVEL',
#  'FAT AGUA',
#  'CONS VEICULO']

# %% [markdown]
# #### Protestos

# %%
dfDiv[dfDiv['tipo']=='protestos']['natureza'].unique().tolist()
# Out:
# ['Falta Pagamento']

# %%
dfDiv[dfDiv['tipo']=='protestos']['modalidade_natureza'].unique().tolist()
# Out:
# ['Dívida não contestada.']

# %%
dfDiv[dfDiv['tipo']=='protestos'].head()
# Out:
#              cnpj descricao_natureza     modalidade_natureza         natureza  \
# 0  19008188000142                NaN  Dívida não contestada.  Falta Pagamento
# 1  19008188000142                NaN  Dívida não contestada.  Falta Pagamento
# 2  19008188000142                NaN  Dívida não contestada.  Falta Pagamento
# 3  19008188000142                NaN  Dívida não contestada.  Falta Pagamento
# 4  19008188000142                NaN  Dívida não contestada.  Falta Pagamento
#
#         tipo  uf      valor        data  valor_divida
# 0  protestos  SP  R$ 892,53  2018-05-21        892.53
# 1  protestos  SP  R$ 560,00  2018-03-22        560.00
# 2  protestos  SP  R$ 560,80  2018-03-15        560.80
# 3  protestos  SP  R$ 452,50  2018-03-01        452.50
# 4  protestos  SP  R$ 452,50  2018-02-22        452.50

# %% [markdown]
# #### Processos

# %%
dfDiv[dfDiv['tipo'] =='processos']['descricao_natureza'].unique().tolist()
# Out:
# ['EXC JUD TRAB',
#  'FISCAL ESTADUAL',
#  'EXECUCAO',
#  'FISCAL FEDERAL',
#  'FISCAL MUNICIPAL',
#  'EXECUCAO - JE',
#  'BUSCA E APREENSAO']

# %%
dfDiv[dfDiv['tipo']=='processos']['natureza'].unique().tolist()
# Out:
# ['Execução de Título Judicial Trabalhista',
#  'Execução Fiscal Estadual',
#  'Execução',
#  'Execução Fiscal Federal',
#  'Execução Fiscal Municipal',
#  'Execução - Pequenas Causas',
#  'Busca e Apreensão']

# %%
dfDiv['natureza'].unique().tolist()
# Out:
# ['Falta Pagamento',
#  'CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO',
#  nan,
#  'Execução de Título Judicial Trabalhista',
#  'Execução Fiscal Estadual',
#  'Empréstimos em contas - c/c garantidas, financiamentos de capital de giro, programas especiais, etc',
#  'Cartão de crédito',
#  'Créditos e financiamentos - empréstimos a pessoas físicas , financiamentos ao consumidor final , etc',
#  'Execução',
#  'Operações imobiliárias em geral, inclusive de sociedades de poupança',
#  'Execução Fiscal Federal',
#  'Adiantamento a depositantes - c/c devedores em geral',
#  'Empréstimos agrícolas e industriais - financiamentos de custeio de investimentos agrícolas e industriais',
#  'Execução Fiscal Municipal',
#  'Execução - Pequenas Causas',
#  'Operações ajuizadas ',
#  'Arrendamentos, inclusive leasing',
#  'Busca e Apreensão',
#  'Consórcio outros bens móveis',
#  'Consórcio veículos leves']

# %% [markdown]
# #### Definindo segmentos de dívidas

# %%
## processos e suas modalidades representa um segmento

# %%
dfDiv[dfDiv['tipo']=='processos']['descricao_natureza'].unique().tolist()
# Out:
# ['EXC JUD TRAB',
#  'FISCAL ESTADUAL',
#  'EXECUCAO',
#  'FISCAL FEDERAL',
#  'FISCAL MUNICIPAL',
#  'EXECUCAO - JE',
#  'BUSCA E APREENSAO']

# %%
# 'descricao_natureza'
segmento1 = ['EXC JUD TRAB',
             'FISCAL ESTADUAL',
             'EXECUCAO',
             'FISCAL FEDERAL',
             'FISCAL MUNICIPAL',
             'EXECUCAO - JE',
             'BUSCA E APREENSAO']
# segmento1 => tipo == processos

# %%
## segmento2 dividas de emprestimos

# %%
l = dfDiv['modalidade_natureza'].unique().tolist()

# %%
for el in l:
    try:
        el.split()
    except:
        print(el is np.nan)
# Out:
# True

# %%
dfDiv['modalidade'] = dfDiv.apply(lambda x : x['modalidade_natureza'].replace(" ", "") if not x['modalidade_natureza'] is np.nan else None, axis=1)

# %%
lista_modalidade = dfDiv['modalidade'].unique().tolist()

# %%
lista_modalidade = [el.replace(".", "") for el in lista_modalidade if not el is None]

# %%
lista_modalidade = [el for el in lista_modalidade if not el is None]

# %%
lista_modalidade
['EMPRESTIMO', 'CREDITOEFINANCIAMENTO-FINANC', 'CREDCARTAO']
# Out:
# ['Dívidanãocontestada',
#  'DUPLICATA',
#  'OUTRASOPER',
#  'NOTAFISCAL',
#  'EMPRESCONTA',
#  'CREDCARTAO',
#  'FINANCIAMENT',
#  'OPERIMOBILI',
#  'VENDAMERCAD',
#  'TITDESCONTA',
#  'ADIANTCONTA',
#  'SERVTELEFON',
#  'EMPRESTIMO',
#  'ALUGUEL',
#  'ARRECADADOR',
#  'CONDOMINIO',
#  'ENERGIAELET',
#  'CONFISSDIV',
#  'CREDITOEFINANCIAMENTO-FINANC',
#  'CREDIARIO',
#  'TITULOSDESCONTADOS-TURISMO',
#  'DIVIDASCHEQ',
#  'OPERAJUIZAD',
#  'REPASSES',
#  'LEASING',
#  'OUTRASOPERACOES-FINANCEIRA',
#  'SEGUROSAUDE',
#  'CONSORCIOCO',
#  'CONSORCIOCONTEMPLADO',
#  'CONSBENS',
#  'TELEFFX',
#  'TELEFFIXA',
#  'TELEFMOVEL',
#  'FATAGUA',
#  'CONSVEICULO',
#  'CONSVEICULOS']

# %%
# segmento 2 : dividas

# %%
dfDiv['cnpj'].iloc[0]
# Out:
# 19008188000142

# %%
dfDiv[dfDiv['cnpj']==18356074000120]
# Out:
#              cnpj descricao_natureza             modalidade_natureza  \
# 0  18356074000120                NaN  CREDITO E FINANCIAMENTO-FINANC
# 1  18356074000120                NaN  CRED CARTAO
# 2  18356074000120                NaN  CRED CARTAO
# 3  18356074000120                NaN  CREDITO E FINANCIAMENTO-FINANC
# 0  18356074000120                NaN          Dívida não contestada.
# 1  18356074000120                NaN          Dívida não contestada.
# 2  18356074000120                NaN          Dívida não contestada.
# 3  18356074000120                NaN          Dívida não contestada.
# 4  18356074000120                NaN          Dívida não contestada.
# 5  18356074000120                NaN          Dívida não contestada.
# 6  18356074000120                NaN          Dívida não contestada.
# 7  18356074000120                NaN          Dívida não contestada.
# 8  18356074000120                NaN          Dívida não contestada.
# 0  18356074000120                NaN                     OUTRAS OPER
#
#                             natureza                    tipo   uf  \
# 0  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  restricoes_financeiras   SP
# 1                  Cartão de crédito  restricoes_financeiras
# 2                  Cartão de crédito  restricoes_financeiras
# 3  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO  restricoes_financeiras   SP
# 0                    Falta Pagamento               protestos   SP
# 1                    Falta Pagamento               protestos   SP
# 2                    Falta Pagamento               protestos   SP
# 3                    Falta Pagamento               protestos   SP
# 4                    Falta Pagamento               protestos   SP
# 5                    Falta Pagamento               protestos   SP
# 6                    Falta Pagamento               protestos   SP
# 7                    Falta Pagamento               protestos   SP
# 8                    Falta Pagamento               protestos   SP
# 0  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO              pendencias  NaN
#
#          valor       data  valor_divida                    modalidade
# 0  R$ 11420,97 2015-01-27      11420.97  CREDITOEFINANCIAMENTO-FINANC
# 1   R$ 2318,53 2015-01-26       2318.53                    CREDCARTAO
# 2   R$ 2590,85 2014-12-13       2590.85                    CREDCARTAO
# 3  R$ 56003,05 2014-05-09      56003.05  CREDITOEFINANCIAMENTO-FINANC
# 0   R$ 5946,33 2018-02-07       5946.33          Dívidanãocontestada.
# 1    R$ 361,79 2017-07-13        361.79          Dívidanãocontestada.
# 2    R$ 817,83 2017-07-13        817.83          Dívidanãocontestada.
# 3    R$ 500,00 2016-01-01        500.00          Dívidanãocontestada.
# 4    R$ 500,00 2015-12-01        500.00          Dívidanãocontestada.
# 5    R$ 500,00 2015-11-01        500.00          Dívidanãocontestada.
# 6    R$ 500,00 2015-10-01        500.00          Dívidanãocontestada.
# 7    R$ 844,75 2015-04-15        844.75          Dívidanãocontestada.
# 8    R$ 267,00 2015-03-11        267.00          Dívidanãocontestada.
# 0   R$ 1877,29 2015-11-01       1877.29                    OUTRASOPER

# %%
l2 = [el.strip() for el in l]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-5cb862319c13> in <module>()
# ----> 1 l2 = [el.strip() for el in l]
#
# <ipython-input-133-5cb862319c13> in <listcomp>(.0)
# ----> 1 l2 = [el.strip() for el in l]
#
# AttributeError: 'float' object has no attribute 'strip'

# %%
l
# Out:
# ['Dívida não contestada.',
#  'DUPLICATA',
#  'OUTRAS OPER',
#  nan,
#  'NOTA FISCAL',
#  'EMPRES CONTA                  ',
#  'CRED CARTAO                   ',
#  'FINANCIAMENT                  ',
#  'OPER IMOBILI                  ',
#  'VENDA MERCAD',
#  'TIT DESCONTA',
#  'ADIANT CONTA                  ',
#  'TIT DESCONTA                  ',
#  'ADIANT CONTA',
#  'SERV TELEFON',
#  'EMPRESTIMO',
#  'OUTRAS OPER                   ',
#  'ALUGUEL',
#  'ARRECADADOR',
#  'CONDOMINIO',
#  'ENERGIA ELET',
#  'CONFISS DIV',
#  'CRED CARTAO',
#  'EMPRES CONTA',
#  'CREDITO E FINANCIAMENTO-FINANC',
#  'EMPRESTIMO                    ',
#  'CREDIARIO',
#  'TITULOS DESCONTADOS-TURISMO   ',
#  'DIVIDAS CHEQ',
#  'OPER AJUIZAD                  ',
#  'REPASSES                      ',
#  'LEASING                       ',
#  'OUTRAS OPERACOES-FINANCEIRA   ',
#  'FINANCIAMENT',
#  'SEGURO SAUDE',
#  'CONSORCIO CO',
#  'CONSORCIO CONTEMPLADO         ',
#  'CONS BENS                     ',
#  'TELEF FX',
#  'TELEF FIXA',
#  'TELEF MOVEL',
#  'FAT AGUA',
#  'CONS VEICULO',
#  'CONS VEICULOS                 ']

# %%
dfDiv[dfDiv['modalidade_natureza']=='CRED CARTAO']
# Out:
#              cnpj descricao_natureza modalidade_natureza           natureza  \
# 2  19070425000103                NaN         CRED CARTAO  Cartão de crédito
# 0   4588664000174                NaN         CRED CARTAO  Cartão de crédito
#
#          tipo   uf        valor        data  valor_divida
# 2  pendencias  NaN  R$ 11166,37  2016-06-10      11166.37
# 0  pendencias  NaN   R$ 5639,21  2016-07-05       5639.21

# %%
dfDiv[dfDiv['modalidade_natureza']=='CRED CARTAO                   ']
# Out:
#               cnpj descricao_natureza             modalidade_natureza  \
# 3    4501499000171                NaN  CRED CARTAO
# 6    4501499000171                NaN  CRED CARTAO
# 9    4501499000171                NaN  CRED CARTAO
# 6   14761474000160                NaN  CRED CARTAO
# 9   14761474000160                NaN  CRED CARTAO
# 10  14761474000160                NaN  CRED CARTAO
# 2   19819235000138                NaN  CRED CARTAO
# 0    5376703000132                NaN  CRED CARTAO
# 1   15389888000173                NaN  CRED CARTAO
# 4   15389888000173                NaN  CRED CARTAO
# 1    7194858000183                NaN  CRED CARTAO
# 1   22886258000170                NaN  CRED CARTAO
# 0   19086478000104                NaN  CRED CARTAO
# 2   49596851000138                NaN  CRED CARTAO
# 0   15335189000140                NaN  CRED CARTAO
# 1   18356074000120                NaN  CRED CARTAO
# 2   18356074000120                NaN  CRED CARTAO
# 11   5800976000162                NaN  CRED CARTAO
# 15   5800976000162                NaN  CRED CARTAO
# 5     178663000281                NaN  CRED CARTAO
# 6     178663000281                NaN  CRED CARTAO
# 1   68417526000105                NaN  CRED CARTAO
# 2   68417526000105                NaN  CRED CARTAO
# 2    8310428000142                NaN  CRED CARTAO
# 0   27090358000109                NaN  CRED CARTAO
# 0   15523647000175                NaN  CRED CARTAO
# 0   14373103000101                NaN  CRED CARTAO
# 1   18836786000147                NaN  CRED CARTAO
# 0   21061108000164                NaN  CRED CARTAO
# 1   47785290000190                NaN  CRED CARTAO
# ..             ...                ...                             ...
# 1    2361751000169                NaN  CRED CARTAO
# 1    8852150000135                NaN  CRED CARTAO
# 0   13153240000178                NaN  CRED CARTAO
# 0   16612923000134                NaN  CRED CARTAO
# 0    7595489000130                NaN  CRED CARTAO
# 1    5458709000159                NaN  CRED CARTAO
# 4   44705564000103                NaN  CRED CARTAO
# 3   18754982000172                NaN  CRED CARTAO
# 0   24247971000107                NaN  CRED CARTAO
# 1    3215938000117                NaN  CRED CARTAO
# 0    5865538000182                NaN  CRED CARTAO
# 0   10886031000145                NaN  CRED CARTAO
# 0   14984780000166                NaN  CRED CARTAO
# 4    3356764000102                NaN  CRED CARTAO
# 1    3941181000149                NaN  CRED CARTAO
# 0    4160069000133                NaN  CRED CARTAO
# 1    4160069000133                NaN  CRED CARTAO
# 2    4160069000133                NaN  CRED CARTAO
# 0    5592130000184                NaN  CRED CARTAO
# 1    5864972000148                NaN  CRED CARTAO
# 1    7810124000181                NaN  CRED CARTAO
# 1    9353407000177                NaN  CRED CARTAO
# 4    9353407000177                NaN  CRED CARTAO
# 5    9353407000177                NaN  CRED CARTAO
# 2   10736773000194                NaN  CRED CARTAO
# 0   11734776000151                NaN  CRED CARTAO
# 0   15690193000127                NaN  CRED CARTAO
# 0   15699778000108                NaN  CRED CARTAO
# 0   17024240000129                NaN  CRED CARTAO
# 0   24509856000155                NaN  CRED CARTAO
#
#              natureza                    tipo  uf         valor        data  \
# 3   Cartão de crédito  restricoes_financeiras  SP   R$ 11756,22  2017-02-25
# 6   Cartão de crédito  restricoes_financeiras       R$ 27909,47  2017-01-15
# 9   Cartão de crédito  restricoes_financeiras       R$ 32512,70  2017-01-05
# 6   Cartão de crédito  restricoes_financeiras        R$ 6456,28  2017-07-15
# 9   Cartão de crédito  restricoes_financeiras       R$ 22849,62  2017-01-26
# 10  Cartão de crédito  restricoes_financeiras       R$ 21012,33  2017-01-24
# 2   Cartão de crédito  restricoes_financeiras        R$ 1924,17  2016-10-15
# 0   Cartão de crédito  restricoes_financeiras       R$ 13525,81  2018-05-01
# 1   Cartão de crédito  restricoes_financeiras        R$ 1715,08  2016-04-01
# 4   Cartão de crédito  restricoes_financeiras        R$ 1605,39  2015-07-29
# 1   Cartão de crédito  restricoes_financeiras        R$ 7334,41  2018-06-25
# 1   Cartão de crédito  restricoes_financeiras         R$ 956,65  2017-04-13
# 0   Cartão de crédito  restricoes_financeiras        R$ 2284,90  2018-04-25
# 2   Cartão de crédito  restricoes_financeiras       R$ 24482,19  2018-06-16
# 0   Cartão de crédito  restricoes_financeiras        R$ 2121,62  2018-02-16
# 1   Cartão de crédito  restricoes_financeiras        R$ 2318,53  2015-01-26
# 2   Cartão de crédito  restricoes_financeiras        R$ 2590,85  2014-12-13
# 11  Cartão de crédito  restricoes_financeiras       R$ 10026,66  2014-11-16
# 15  Cartão de crédito  restricoes_financeiras      R$ 191003,59  2014-10-16
# 5   Cartão de crédito  restricoes_financeiras       R$ 22205,07  2016-10-15
# 6   Cartão de crédito  restricoes_financeiras       R$ 10822,40  2016-09-25
# 1   Cartão de crédito  restricoes_financeiras  SP   R$ 11397,94  2019-01-10
# 2   Cartão de crédito  restricoes_financeiras  SP    R$ 3531,10  2019-01-10
# 2   Cartão de crédito  restricoes_financeiras        R$ 1906,92  2018-10-13
# 0   Cartão de crédito  restricoes_financeiras        R$ 3161,01  2018-12-01
# 0   Cartão de crédito  restricoes_financeiras        R$ 5183,43  2015-10-14
# 0   Cartão de crédito  restricoes_financeiras        R$ 2668,79  2016-07-24
# 1   Cartão de crédito  restricoes_financeiras        R$ 5369,88  2018-06-20
# 0   Cartão de crédito  restricoes_financeiras         R$ 792,63  2018-09-10
# 1   Cartão de crédito  restricoes_financeiras         R$ 239,18  2018-11-01
# ..                ...                     ...  ..           ...         ...
# 1   Cartão de crédito  restricoes_financeiras        R$ 1160,24  2017-11-29
# 1   Cartão de crédito  restricoes_financeiras         R$ 144,28  2014-10-30
# 0   Cartão de crédito  restricoes_financeiras        R$ 2314,46  2016-10-01
# 0   Cartão de crédito  restricoes_financeiras        R$ 8912,76  2018-08-25
# 0   Cartão de crédito  restricoes_financeiras         R$ 610,07  2017-07-15
# 1   Cartão de crédito  restricoes_financeiras         R$ 952,70  2018-03-15
# 4   Cartão de crédito  restricoes_financeiras         R$ 154,87  2016-02-21
# 3   Cartão de crédito  restricoes_financeiras        R$ 9863,99  2016-11-03
# 0   Cartão de crédito  restricoes_financeiras         R$ 471,88  2017-12-01
# 1   Cartão de crédito  restricoes_financeiras       R$ 51369,15  2017-03-20
# 0   Cartão de crédito  restricoes_financeiras        R$ 3471,77  2018-10-25
# 0   Cartão de crédito  restricoes_financeiras  SP   R$ 12859,42  2019-01-07
# 0   Cartão de crédito  restricoes_financeiras        R$ 8757,20  2017-09-20
# 4   Cartão de crédito  restricoes_financeiras        R$ 1733,42  2015-12-15
# 1   Cartão de crédito  restricoes_financeiras        R$ 3376,08  2015-02-28
# 0   Cartão de crédito  restricoes_financeiras         R$ 881,99  2019-02-05
# 1   Cartão de crédito  restricoes_financeiras        R$ 5623,15  2019-01-23
# 2   Cartão de crédito  restricoes_financeiras        R$ 8116,65  2018-12-16
# 0   Cartão de crédito  restricoes_financeiras        R$ 3039,92  2016-09-28
# 1   Cartão de crédito  restricoes_financeiras       R$ 69550,78  2015-01-16
# 1   Cartão de crédito  restricoes_financeiras       R$ 20842,39  2016-12-16
# 1   Cartão de crédito  restricoes_financeiras         R$ 273,71  2018-11-09
# 4   Cartão de crédito  restricoes_financeiras         R$ 505,19  2018-10-15
# 5   Cartão de crédito  restricoes_financeiras      R$ 100196,62  2018-07-16
# 2   Cartão de crédito  restricoes_financeiras        R$ 8567,08  2017-01-16
# 0   Cartão de crédito  restricoes_financeiras        R$ 1204,54  2015-09-18
# 0   Cartão de crédito  restricoes_financeiras        R$ 1309,08  2017-04-10
# 0   Cartão de crédito  restricoes_financeiras       R$ 23254,02  2016-09-01
# 0   Cartão de crédito  restricoes_financeiras        R$ 2349,29  2018-10-26
# 0   Cartão de crédito  restricoes_financeiras  PE     R$ 859,21  2019-01-02
#
#     valor_divida
# 3       11756.22
# 6       27909.47
# 9       32512.70
# 6        6456.28
# 9       22849.62
# 10      21012.33
# 2        1924.17
# 0       13525.81
# 1        1715.08
# 4        1605.39
# 1        7334.41
# 1         956.65
# 0        2284.90
# 2       24482.19
# 0        2121.62
# 1        2318.53
# 2        2590.85
# 11      10026.66
# 15     191003.59
# 5       22205.07
# 6       10822.40
# 1       11397.94
# 2        3531.10
# 2        1906.92
# 0        3161.01
# 0        5183.43
# 0        2668.79
# 1        5369.88
# 0         792.63
# 1         239.18
# ..           ...
# 1        1160.24
# 1         144.28
# 0        2314.46
# 0        8912.76
# 0         610.07
# 1         952.70
# 4         154.87
# 3        9863.99
# 0         471.88
# 1       51369.15
# 0        3471.77
# 0       12859.42
# 0        8757.20
# 4        1733.42
# 1        3376.08
# 0         881.99
# 1        5623.15
# 2        8116.65
# 0        3039.92
# 1       69550.78
# 1       20842.39
# 1         273.71
# 4         505.19
# 5      100196.62
# 2        8567.08
# 0        1204.54
# 0        1309.08
# 0       23254.02
# 0        2349.29
# 0         859.21
#
# [64 rows x 9 columns]

# %%
dfDiv[dfDiv['modalidade_natureza']=='EMPRESTIMO']['tipo'].unique().tolist()
# Out:
# ['pendencias']

# %%
dfDiv['tipo'].unique().tolist()
# Out:
# ['protestos', 'pendencias', 'processos', 'restricoes_financeiras']

# %%
## uma ideia de variavel : alavanvagem anual de dividas

# %%
## porte da dívida (só faz sentido se comparado com o faturamento médio?)
