# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings("ignore")

# %%
engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
con = engine.connect()
dfjusta = pd.read_sql("select * from propostas_mensais where produto='Justa'", con)
con.close()

# %%
dfjusta.shape
# Out:
# (186, 7)

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta
from conector.mysql import mysql_engine
from sqlalchemy import create_engine
from pricing.service.scoring.base import BaseScoring
from werkzeug import exceptions
from scipy import stats
from pricing.utils import formata_cnpj
from datamanager import conn_pricing


class LScoring(BaseScoring):
    def __init__(self, data=None, cnpj=None, produto=None):
        self.cnpj = cnpj
        self.produto = data.get("id_produto") if not data is None else produto
        self.params = self.get_dados() if not self.cnpj is None else data.get("dados")
        # self.params = data['dados']
        # self.produto = data['id_produto']
        self.faturamentos = None
        self.razao_outlier = None
        self.data_max = None
        self.estabilidade = None
        self.pesos = None
        self.volatilidade = None
        self.curva_score = None
        self.score_crescimento = None
        self.prop_queda = None
        self.score_volatilidade = None
        self.slope = None
        self.erro = None
        self.probabilidade_zeros = None
        self.zscore = None
        self.score1 = None
    
    def get_dados(self):
        if self.produto in ["tomatico", "padrao"]:
            engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/credito-digital")
            con = engine.connect()
        else:
            engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
            con = engine.connect()
        
        query_wirecard = "select cpf_cnpj as cnpj, data, pgto_liquido as valor from fluxo_moip where cpf_cnpj='{}'".format(formata_cnpj(self.cnpj))
        query_pv = "select cpf_cnpj as cnpj, data, valor from fluxo_pv where cpf_cnpj='{}'".format(formata_cnpj(self.cnpj))
        query_tomatico = "select cnpj, dataFluxo as data, valorFluxo as valor from tb_Fluxo where cnpj='{}'".format(self.cnpj)
        query_justa = "select cnpj, data, valor from fluxo_justa where cnpj='{}'".format(self.cnpj)
        dict_query = {"tomatico" : query_tomatico,
                    "padrao" : query_tomatico,
                    "wirecard" : query_wirecard,
                    "moip" : query_wirecard,
                    "pagueveloz" : query_pv,
                    "justa" : query_justa
                }
        query = dict_query.get(self.produto)
        df = pd.read_sql(query, con)
        con.close()
        df = df.groupby("data").sum().reset_index()
        try:
            df["data"] = df.apply(lambda x : x["data"].date(), axis=1)
        except:
            pass
        dados = df[["data", "valor"]].to_dict("records")
        return dados
    
    @classmethod
    def validar_dados(cls, data):
        if data is None:
            raise exceptions.BadRequest("Missing data")

        if not isinstance(data['dados'], list):
            raise exceptions.UnprocessableEntity(
                "Field 'dados' should be an array")

    @staticmethod
    def gera_periodo(periods=12):
        now = datetime.now().date()
        start = datetime(now.year, now.month, 1)
        start = start - relativedelta(months=periods)
        datas = pd.date_range(start=start, periods=periods, freq='MS')
        datas = [el.date() for el in datas]
        return datas

    @staticmethod
    def mensaliza(df):
        df.index = pd.to_datetime(df.data)
        df = df.resample('MS').sum().reset_index()
        print(df)
        return df

    def isElegible(self):
        df = pd.DataFrame(self.params)
        df = self.mensaliza(df)
        per = self.gera_periodo(periods=6)
        print("periodo de elegibilidade : {}".format(per))
        df = df[df['data'].isin(per)].copy()
        lista_val = df['valor'].tolist()
        if 0 in lista_val or len(df) < 6:
            return None
        return 1

    def gera_serie(self, periods=12):
        df = pd.DataFrame(self.params)
        df = self.mensaliza(df)
        df['data'] = df.data.dt.date
        periodo_completo = self.gera_periodo(periods=periods)
        df = df[df['data'].isin(periodo_completo)]
        if df.empty:
            self.faturamentos = df
            return
        data_min = df['data'].min()
        datas = pd.date_range(
            start=data_min, end=periodo_completo[-1], freq="MS")
        datas = [el.date() for el in datas]

        for data in datas:
            if data not in df['data'].tolist():
                df_extra = pd.DataFrame({"data": [data], "valor": [0]})
                df = pd.concat([df, df_extra])
                df.sort_values("data", inplace=True)

        if self.faturamentos is None:
            self.faturamentos = df
        return

    def outlier_6meses(self):
        razao_outlier = self.faturamentos['valor'].mean(
        )/np.mean(self.faturamentos['valor'].tolist()[:-1])
        if self.razao_outlier is None:
            self.razao_outlier = razao_outlier
        return

    def data_maxima(self):
        res = dict(zip(list(self.faturamentos['valor'].diff())[
                   1:], self.faturamentos['data'].tolist()[0:-1]))
        data_max = res.get(np.max(list(res.keys())))
        if self.data_max is None:
            self.data_max = data_max
        return

    def crescimento_efetivo(self):
        df = self.faturamentos[self.faturamentos['data'] > self.data_max]
        estabilidade = df['valor'].std()/df['valor'].iloc[0]
        if self.estabilidade is None:
            self.estabilidade = estabilidade
        return

    def calcula_pesos(self):
        pesos = list(range(1, self.faturamentos.shape[0]))

        if self.estabilidade <= 0.15:
            dic_pesos = dict(
                zip(self.faturamentos['data'].tolist()[:-1], pesos))
            peso_max = np.max(list(dic_pesos.values()))
            dic_pesos[self.data_max] = peso_max

            if self.data_max - relativedelta(months=1) in list(dic_pesos.keys()):
                p = dic_pesos.get(self.data_max - relativedelta(months=1))
            else:
                p = 0

            keys = pd.date_range(start=self.data_max + relativedelta(months=1),
                                 end=list(dic_pesos.keys())[-1], freq='MS')
            keys = [el.date() for el in keys]

            i = 1
            for data in keys:
                dic_pesos[data] = p + i
                i += 1
        else:
            dic_pesos = dict(
                zip(self.faturamentos['data'].tolist()[:-1], pesos))

        if self.pesos is None:
            self.pesos = dic_pesos
        return

    def calcula_volatilidade(self):
        self.volatilidade = self.faturamentos['valor'].std(
        )/self.faturamentos['valor'].mean()
        return

    # score de crescimento
    def lscore(self):
        pesos = list(self.pesos.values())

        if self.razao_outlier >= 2:
            pesos[-1] = 1

        dfcalc = self.faturamentos[['valor']].diff()
        dfcalc.dropna(inplace=True)
        dfcalc['pesos'] = pesos
        dfcalc['tx'] = dfcalc['valor'] * dfcalc['pesos']
        tx = dfcalc['tx'].sum() / dfcalc['pesos'].sum()
        tx = tx/self.faturamentos['valor'].mean()
        return tx

    def calibracao(self):
        eng = mysql_engine("apiPricing")
        df = pd.read_sql("select * from apiPricing.calibracao_score", eng)
        self.curva_score = df[['metrica',
                               'score', 'tipo_metrica', 'bandwidth']]
        return

    def get_score(self, metrica, tipo_metrica):
        dfcal = self.curva_score[self.curva_score['tipo_metrica']
                                 == tipo_metrica]
        bw = dfcal['bandwidth'].iloc[0]

        if tipo_metrica == 'lscore':
            if metrica <= dfcal['metrica'].min():
                return 0
            if metrica >= dfcal['metrica'].max():
                return 1000
        else:
            if metrica >= dfcal['metrica'].max():
                return 0
            if metrica <= dfcal["metrica"].min():
                return 1000

        return dfcal[(dfcal['metrica'] >= metrica-bw) & (dfcal['metrica'] <= metrica+bw)]['score'].mean()

    def prop_quedas(self):
        dt = self.faturamentos
        df1 = dt[['valor']].diff()
        df1.dropna(inplace=True)
        df1['flag'] = df1.apply(lambda x: int(x['valor'] < 0), axis=1)
        if 1 not in df1['flag'].tolist():
            self.prop_queda = 0
        if 0 not in df1["flag"].tolist():
            self.prop_queda = 1
        
        return

    def calcula_tendencia(self):
        dt = pd.DataFrame(self.params)
        dt["valor"] = dt["valor"]/dt["valor"].max()
        x = dt.index
        y = dt['valor']

        slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
        self.slope = slope
        self.erro = std_err
        return
    
    # calculo da probabilidade de se observar faturamento nulo
    def probabilidade_faturamento_nulo(self):
        _df = self.faturamentos
        media = _df['valor'].mean()
        _df['prop'] = _df['valor']/media

        periodo_elegibilidade = self.gera_periodo(periods=6)
        df_zeros = _df[~_df['data'].isin(periodo_elegibilidade)]
        
        # qualquer valor menor que 20% do valor medio sera considerado faturamento nulo
        probabilidade = len(df_zeros[df_zeros['prop'] <= 0.2])/len(_df)
        print("probabilidade_zeros :{}".format(probabilidade))
        if self.probabilidade_zeros is None:
            self.probabilidade_zeros = probabilidade
        return 
    
    def calcula_zscore(self, score_inicial):
        if self.probabilidade_zeros > 0:
            n = len(self.faturamentos)
            # considering a valid prob if we have at least 10 months
            if n >= 10:
                score = score_inicial * ((((-1) * n)/(n-6)) * self.probabilidade_zeros + 1)
                if self.zscore is None:
                    self.zscore = score
                    print("ZSCORE : {}".format(score))
    @property
    def correcao(self):
        return {6 : 0.7, 7 : 0.8, 8 : 0.9}
    
    def get_correcao(self, score):
        historico = len(self.faturamentos)
        print("HISTORICO : {}".format(historico))
        fator_correcao = self.correcao.get(historico, 1)
        print('CORRECAO HISTORICO : {}'.format(fator_correcao))
        return fator_correcao*score

    def calcula(self):
        if self.produto == 'tomatico' or self.produto == "padrao":
            if not self.isElegible():
                return {'score': np.nan}

        self.gera_serie()
        if self.faturamentos.empty:
            return {"score" : np.nan}

        now = datetime.now().date() - relativedelta(months=1)
        data_proposta = datetime(now.year, now.month, 1).date()

        if self.faturamentos[self.faturamentos['data'] == data_proposta]['valor'].iloc[0] == 0:
            self.faturamentos = self.faturamentos[self.faturamentos['data'] != data_proposta]

        self.data_maxima()
        self.outlier_6meses()
        self.calcula_volatilidade()
        self.crescimento_efetivo()
        self.calcula_pesos()
        self.probabilidade_faturamento_nulo()

        lscore = self.lscore()

        self.prop_quedas()
        self.calibracao()

        score = self.get_score(metrica=lscore, tipo_metrica='lscore')
        self.score_crescimento = score
        if self.prop_queda == 0:
            self.score_crescimento = 1000
            self.calcula_zscore(self.score_crescimento)
            if not self.zscore is None:
                score = (self.score_crescimento + self.zscore)/2
                
            else:
                score = self.score_crescimento
            self.score1 = score
            score = self.get_correcao(score)
            return {'score' : int(score)}

        if self.prop_queda == 1:
            self.calcula_zscore(self.score_crescimento)
            if not self.zscore is None:
                score = (self.zscore + self.score_crescimento)/2
        
            else:
                score = self.score_crescimento
            self.score1 = score
            score = self.get_correcao(score)
            return {'score' : int(score)}

        self.calcula_tendencia()
        if self.slope < -0.2:
            self.calcula_zscore(score)
            if not self.zscore is None:
                score = (self.zscore + self.score_crescimento)/2
            else:
                score = self.score_crescimento
            self.score1 = score
            score = self.get_correcao(score)
            return {'score': int(score)}

        if abs(self.slope) <= 0.01 and self.erro < 0.05:
            self.score_volatilidade = 1000*(1-self.erro)
            score = (2*self.score_crescimento + self.score_volatilidade)/3
            self.calcula_zscore(score)
            
            if not self.zscore is None:
                score = (self.zscore + score)/2
            
            self.score1 = score
            score = self.get_correcao(score)
            
            return {'score': int(score)}

        self.params = self.faturamentos.sort_values('data', ascending=False).iloc[:6, :].sort_values('data').to_dict('records')
        self.calcula_tendencia()
        if self.slope < -0.2:
            self.calcula_zscore(self.score_crescimento)
            
            if not self.zscore is None:
                score = (self.zscore + self.score_crescimento)/2
            else:
                score = self.score_crescimento
            
            self.score1 = score
            score = self.get_correcao(score)
            
            return  {'score': int(score)}
        
        self.score_volatilidade = int(self.get_score(metrica=self.volatilidade, tipo_metrica='vscore'))
        
        score = (2*self.score_crescimento + self.score_volatilidade)/3
        print("SCORE INICIAL : {}".format(score))
        self.calcula_zscore(score)
        if not self.zscore is None:
            score = (self.zscore + score)/2
        self.score1 = score
        score = self.get_correcao(score)
        
        return {'score': int(score)}


if __name__ == '__main__':
    # {'data': datetime(2018, 6, 1).date(), 'valor': 17940.7},
    #                     {'data': datetime(2018, 7, 1).date(), 'valor': 54562.7},
    #                     {'data': datetime(2018, 8, 1).date(), 'valor': 25548.5},
    #                     {'data': datetime(2018, 9, 1).date(), 'valor': 57659.6},
    body = {'dados': [
                        {'data': datetime(2018, 12, 1).date(), 'valor': 98865.0},
                        {'data': datetime(2019, 1, 1).date(), 'valor': 101838.0},
                        {'data': datetime(2019, 2, 1).date(), 'valor': 62798.6},
                        {'data': datetime(2019, 3, 1).date(), 'valor': 52231.3},
                        {'data': datetime(2019, 4, 1).date(), 'valor': 22814.2},
                        {'data': datetime(2019, 5, 1).date(), 'valor': 34214.0}],
            'id_produto': 'tomatico'}

    ls = LScoring(cnpj='01246934000170', produto="justa")
    ls = LScoring(body)
    _df = pd.DataFrame(ls.params)
    datas = pd.date_range(end = (datetime.now().date().replace(day=1) - relativedelta(months=1)), periods=len(_df), freq='MS')
    datas = [el.date() for el in datas]
    _df['data'] = datas
    ls.params = _df.to_dict("records")
    print(ls.calcula())
    print(ls.faturamentos)
# Out:
#         data     valor
# 0 2018-12-01   98865.0
# 1 2019-01-01  101838.0
# 2 2019-02-01   62798.6
# 3 2019-03-01   52231.3
# 4 2019-04-01   22814.2
# 5 2019-05-01   34214.0
# periodo de elegibilidade : [datetime.date(2018, 12, 1), datetime.date(2019, 1, 1), datetime.date(2019, 2, 1), datetime.date(2019, 3, 1), datetime.date(2019, 4, 1), datetime.date(2019, 5, 1)]
#         data     valor
# 0 2018-12-01   98865.0
# 1 2019-01-01  101838.0
# 2 2019-02-01   62798.6
# 3 2019-03-01   52231.3
# 4 2019-04-01   22814.2
# 5 2019-05-01   34214.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 372.8417508417508
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# {'score': 260}
#          data     valor      prop
# 0  2018-12-01   98865.0  1.591341
# 1  2019-01-01  101838.0  1.639195
# 2  2019-02-01   62798.6  1.010813
# 3  2019-03-01   52231.3  0.840720
# 4  2019-04-01   22814.2  0.367220
# 5  2019-05-01   34214.0  0.550712

# %%
ls.score1
# Out:
# 372.8417508417508

# %%
ls.faturamentos["valor"].plot()

# %%
ls.faturamentos["valor"].mean()
# Out:
# 62126.85

# %%
# def recalcula_score(cnpj):
#     ls = LScoring(cnpj=cnpj, produto='justa')
#     return ls.calcula().get("score")

def recalcula_score(cnpj):
    ls = LScoring(cnpj=cnpj, produto='justa')
    ls.calcula()
    return ls.score1

# %%
dfjusta["score1"] = dfjusta.apply(lambda x : recalcula_score(x["cnpj"]), axis=1)
# Out:
#         data     valor
# 0 2018-11-01   3995.38
# 1 2018-12-01   4311.87
# 2 2019-01-01   9195.56
# 3 2019-02-01  11127.60
# 4 2019-03-01  12082.30
# 5 2019-04-01   7528.29
# probabilidade_zeros :0.0
# SCORE INICIAL : 682.0909090909091
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data    valor
# 0 2018-11-01  17046.6
# 1 2018-12-01  28100.6
# 2 2019-01-01  23499.0
# 3 2019-02-01  18850.0
# 4 2019-03-01  15413.2
# 5 2019-04-01  18899.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 705.4151515151516
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data    valor
# 0 2018-11-01  15039.2
# 1 2018-12-01  15871.7
# 2 2019-01-01  15352.9
# 3 2019-02-01  17385.3
# 4 2019-03-01  17599.8
# 5 2019-04-01  11693.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 676.1515151515152
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data    valor
# 0 2018-11-01  7064.19
# 1 2018-12-01  2752.12
# 2 2019-01-01  3386.54
# 3 2019-02-01  3849.75
# 4 2019-03-01  1936.75
# 5 2019-04-01  5938.08
# probabilidade_zeros :0.0
# SCORE INICIAL : 809.4545454545454
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data    valor
# 0 2018-11-01  16057.4
# 1 2018-12-01  51227.7
# 2 2019-01-01  34836.9
# 3 2019-02-01  33232.4
# 4 2019-03-01  26755.9
# 5 2019-04-01  64251.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 887.8727272727274
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data    valor
# 0 2018-11-01  2513.00
# 1 2018-12-01  7246.60
# 2 2019-01-01  4818.61
# 3 2019-02-01  3733.46
# 4 2019-03-01  4397.72
# 5 2019-04-01  8299.86
# probabilidade_zeros :0.0
# SCORE INICIAL : 866.6181818181818
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data     valor
# 0 2018-11-01
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data    valor
# 0 2018-11-01  13636.2
# 1 2018-12-01  15313.3
# 2 2019-01-01  21352.1
# 3 2019-02-01  77142.6
# 4 2019-03-01  20056.0
# 5 2019-04-01  65356.4
# probabilidade_zeros :0.0
# SCORE INICIAL : 856.5787878787878
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data    valor
# 0 2018-11-01  18265.2
# 1 2018-12-01  15026.5
# 2 2019-01-01  27686.0
# 3 2019-02-01  17062.1
# 4 2019-03-01  14142.0
# 5 2019-04-01  20620.8
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data     valor
# 0 2018-11-01  20939.90
# 1 2018-12-01  15946.80
# 2 2019-01-01  20853.10
# 3 2019-02-01  20839.40
# 4 2019-03-01  13222.80
# 5 2019-04-01   9400.01
# probabilidade_zeros :0.0
# SCORE INICIAL : 427.60942760942754
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data     valor
# 0 2018-11-01  11329.60
# 1 2018-12-01   6353.57
# 2 2019-01-01   7329.34
# 3 2019-02-01  11209.40
# 4 2019-03-01  20173.40
# 5 2019-04-01  19050.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 871.3969696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
#         data    valor
# 0 2018-11-01  20818.4
# 1 2018-12-01  36132.9
# 2 2019-01-01  25006.4
# 3 2019-02-01  15247.2
# 4 2019-03-01  15742.2
# 5 2019-04-01  29339.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 770.4787878787879
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7

# %%
dfjusta.head()
# Out:
#              cnpj     fat_medio  score  proposta_max         modelo produto  \
# 0  00150714000186   8040.163333  770.0       10000.0  PricingPadrao   Justa
# 1  00686810000143  20301.548333  779.0       25000.0  PricingPadrao   Justa
# 2  00842847000113  15490.373333  757.0       19000.0  PricingPadrao   Justa
# 3  00874646000289   4154.571667  781.0        6000.0  PricingPadrao   Justa
# 4  00934773000145  37726.873333  878.0       68000.0  PricingPadrao   Justa
#
#   data_posicao  score2      score1
# 0   2019-05-27     477  682.090909
# 1   2019-05-27     493  705.415152
# 2   2019-05-27     473  676.151515
# 3   2019-05-27     566  809.454545
# 4   2019-05-27     621  887.872727

# %%
ls = LScoring(cnpj='30420875000103', produto='justa')

# %%
ls.calcula()
# Out:
#         data     valor
# 0 2018-11-01  11028.20
# 1 2018-12-01   7451.72
# 2 2019-01-01   8899.57
# 3 2019-02-01  16106.80
# 4 2019-03-01  19263.00
# 5 2019-04-01  29671.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 931.469696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# {'score': 652}

# %%
ls.faturamentos["valor"].plot()

# %%
engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
con = engine.connect()

# %%
for el in dfjusta["cnpj"].unique().tolist():
    dt = dfjusta[dfjusta["cnpj"]==el]
    score = int(dt["score1"].iloc[0])
    con.execute("update propostas_mensais set score={} where cnpj='{}' and data_posicao='2019-05-27'".format(score, el))

# %%
dfjusta.head()
# Out:
#              cnpj     fat_medio  score  proposta_max         modelo produto  \
# 0  00150714000186   8040.163333  770.0       10000.0  PricingPadrao   Justa
# 1  00686810000143  20301.548333  779.0       25000.0  PricingPadrao   Justa
# 2  00842847000113  15490.373333  757.0       19000.0  PricingPadrao   Justa
# 3  00874646000289   4154.571667  781.0        6000.0  PricingPadrao   Justa
# 4  00934773000145  37726.873333  878.0       68000.0  PricingPadrao   Justa
#
#   data_posicao  score2      score1
# 0   2019-05-27     477  682.090909
# 1   2019-05-27     493  705.415152
# 2   2019-05-27     473  676.151515
# 3   2019-05-27     566  809.454545
# 4   2019-05-27     621  887.872727

# %%
# '''
# WIP : score de divida

# '''

# # from pricing.service.scoring.lscore import LScoring
# from sqlalchemy import create_engine
# import numpy as np
# import pandas as pd
# import requests
# from time import sleep
# from datetime import datetime
# from dateutil.relativedelta import relativedelta
# from conector.mysql import mysql_engine, CaptalysDBContext

# class DScoring(object):
#     def __init__(self, cnpj, produto):
#         self.cnpj = cnpj
#         self.doctype = 'cpf' if len(self.cnpj)<12 else 'cnpj'
#         self.produto = produto
#         self.lscore = None
#         self.baseline = 800
#         self.fator_elegibilidade = 3
#         self.faturamento_medio = None
#         self.calibracao_segmento = None
#         self.consulta = None
#         self.estados_dividas = None
#         self.dispersao_divida = None
#         self.idade_empresa = None
#         self.metricas = None
        
#     def score_mestre(self, shift=True):
#         ls = LScoring(cnpj=self.cnpj, produto=self.produto)
#         if shift:
#             _df = pd.DataFrame(ls.params)
#             datas = pd.date_range(end = (datetime.now().date() - relativedelta(months=1)).replace(day=1), periods=len(_df), freq='MS')
#             datas = [el.date() for el in datas]
#             _df['data'] = datas
#             ls.params = _df.to_dict("records")
#         lscore = ls.calcula().get('score')
#         fat_medio = ls.faturamentos['valor'].mean()
#         self.lscore = lscore
#         self.faturamento_medio = fat_medio
#         return
    
#     def set_calibracao(self):
#         delta = int(np.floor(0.8*self.lscore/4))
#         escala_score = {
#                 "credito" : delta,
#                 "processos" : 2*delta,
#                 "infra" : 3*delta,
#                 "outros" : 4*delta
#         }
#         if self.calibracao_segmento is None:
#             self.calibracao_segmento = escala_score
#         return
    
#     @property
#     def campos_divida(self):
#         return {
#                 "restricoes" : ["data_ocorrencia", "modalidade_natureza", "natureza", "valor"],
#                 "protestos" : ["data_anotacao", "natureza", "sub_judice_descricao", "valor"],
#                 "pendencias" : ["data_ocorrencia", "modalidade", "natureza", "valor"],
#                 "processos" : ["data_ocorrencia", "descricao_natureza", "natureza", "valor"],
#                 "restricoes_financeiras" : ["data_ocorrencia", "modalidade_natureza", "natureza", "valor"]
#                }
#     @property
#     def campos_rename(self):
#         return {
#                 "processos" : {"descricao_natureza" : "modalidade_natureza"},
#                 "pendencias" : {"modalidade" : "modalidade_natureza"},
#                 "protestos" : {'sub_judice_descricao' : "modalidade_natureza", "data_anotacao" : "data_ocorrencia"}
#                 }
    
#     @property
#     def segmentos(self):
#         return {"credito" : ['EMPRESCONTA', 'EMPRESTIMO', 'CREDCARTAO', 'FINANCIAMENT', 
#                              'CREDITOEFINANCIAMENTO-FINANC'],
#                 "processos" : ['EXCJUDTRAB', 'FISCALESTADUAL', 'EXECUCAO', 'FISCALFEDERAL', 
#                                'FISCALMUNICIPAL','EXECUCAO-JE', 'BUSCAEAPREENSAO'],
#                 "infra" : ['FATAGUA', 'TELEFFX', 'TELEFFIXA', 'TELEFMOVEL', 'CONDOMINIO', 
#                            'ENERGIAELET', 'ALUGUEL', 'SERVTELEFON'] 
#                }
    
#     @property
#     def escala_impacto(self):
#         return {"credito" : {"i0" : 0.75, "i1" : 1},
#                 "processos" : {"i0" : 0.5, "i1" : 0.75},
#                 "infra" : {"i0" : 0.25, "i1" : 0.5},
#                 "outros" : {"i0" : 0, "i1" : 0.25},
#                 }
    
#     def get_numero_consulta(self):
#         engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
#         con = engine.connect()
#         query = "select data_ref, numero_consulta from consultas_idwall_operacoes where cnpj_cpf='{}'".format(self.cnpj)
#         df = pd.read_sql(query, con)
#         numero = df[df['data_ref']==df['data_ref'].max()]["numero_consulta"].iloc[0]
#         con.close()
#         self.numero_consulta = numero
#         return numero
    
#     @staticmethod
#     def get_details(numero):
#         URL = "https://api-v2.idwall.co/relatorios"
#         authorization = "b3818f92-5807-4acf-ade8-78a1f6d7996b"
#         url_details = URL + "/{}".format(numero) + "/dados"
#         while True:
#             dets = requests.get(url_details, headers={"authorization": authorization})
#             djson = dets.json()
#             sleep(1)
#             if djson['result']['status'] == "CONCLUIDO":
#                 break

#         return dets.json()
    
#     @staticmethod
#     def formata_dados(df):
#         df['modalidade_natureza'] = df.apply(lambda x : x['modalidade_natureza'].replace(" ", "") if isinstance(x['modalidade_natureza'], str) else "OUTROS", axis=1)
#         df['valor'] = df.apply(lambda x : x['valor'].split("R$ ")[1].replace(",", "."), axis=1)
#         df["valor"] = df.apply(lambda x : float(x["valor"]), axis=1)
#         return df
    
#     def get_infos_dividas(self, js, tp_pendencia):
#         res = js.get("result").get(tp_pendencia)
#         if not res is None:
#             df = pd.DataFrame(res.get('itens'))
#             cols = self.campos_divida.get(tp_pendencia)
#             if "uf" in list(df.columns):
#                 cols = cols + ["uf"]
#                 df = df[cols].copy()
#             else:
#                 df = df[cols]
#                 df["uf"] = None
#             rename = self.campos_rename.get(tp_pendencia)
#             if not rename is None:
#                 df.rename(columns = rename, inplace=True)
#             df["tipo"] = tp_pendencia
#             return df
#         return None

#     def gera_dados(self):
#         numero = self.get_numero_consulta()
#         js = self.get_details(numero)
#         self.consulta = js
#         fr = []
#         lista_pendencias = ["restricoes", "processos", "protestos", "pendencias", "restricoes_financeiras"]
#         for el in lista_pendencias:
#             print(el)
#             res = self.get_infos_dividas(js, el)
#             if not res is None:
#                 fr.append(res)
#         if len(fr) == 0:
#             return None
        
#         df = pd.concat(fr)
#         df = self.formata_dados(df)
#         self.estados_dividas = df["uf"].unique().tolist()
#         return df
    
#     def calcula_dispersao_divida(self):
#         uf_cnpj = self.consulta.get("result").get("cnpj").get("localizacao").get("estado")
#         lista_dispersao = [el for el in self.estados_dividas if el!= uf_cnpj]
#         dispersao = len(lista_dispersao)/4
#         self.dispersao_divida = dispersao
#         return
    
#     def get_idade(self):
#         data_abertura = self.consulta.get("result").get("cnpj").get("data_abertura")
#         data_abertura = data_abertura.replace("/", "-")
#         data = datetime.strptime(data_abertura, "%d-%m-%Y").date()
#         idade = ((datetime.now().date() - data).days/366)
#         self.idade_empresa = np.around(idade, 2)
#         return 

    
#     def atribui_segmento(self, df):
#         df['segmento'] = df.apply(lambda x : 'processos' if x['tipo']=='processos'
#                               else('credito' if x['modalidade_natureza'] in self.segmentos.get("credito")
#                                   else ('infra' if x['modalidade_natureza'] in self.segmentos.get("infra") else "outros")), axis=1)
#         return df
    
#     @staticmethod
#     def calcula_probabilidade(df):
#         dt = df.groupby("segmento").count().reset_index()[["segmento", "valor"]]
#         dt.columns = ["segmento", "ocorrencias"]
#         dt["probabilidade"] = dt["ocorrencias"]/dt["ocorrencias"].sum()
#         return dt
    
#     @staticmethod
#     def calcula_composicao(df):
#         dt = df.groupby("segmento").sum().reset_index()
#         dt.columns = ["segmento", "valor_divida"]
#         dt["composicao"] = dt["valor_divida"]/dt["valor_divida"].sum()
#         return dt
    
#     def calcula_pi(self, dfcalc):
#         dfcalc['pi'] = dfcalc['valor_divida']/dfcalc['fat_medio']
#         dfcalc['pi'] = (1/self.fator_elegibilidade)*dfcalc['pi']
#         return dfcalc
    
#     @staticmethod
#     def calcula_lambda(dfcalc):
#         dfcalc["lambda"] = dfcalc['composicao']*dfcalc['pi']
#         return dfcalc
    
#     @staticmethod
#     def impacto_segmento(lambda_, segmento, escala):
#         escala = escala.get(segmento)
#         i0 = escala.get("i0")
#         i1 = escala.get("i1")
#         return (i1 - i0)*lambda_ + i0
    
#     def calcula_impacto_segmento(self, dfcalc):
#         dfcalc['impacto_segmento'] = dfcalc.apply(lambda x : self.impacto_segmento(x['lambda'], x["segmento"], self.escala_impacto), axis=1)
#         return dfcalc
    
#     @staticmethod
#     def calcula_risco(dfcalc):
#         dfcalc["risco"] = dfcalc["probabilidade"]*dfcalc["impacto_segmento"]
#         return dfcalc
    
#     @staticmethod
#     def d_score(risco_, score_limite):
#         return -score_limite*risco_ + score_limite


#     def calcula_dscore(self, dfcalc):
#         escala = self.calibracao_segmento
#         dfcalc["dscore"] = dfcalc.apply(lambda x : self.d_score(x["risco"], escala.get(x["segmento"])), axis=1)
#         return dfcalc
    
#     def get_metricas(self, dfcalc):
#         segmentos = ["credito", "processos", "infra", "outros"]
#         final = {}
#         for el in segmentos:
#             dt = dfcalc[dfcalc["segmento"]==el]
#             res = {}
#             if dt.empty:
#                 res["num_ocorr"] = 0
#                 res["comp"] = 0
#                 res["risco"] = 0
#                 final[el] = res
#             else:
#                 res["num_ocorr"] = dt["ocorrencias"].iloc[0]
#                 res["comp"] = dt['composicao'].iloc[0]
#                 res["risco"] = dt["risco"].iloc[0]
#                 final[el] = res
#         self.metricas = final
#         return
    
#     def update_dataset(self):
#         df_metricas = pd.DataFrame()
#         df_metricas["cnpj"] = [self.cnpj]
#         df_metricas["num_ocorr_cr"] = [self.metricas.get('credito').get('num_ocorr')]
#         df_metricas["num_ocorr_proc"] = [self.metricas.get('processos').get('num_ocorr')]
#         df_metricas["num_ocorr_infra"] =  [self.metricas.get('infra').get('num_ocorr')]
#         df_metricas["num_ocorr_out"] = [self.metricas.get('outros').get('num_ocorr')]
#         df_metricas["comp_cr"] = [self.metricas.get('credito').get('comp')]
#         df_metricas["comp_proc"] = [self.metricas.get('processos').get('comp')]
#         df_metricas["comp_infra"] = [self.metricas.get('infra').get('comp')]
#         df_metricas["comp_out"] = [self.metricas.get('outros').get('comp')]
#         df_metricas["risco_cr"] = [self.metricas.get('credito').get('risco')]
#         df_metricas["risco_proc"] = [self.metricas.get('processos').get('risco')]
#         df_metricas["risco_infra"] = [self.metricas.get('infra').get('risco')]
#         df_metricas["risco_out"] = [self.metricas.get('outros').get('risco')]
#         df_metricas["idade"] = [self.idade_empresa]
#         df_metricas["dispersao_divida"] = [self.dispersao_divida]
#         df_metricas["outlier"] = [None]
#         df_metricas["data_ref"] = datetime.now().date()
#         engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
#         con = engine.connect()
        
#         con.execute("delete from outlier_detection where cnpj='{}'".format(self.cnpj))
#         df_metricas.to_sql('outlier_detection', schema='varejo', con=con, if_exists='append', index=False)
            
#         con.close()
#         print("DATASET UPDATED!")
#         return
    
#     def calcula(self):
#         self.score_mestre()
#         self.set_calibracao()
        
#         df = self.gera_dados()
#         if df is None:
#             return {}, None
#         self.calcula_dispersao_divida()
#         self.get_idade()
#         df = self.atribui_segmento(df)
#         dfp = self.calcula_probabilidade(df)
#         dfc = self.calcula_composicao(df)
#         dfcalc = dfp.merge(dfc, left_on="segmento", right_on="segmento", how='left')

#         dfcalc['fat_medio'] = self.faturamento_medio
#         dfcalc = self.calcula_pi(dfcalc)
#         dfcalc = self.calcula_lambda(dfcalc)
#         dfcalc = self.calcula_impacto_segmento(dfcalc)
#         dfcalc = self.calcula_risco(dfcalc)
#         dfcalc = self.calcula_dscore(dfcalc)
#         self.get_metricas(dfcalc)
#         self.update_dataset()
        
#         dscore = dfcalc['dscore'].mean()
        
#         lista_segmentos = dfcalc["segmento"].tolist()
#         lista_dscore = dfcalc["dscore"].tolist()
#         lista_dscore = [int(el) for el in lista_dscore]
#         res = dict(zip(lista_segmentos, lista_dscore))
#         res["lscore"] = int(self.lscore)
#         res['dscore'] = int(dscore)
#         res['score'] = int((self.lscore + dscore)/2)
#         return res, dfcalc

# if __name__ == '__main__':
#     ds = DScoring(cnpj='26203839000110', produto = "tomatico")
#     scores,dfcalc = ds.calcula()
#     print(scores)

# %%
# from pricing.service.scoring.lscore import LScoring
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import requests
from time import sleep
from datetime import datetime
from conector.mysql import mysql_engine, CaptalysDBContext
from dateutil.relativedelta import relativedelta

class DScoring(object):
    def __init__(self, cnpj, produto, socios=False):
        self.cnpj = cnpj
        self.doctype = 'cpf' if len(self.cnpj)<12 else 'cnpj'
        self.score_socios = socios
        self.produto = produto
        self.lscore = None
        self.baseline = 800
        self.fator_elegibilidade = 3
        self.faturamento_medio = None
        self.calibracao_segmento = None
        self.consulta = None
        self.estados_dividas = None
        self.dispersao_divida = None
        self.idade_empresa = None
        self.metricas = None
        
    def score_mestre(self):
        ls = LScoring(cnpj=self.cnpj, produto=self.produto)
        
        df = pd.DataFrame(ls.params)
        periodo = len(df)

        datas = pd.date_range(end=datetime.now().date().replace(day=1) - relativedelta(months=1), periods=periodo, freq='MS')
        datas = [el.date() for el in datas]
        df['data'] = datas

        params = df.to_dict("records")
        ls.params = params
        lscore = ls.calcula().get('score')
        fat_medio = ls.faturamentos['valor'].mean()
        self.lscore = lscore
        self.faturamento_medio = fat_medio
        return
    
    def set_calibracao(self):
        delta = int(np.floor(0.8*self.lscore/4))
#         delta = int(np.floor(self.baseline/4))
        escala_score = {
                "credito" : delta,
                "processos" : 2*delta,
                "infra" : 3*delta,
                "outros" : 4*delta
        }
        if self.calibracao_segmento is None:
            self.calibracao_segmento = escala_score
        return
    
    @property
    def campos_divida(self):
        return {
                "restricoes" : ["data_ocorrencia", "modalidade_natureza", "natureza", "valor"],
                "protestos" : ["data_anotacao", "natureza", "sub_judice_descricao", "valor"],
                "pendencias" : ["data_ocorrencia", "modalidade", "natureza", "valor"],
                "processos" : ["data_ocorrencia", "descricao_natureza", "natureza", "valor"],
                "restricoes_financeiras" : ["data_ocorrencia", "modalidade_natureza", "natureza", "valor"]
               }
    @property
    def campos_rename(self):
        return {
                "processos" : {"descricao_natureza" : "modalidade_natureza"},
                "pendencias" : {"modalidade" : "modalidade_natureza"},
                "protestos" : {'sub_judice_descricao' : "modalidade_natureza", "data_anotacao" : "data_ocorrencia"}
                }
    
    @property
    def segmentos(self):
        return {"credito" : ['EMPRESCONTA', 'EMPRESTIMO', 'CREDCARTAO', 'FINANCIAMENT', 
                             'CREDITOEFINANCIAMENTO-FINANC'],
                "processos" : ['EXCJUDTRAB', 'FISCALESTADUAL', 'EXECUCAO', 'FISCALFEDERAL', 
                               'FISCALMUNICIPAL','EXECUCAO-JE', 'BUSCAEAPREENSAO'],
                "infra" : ['FATAGUA', 'TELEFFX', 'TELEFFIXA', 'TELEFMOVEL', 'CONDOMINIO', 
                           'ENERGIAELET', 'ALUGUEL', 'SERVTELEFON'] 
               }
    
    @property
    def escala_impacto(self):
        return {"credito" : {"i0" : 0.75, "i1" : 1},
                "processos" : {"i0" : 0.5, "i1" : 0.75},
                "infra" : {"i0" : 0.25, "i1" : 0.5},
                "outros" : {"i0" : 0, "i1" : 0.25},
                }
    
    @staticmethod
    def get_numero_consulta(doc):
        engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
        con = engine.connect()
        query = "select data_ref, numero_consulta from consultas_idwall_operacoes where cnpj_cpf='{}'".format(doc)
        df = pd.read_sql(query, con)
        numero = df[df['data_ref']==df['data_ref'].max()]["numero_consulta"].iloc[0]
        con.close()
#         self.numero_consulta = numero
        return numero
    
    @staticmethod
    def get_details(numero):
        URL = "https://api-v2.idwall.co/relatorios"
        authorization = "b3818f92-5807-4acf-ade8-78a1f6d7996b"
        url_details = URL + "/{}".format(numero) + "/dados"
        while True:
            dets = requests.get(url_details, headers={"authorization": authorization})
            djson = dets.json()
            sleep(1)
            if djson['result']['status'] == "CONCLUIDO":
                break

        return dets.json()
    
    @staticmethod
    def formata_dados(df):
        df['modalidade_natureza'] = df.apply(lambda x : x['modalidade_natureza'].replace(" ", "") if isinstance(x['modalidade_natureza'], str) else "OUTROS", axis=1)
        df['valor'] = df.apply(lambda x : x['valor'].split("R$ ")[1].replace(",", "."), axis=1)
        df["valor"] = df.apply(lambda x : float(x["valor"]), axis=1)
        return df
    
    def get_infos_dividas(self, js, tp_pendencia):
        res = js.get("result").get(tp_pendencia)
        if not res is None:
            df = pd.DataFrame(res.get('itens'))
            cols = self.campos_divida.get(tp_pendencia)
            if "uf" in list(df.columns):
                cols = cols + ["uf"]
                df = df[cols].copy()
            else:
                df = df[cols]
                df["uf"] = None
            rename = self.campos_rename.get(tp_pendencia)
            if not rename is None:
                df.rename(columns = rename, inplace=True)
            df["tipo"] = tp_pendencia
            return df
        return None
    
    
    def gera_dados(self, doc):
        numero = self.get_numero_consulta(doc)
        js = self.get_details(numero)
        if len(doc) > 11:
            self.consulta = js
        fr = []
        lista_pendencias = ["restricoes", "processos", "protestos", "pendencias", "restricoes_financeiras"]
        for el in lista_pendencias:
            res = self.get_infos_dividas(js, el)
            if not res is None:
                fr.append(res)
        if len(fr) == 0:
            return pd.DataFrame()
        df = pd.concat(fr)
        df = self.formata_dados(df)
        if len(doc) > 11:
            self.estados_dividas = df["uf"].unique().tolist()
        return df
    
    def calcula_dispersao_divida(self):
        uf_cnpj = self.consulta.get("result").get("cnpj").get("localizacao").get("estado")
        lista_dispersao = [el for el in self.estados_dividas if el!= uf_cnpj]
        dispersao = len(lista_dispersao)/4
        self.dispersao_divida = dispersao
        return
    
    def get_idade(self):
        data_abertura = self.consulta.get("result").get("cnpj").get("data_abertura")
        data_abertura = data_abertura.replace("/", "-")
        data = datetime.strptime(data_abertura, "%d-%m-%Y").date()
        idade = ((datetime.now().date() - data).days/366)
        self.idade_empresa = np.around(idade, 2)
        return 

    
    def atribui_segmento(self, df):
        df['segmento'] = df.apply(lambda x : 'processos' if x['tipo']=='processos'
                              else('credito' if x['modalidade_natureza'] in self.segmentos.get("credito")
                                  else ('infra' if x['modalidade_natureza'] in self.segmentos.get("infra") else "outros")), axis=1)
        return df
    
    @staticmethod
    def calcula_probabilidade(df):
        dt = df.groupby("segmento").count().reset_index()[["segmento", "valor"]]
        dt.columns = ["segmento", "ocorrencias"]
        dt["probabilidade"] = dt["ocorrencias"]/dt["ocorrencias"].sum()
        return dt
    
    @staticmethod
    def calcula_composicao(df):
        dt = df.groupby("segmento").sum().reset_index()
        dt.columns = ["segmento", "valor_divida"]
        dt["composicao"] = dt["valor_divida"]/dt["valor_divida"].sum()
        return dt
    
    
    def calcula_pi(self, dfcalc):
        dfcalc['pi'] = dfcalc['valor_divida']/dfcalc['fat_medio']
        dfcalc['pi'] = (1/self.fator_elegibilidade)*dfcalc['pi']
        return dfcalc
    
    @staticmethod
    def calcula_lambda(dfcalc):
        dfcalc["lambda"] = dfcalc['composicao']*dfcalc['pi']
        return dfcalc
    
    @staticmethod
    def impacto_segmento(lambda_, segmento, escala):
        escala = escala.get(segmento)
        i0 = escala.get("i0")
        i1 = escala.get("i1")
        return (i1 - i0)*lambda_ + i0
    
    def calcula_impacto_segmento(self, dfcalc):
        dfcalc['impacto_segmento'] = dfcalc.apply(lambda x : self.impacto_segmento(x['lambda'], x["segmento"], self.escala_impacto), axis=1)
        return dfcalc
    
    @staticmethod
    def calcula_risco(dfcalc):
        dfcalc["risco"] = dfcalc["probabilidade"]*dfcalc["impacto_segmento"]
        return dfcalc
    
    @staticmethod
    def d_score(risco_, score_limite):
        return -score_limite*risco_ + score_limite


    def calcula_dscore(self, dfcalc):
        escala = self.calibracao_segmento
        score_limite = 0.8*self.lscore
#         dfcalc["dscore"] = dfcalc.apply(lambda x : self.d_score(x["risco"], escala.get(x["segmento"])) if x["pi"] <=1 else 0, axis=1)
        dfcalc["dscore"] = dfcalc.apply(lambda x : self.d_score(x["risco"], score_limite) if x["pi"] <=1 else 0, axis=1)
        return dfcalc
    
    def get_metricas(self, dfcalc):
        segmentos = ["credito", "processos", "infra", "outros"]
        final = {}
        for el in segmentos:
            dt = dfcalc[dfcalc["segmento"]==el]
            res = {}
            if dt.empty:
                res["num_ocorr"] = 0
                res["comp"] = 0
                res["risco"] = 0
                final[el] = res
            else:
                res["num_ocorr"] = dt["ocorrencias"].iloc[0]
                res["comp"] = dt['composicao'].iloc[0]
                res["risco"] = dt["risco"].iloc[0]
                final[el] = res
        self.metricas = final
        return
    
    def update_dataset(self):
        df_metricas = pd.DataFrame()
        df_metricas["cnpj"] = [self.cnpj]
        df_metricas["num_ocorr_cr"] = [self.metricas.get('credito').get('num_ocorr')]
        df_metricas["num_ocorr_proc"] = [self.metricas.get('processos').get('num_ocorr')]
        df_metricas["num_ocorr_infra"] =  [self.metricas.get('infra').get('num_ocorr')]
        df_metricas["num_ocorr_out"] = [self.metricas.get('outros').get('num_ocorr')]
        df_metricas["comp_cr"] = [self.metricas.get('credito').get('comp')]
        df_metricas["comp_proc"] = [self.metricas.get('processos').get('comp')]
        df_metricas["comp_infra"] = [self.metricas.get('infra').get('comp')]
        df_metricas["comp_out"] = [self.metricas.get('outros').get('comp')]
        df_metricas["risco_cr"] = [self.metricas.get('credito').get('risco')]
        df_metricas["risco_proc"] = [self.metricas.get('processos').get('risco')]
        df_metricas["risco_infra"] = [self.metricas.get('infra').get('risco')]
        df_metricas["risco_out"] = [self.metricas.get('outros').get('risco')]
        df_metricas["idade"] = [self.idade_empresa]
        df_metricas["dispersao_divida"] = [self.dispersao_divida]
        df_metricas["outlier"] = [None]
        df_metricas["data_ref"] = [datetime.now().date()]
        
        engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
        con = engine.connect()
        
        con.execute("delete from outlier_detection where cnpj='{}'".format(self.cnpj))
        df_metricas.to_sql('outlier_detection', schema='varejo', con=con, if_exists='append', index=False)
            
        con.close()
        
        return
    
    def get_socios(self):
        schema = 'credito-digital' if self.produto != 'moip' else self.produto
        engine = mysql_engine(schema)
        query = "select cpf from tb_Socio where cnpj='{}'".format(self.cnpj)
        with CaptalysDBContext(engine) as db:
            res = db.session.execute(query).fetchall()

        lista_socios = [el[0] for el in res]
        self.lista_socios = lista_socios
        return lista_socios
    
    def calcula_socios(self):
        lista_socios = self.get_socios()
        resp = []
        for el in lista_socios:
            _df = self.gera_dados(el)
            if not _df.empty:
                resp.append(_df)
        if len(resp) == 0:
            return np.nan
        
        df = pd.concat(resp)
        df = self.atribui_segmento(df)
        dfp = self.calcula_probabilidade(df)
        dfc = self.calcula_composicao(df)
        dfcalc = dfp.merge(dfc, left_on="segmento", right_on="segmento", how='left')
        dfcalc['fat_medio'] = self.faturamento_medio
        dfcalc = self.calcula_pi(dfcalc)
        dfcalc = self.calcula_lambda(dfcalc)
        dfcalc = self.calcula_impacto_segmento(dfcalc)
        dfcalc = self.calcula_risco(dfcalc)
        dfcalc = self.calcula_dscore(dfcalc)
        self.get_metricas(dfcalc)
        dscore = dfcalc['dscore'].mean()
        
        lista_segmentos = dfcalc["segmento"].tolist()
        lista_dscore = dfcalc["dscore"].tolist()
        lista_dscore = [int(el) for el in lista_dscore]
        res = dict(zip(lista_segmentos, lista_dscore))
        res["lscore"] = int(self.lscore)
        res['dscore'] = int(dscore)
        res['score'] = int((self.lscore + dscore)/2)
        return res, dfcalc
    
            
    def calcula(self):
        self.score_mestre()
        
        self.set_calibracao()
        doc = self.cnpj
        df = self.gera_dados(doc)
        if df.empty:
            return {}, None
        self.calcula_dispersao_divida()
        self.get_idade()
        df = self.atribui_segmento(df)
        dfp = self.calcula_probabilidade(df)
        dfc = self.calcula_composicao(df)
        dfcalc = dfp.merge(dfc, left_on="segmento", right_on="segmento", how='left')

        dfcalc['fat_medio'] = self.faturamento_medio
        dfcalc = self.calcula_pi(dfcalc)
        dfcalc = self.calcula_lambda(dfcalc)
        dfcalc = self.calcula_impacto_segmento(dfcalc)
        dfcalc = self.calcula_risco(dfcalc)
        dfcalc = self.calcula_dscore(dfcalc)
        self.get_metricas(dfcalc)
        self.update_dataset()
        
        dscore = dfcalc['dscore'].mean()
        
        lista_segmentos = dfcalc["segmento"].tolist()
        lista_dscore = dfcalc["dscore"].tolist()
        lista_dscore = [int(el) for el in lista_dscore]
        res = dict(zip(lista_segmentos, lista_dscore))
        res["lscore"] = int(self.lscore)
        res['dscore'] = int(dscore)
        res['score'] = int((self.lscore + dscore)/2)
        return res, dfcalc

# %%
fr = []
sem_divida = []
err = []
for el in dfjusta['cnpj'].unique().tolist():
    try:
        ds = DScoring(cnpj=el, produto='justa')
        _df = ds.gera_dados(el)
        if not _df.empty:
            _df['cnpj'] = el
            fr.append(_df)
        else:
            sem_divida.append(el)
    except:
        err.append(el)

# %%
sem_divida.__len__()
# Out:
# 114

# %%
err.__len__()
# Out:
# 2

# %%
df_dividas = pd.concat(fr)

# %%
df_dividas.head()
# Out:
#              cnpj data_ocorrencia modalidade_natureza  \
# 0  00842847000113      28/04/2017         SERVTELEFON
# 1  00842847000113      24/04/2017         SERVTELEFON
# 0  00842847000113      20/12/2018         EMPRESCONTA
# 1  00842847000113      20/11/2018         EMPRESCONTA
# 2  00842847000113      02/11/2018         ADIANTCONTA
#
#                                             natureza                    tipo  \
# 0                  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO              pendencias
# 1                  CÓDIGO DE ANOTAÇÃO NÃO ENCONTRADO              pendencias
# 0  Empréstimos em contas - c/c garantidas, financ...  restricoes_financeiras
# 1  Empréstimos em contas - c/c garantidas, financ...  restricoes_financeiras
# 2  Adiantamento a depositantes - c/c devedores em...  restricoes_financeiras
#
#      uf    valor
# 0  None   149.58
# 1  None   138.73
# 0        1369.77
# 1        1369.77
# 2        7500.00

# %%
resp = []
fr = []
err = []
for el in dfjusta["cnpj"].unique().tolist():
    print(el)
    try:
        ds = DScoring(cnpj=el, produto='justa')
        scores, dfcalc = ds.calcula()
        resp.append({el : scores})
        dfcalc["cnpj"] = el
        fr.append(dfcalc)
    except:
        err.append(el)
# Out:
# 00150714000186
#         data     valor
# 0 2018-12-01   3995.38
# 1 2019-01-01   4311.87
# 2 2019-02-01   9195.56
# 3 2019-03-01  11127.60
# 4 2019-04-01  12082.30
# 5 2019-05-01   7528.29
# probabilidade_zeros :0.0
# SCORE INICIAL : 682.0909090909091
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 00686810000143
#         data    valor
# 0 2018-12-01  17046.6
# 1 2019-01-01  28100.6
# 2 2019-02-01  23499.0
# 3 2019-03-01  18850.0
# 4 2019-04-01  15413.2
# 5 2019-05-01  18899.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 705.4151515151516
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 00842847000113
#         data    valor
# 0 2018-12-01  15039.2
# 1 2019-01-01  15871.7
# 2 2019-02-01  15352.9
# 3 2019-03-01  17385.3
# 4 2019-04-01  17599.8
# 5 2019-05-01  11693.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 676.1515151515152
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 00874646000289
#         data    valor
# 0 2018-12-01  7064.19
# 1 2019-01-01  2752.12
# 2 2019-02-01  3386.54
# 3 2019-03-01  3849.75
# 4 2019-04-01  1936.75
# 5 2019-05-01  5938.08
# probabilidade_zeros :0.0
# SCORE INICIAL : 809.4545454545454
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 00934773000145
#         data    valor
# 0 2018-12-01  16057.4
# 1 2019-01-01  51227.7
# 2 2019-02-01  34836.9
# 3 2019-03-01  33232.4
# 4 2019-04-01  26755.9
# 5 2019-05-01  64251.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 887.8727272727274
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 01147087000197
#         data    valor
# 0 2018-12-01  2513.00
# 1 2019-01-01  7246.60
# 2 2019-02-01  4818.61
# 3 2019-03-01  3733.46
# 4 2019-04-01  4397.72
# 5 2019-05-01  8299.86
# probabilidade_zeros :0.0
# SCORE INICIAL : 866.6181818181818
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 01242387000155
#         data     valor
# 0 2018-12-01   6800.82
# 1 2019-01-01  27024.30
# 2 2019-02-01  14727.50
# 3 2019-03-01  10245.60
# 4 2019-04-01  31876.50
# 5 2019-05-01  28434.70
# probabilidade_zeros :0.0
# SCORE INICIAL : 856.0484848484848
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 01246934000170
#         data     valor
# 0 2018-12-01    253.52
# 1 2019-01-01   7720.57
# 2 2019-02-01  27407.00
# 3 2019-03-01  25582.40
# 4 2019-04-01  32220.20
# 5 2019-05-01  37672.90
# probabilidade_zeros :0.0
# SCORE INICIAL : 853.939393939394
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 01368548000151
#         data     valor
# 0 2018-12-01  14072.30
# 1 2019-01-01   4690.91
# 2 2019-02-01   9496.40
# 3 2019-03-01   4531.23
# 4 2019-04-01   3843.55
# 5 2019-05-01  29575.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 883.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 01698637000166
#         data     valor
# 0 2018-12-01   78300.6
# 1 2019-01-01  152685.0
# 2 2019-02-01   49690.2
# 3 2019-03-01   51065.2
# 4 2019-04-01   61952.6
# 5 2019-05-01   42298.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 419.04713804713805
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 01698637000328
#         data    valor
# 0 2018-12-01  38085.8
# 1 2019-01-01  78370.0
# 2 2019-02-01  26429.8
# 3 2019-03-01  42485.8
# 4 2019-04-01  29908.6
# 5 2019-05-01  24395.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 478.8518518518519
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 01760044000182
#         data     valor
# 0 2018-12-01   2751.15
# 1 2019-01-01  16515.10
# 2 2019-02-01   5899.02
# 3 2019-03-01  47292.10
# 4 2019-04-01  27005.90
# 5 2019-05-01  50340.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 898.6666666666666
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02125400000159
#         data    valor
# 0 2018-12-01  31873.7
# 1 2019-01-01  14099.4
# 2 2019-02-01  36872.4
# 3 2019-03-01  28995.7
# 4 2019-04-01  23873.2
# 5 2019-05-01  38987.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 809.1757575757575
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02407917000130
#         data    valor
# 0 2018-12-01  12048.2
# 1 2019-01-01  10684.9
# 2 2019-02-01  13817.5
# 3 2019-03-01  16632.7
# 4 2019-04-01  19339.1
# 5 2019-05-01  15703.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 727.9515151515152
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02801654000220
#         data     valor
# 0 2018-12-01  10430.00
# 1 2019-01-01   5670.52
# 2 2019-02-01  10901.00
# 3 2019-03-01  11893.80
# 4 2019-04-01  11824.00
# 5 2019-05-01  11873.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 823.9484848484848
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02802892000170
#         data     valor
# 0 2018-12-01   7589.99
# 1 2019-01-01   6944.44
# 2 2019-02-01   5772.95
# 3 2019-03-01  12005.80
# 4 2019-04-01  13817.90
# 5 2019-05-01  16967.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 868.969696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 03300735000129
#         data     valor
# 0 2018-12-01  13108.60
# 1 2019-01-01  14258.00
# 2 2019-02-01  22824.00
# 3 2019-03-01  20834.60
# 4 2019-04-01   9954.06
# 5 2019-05-01  26990.70
# probabilidade_zeros :0.0
# SCORE INICIAL : 851.6454545454544
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04293170000162
#         data     valor
# 0 2018-12-01   87371.5
# 1 2019-01-01  162864.0
# 2 2019-02-01   81023.0
# 3 2019-03-01   97462.2
# 4 2019-04-01  103626.0
# 5 2019-05-01  101782.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 710.7969696969698
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04474793000131
#         data     valor
# 0 2018-12-01   86725.1
# 1 2019-01-01  117787.0
# 2 2019-02-01   83341.4
# 3 2019-03-01   61009.1
# 4 2019-04-01   63278.5
# 5 2019-05-01   84204.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 719.878787878788
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04608458000189
#         data    valor
# 0 2018-12-01  26880.6
# 1 2019-01-01  56212.3
# 2 2019-02-01  57116.8
# 3 2019-03-01  37797.3
# 4 2019-04-01  78617.5
# 5 2019-05-01  66646.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 823.030303030303
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04943517000175
#         data     valor
# 0 2018-12-01   7035.65
# 1 2019-01-01   8292.30
# 2 2019-02-01  12711.00
# 3 2019-03-01   7682.81
# 4 2019-04-01   8778.21
# 5 2019-05-01   5224.73
# probabilidade_zeros :0.0
# SCORE INICIAL : 550.171717171717
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05074012000184
#         data      valor
# 0 2018-12-01       0.06
# 1 2019-01-01  218279.00
# 2 2019-02-01   29946.30
# 3 2019-03-01   26716.50
# 4 2019-04-01   32086.30
# 5 2019-05-01   45117.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 471.1727272727273
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05093466000100
#         data    valor
# 0 2018-12-01  16574.8
# 1 2019-01-01  11231.4
# 2 2019-02-01  13471.4
# 3 2019-03-01  11607.0
# 4 2019-04-01  14060.9
# 5 2019-05-01  20959.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 843.121212121212
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05115981000136
#         data     valor
# 0 2018-12-01   3301.85
# 1 2019-01-01  18841.90
# 2 2019-02-01   7111.67
# 3 2019-03-01   5303.83
# 4 2019-04-01   6459.27
# 5 2019-05-01  14457.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 808.8363636363637
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05336959000116
#         data    valor
# 0 2018-12-01  25973.4
# 1 2019-01-01  40821.2
# 2 2019-02-01  22432.1
# 3 2019-03-01  19780.5
# 4 2019-04-01  23515.4
# 5 2019-05-01  26933.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 719.2060606060608
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05583640000195
#         data     valor
# 0 2018-12-01  20696.60
# 1 2019-01-01  12057.40
# 2 2019-02-01   9491.89
# 3 2019-03-01  13067.50
# 4 2019-04-01  16180.50
# 5 2019-05-01  14555.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 729.969696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05634767000358
#         data    valor
# 0 2018-12-01  56483.6
# 1 2019-01-01  89081.6
# 2 2019-02-01  37709.6
# 3 2019-03-01  14374.7
# 4 2019-04-01  43590.6
# 5 2019-05-01  29673.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 542.959595959596
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05766218000175
#         data    valor
# 0 2018-12-01  4106.04
# 1 2019-01-01  5137.21
# 2 2019-02-01  2965.32
# 3 2019-03-01  3471.32
# 4 2019-04-01  2260.01
# 5 2019-05-01  9407.86
# probabilidade_zeros :0.0
# SCORE INICIAL : 948.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05891070000109
#         data    valor
# 0 2018-12-01  21246.4
# 1 2019-01-01  36609.5
# 2 2019-02-01  37633.5
# 3 2019-03-01  25881.3
# 4 2019-04-01  27553.4
# 5 2019-05-01  32092.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 842.4484848484849
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 06096281000104
#         data     valor
# 0 2018-12-01  12957.70
# 1 2019-01-01   9730.81
# 2 2019-02-01  15963.80
# 3 2019-03-01  18724.50
# 4 2019-04-01  14586.00
# 5 2019-05-01  41216.90
# probabilidade_zeros :0.0
# SCORE INICIAL : 940.6666666666666
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 06213352000101
#         data    valor
# 0 2018-12-01  31632.9
# 1 2019-01-01  14435.4
# 2 2019-02-01  32660.6
# 3 2019-03-01  14822.0
# 4 2019-04-01  21713.2
# 5 2019-05-01  23934.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 713.8969696969698
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07176964000134
#         data    valor
# 0 2018-12-01  9395.79
# 1 2019-01-01  2537.83
# 2 2019-02-01  3956.72
# 3 2019-03-01  3857.69
# 4 2019-04-01  2410.92
# 5 2019-05-01  4598.17
# probabilidade_zeros :0.0
# SCORE INICIAL : 667.8969696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07406557000176
#         data    valor
# 0 2018-12-01  16148.0
# 1 2019-01-01  19888.3
# 2 2019-02-01  17926.8
# 3 2019-03-01  20778.0
# 4 2019-04-01  17371.7
# 5 2019-05-01  26245.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 809.4848484848485
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07449710000142
#         data     valor
# 0 2018-12-01   4334.67
# 1 2019-01-01  13087.30
# 2 2019-02-01  42768.00
# 3 2019-03-01  28491.30
# 4 2019-04-01  39592.30
# 5 2019-05-01  44588.60
# probabilidade_zeros :0.0
# SCORE INICIAL : 818.1272727272727
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07513220000168
#         data     valor
# 0 2018-12-01    186.80
# 1 2019-01-01   2994.89
# 2 2019-02-01   3344.30
# 3 2019-03-01   8937.61
# 4 2019-04-01   8614.95
# 5 2019-05-01  13706.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 903.6666666666666
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07874345000113
#         data     valor
# 0 2018-12-01  11709.60
# 1 2019-01-01  18884.40
# 2 2019-02-01  12726.30
# 3 2019-03-01   6099.03
# 4 2019-04-01  11137.60
# 5 2019-05-01  11814.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 705.8212121212122
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07942208000179
#         data     valor
# 0 2018-12-01   6291.18
# 1 2019-01-01   7366.48
# 2 2019-02-01   9967.77
# 3 2019-03-01   5840.88
# 4 2019-04-01  10813.90
# 5 2019-05-01  17004.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 909.7606060606062
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 08312804000138
#         data    valor
# 0 2018-12-01  6589.04
# 1 2019-01-01  5958.25
# 2 2019-02-01  3532.15
# 3 2019-03-01  4445.33
# 4 2019-04-01  6279.50
# 5 2019-05-01  7191.94
# probabilidade_zeros :0.0
# SCORE INICIAL : 798.4525252525253
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 08601921000111
#         data     valor
# 0 2018-12-01   73117.2
# 1 2019-01-01  112919.0
# 2 2019-02-01   38020.4
# 3 2019-03-01   40724.9
# 4 2019-04-01   52679.5
# 5 2019-05-01   41272.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 612.5453198653199
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 08656814000190
#         data    valor
# 0 2018-12-01  5943.71
# 1 2019-01-01  4695.12
# 2 2019-02-01  5198.58
# 3 2019-03-01  5913.69
# 4 2019-04-01  7046.96
# 5 2019-05-01  9226.16
# probabilidade_zeros :0.0
# SCORE INICIAL : 851.8666666666668
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 08744783000120
#         data     valor
# 0 2018-12-01      2.65
# 1 2019-01-01  10943.50
# 2 2019-02-01   4696.72
# 3 2019-03-01  19386.30
# 4 2019-04-01  11505.30
# 5 2019-05-01  38932.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 869.3333333333334
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 08792506000192
#         data    valor
# 0 2018-12-01  24561.2
# 1 2019-01-01  22533.6
# 2 2019-02-01  16023.0
# 3 2019-03-01  11188.3
# 4 2019-04-01  13128.7
# 5 2019-05-01  11941.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 667.1484848484849
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 08982475000213
#         data     valor
# 0 2018-12-01   9223.43
# 1 2019-01-01  20021.70
# 2 2019-02-01  11041.00
# 3 2019-03-01   9208.51
# 4 2019-04-01  12062.10
# 5 2019-05-01   9480.69
# probabilidade_zeros :0.0
# SCORE INICIAL : 673.5545454545455
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 08992524000118
#         data     valor
# 0 2018-12-01  219002.0
# 1 2019-01-01  356404.0
# 2 2019-02-01   51249.1
# 3 2019-03-01  201143.0
# 4 2019-04-01   72730.5
# 5 2019-05-01  299346.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 803.9727272727273
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 08993567000118
#         data    valor
# 0 2018-12-01  4989.81
# 1 2019-01-01  3450.24
# 2 2019-02-01  6679.35
# 3 2019-03-01  5306.71
# 4 2019-04-01  2000.65
# 5 2019-05-01  3012.11
# probabilidade_zeros :0.0
# SCORE INICIAL : 646.1159595959597
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 09165878000151
#         data     valor
# 0 2018-12-01   6892.98
# 1 2019-01-01   7909.90
# 2 2019-02-01  10196.00
# 3 2019-03-01   8956.09
# 4 2019-04-01   7140.10
# 5 2019-05-01  12164.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 822.939393939394
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 09214739000170
#         data    valor
# 0 2018-12-01  29605.9
# 1 2019-01-01  20133.1
# 2 2019-02-01  33955.6
# 3 2019-03-01  26053.6
# 4 2019-04-01  62540.3
# 5 2019-05-01  41370.4
# probabilidade_zeros :0.0
# SCORE INICIAL : 729.5818181818182
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 09434547000170
#         data    valor
# 0 2018-12-01  24732.2
# 1 2019-01-01  10529.6
# 2 2019-02-01  19515.7
# 3 2019-03-01  15643.3
# 4 2019-04-01  19965.2
# 5 2019-05-01  20910.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 818.2303030303032
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 10258160000199
#         data     valor
# 0 2018-12-01   7273.06
# 1 2019-01-01  24353.80
# 2 2019-02-01   4622.03
# 3 2019-03-01  36239.70
# 4 2019-04-01   6401.55
# 5 2019-05-01  17844.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 642.2247086247086
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 10277108000180
#         data    valor
# 0 2018-12-01   2017.3
# 1 2019-01-01  10127.1
# 2 2019-02-01  18971.5
# 3 2019-03-01  13312.1
# 4 2019-04-01  13773.6
# 5 2019-05-01  17206.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 894.9727272727273
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 10380621000100
#         data    valor
# 0 2018-12-01   9509.7
# 1 2019-01-01  31777.8
# 2 2019-02-01  11172.5
# 3 2019-03-01  11927.0
# 4 2019-04-01  12169.6
# 5 2019-05-01  14183.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 657.4242424242425
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 10690679000141
#         data     valor
# 0 2018-12-01   65349.9
# 1 2019-01-01  129542.0
# 2 2019-02-01   89692.3
# 3 2019-03-01   58225.7
# 4 2019-04-01   73163.4
# 5 2019-05-01   56626.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 660.0969696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 10714656000120
#         data    valor
# 0 2018-12-01  19092.2
# 1 2019-01-01  21490.0
# 2 2019-02-01  21127.0
# 3 2019-03-01  32471.2
# 4 2019-04-01  46558.2
# 5 2019-05-01  44522.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 850.090909090909
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 10819214000148
#         data    valor
# 0 2018-12-01  36109.8
# 1 2019-01-01  53010.0
# 2 2019-02-01  19129.1
# 3 2019-03-01  16465.6
# 4 2019-04-01  17533.8
# 5 2019-05-01  22049.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 639.5606060606061
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 10819466000177
#         data     valor
# 0 2018-12-01   8276.07
# 1 2019-01-01  37801.20
# 2 2019-02-01  31991.00
# 3 2019-03-01  12140.50
# 4 2019-04-01  13796.80
# 5 2019-05-01  21791.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 671.5757575757575
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 10946187000174
#         data     valor
# 0 2018-12-01   9913.47
# 1 2019-01-01   9955.49
# 2 2019-02-01  10665.20
# 3 2019-03-01  19789.80
# 4 2019-04-01  18402.50
# 5 2019-05-01  13712.60
# probabilidade_zeros :0.0
# SCORE INICIAL : 712.5151515151514
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11014236000101
#         data    valor
# 0 2018-12-01  43220.7
# 1 2019-01-01  55345.2
# 2 2019-02-01  62840.4
# 3 2019-03-01  57609.1
# 4 2019-04-01  50374.5
# 5 2019-05-01  41359.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 716.8515151515152
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11018748001703
#         data    valor
# 0 2018-12-01  60298.0
# 1 2019-01-01  52105.7
# 2 2019-02-01  27402.7
# 3 2019-03-01  52225.8
# 4 2019-04-01  47665.6
# 5 2019-05-01  33454.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 672.7878787878786
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11018748002009
#         data    valor
# 0 2018-12-01  31773.4
# 1 2019-01-01  57818.4
# 2 2019-02-01  17815.3
# 3 2019-03-01  15586.2
# 4 2019-04-01  18567.4
# 5 2019-05-01  15963.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 448.1346801346802
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11020761000121
#         data    valor
# 0 2018-12-01  20039.4
# 1 2019-01-01  56006.2
# 2 2019-02-01  46420.1
# 3 2019-03-01  35630.7
# 4 2019-04-01  40461.4
# 5 2019-05-01  49448.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 940.4727272727272
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11029156000200
#         data     valor
# 0 2018-12-01   32867.5
# 1 2019-01-01  123930.0
# 2 2019-02-01   86127.2
# 3 2019-03-01   31661.8
# 4 2019-04-01   59830.4
# 5 2019-05-01   78160.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 703.1696969696969
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11226953000270
#         data    valor
# 0 2018-12-01  10969.8
# 1 2019-01-01  18531.4
# 2 2019-02-01  14469.3
# 3 2019-03-01  10238.4
# 4 2019-04-01  21663.6
# 5 2019-05-01  14514.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 710.7969696969698
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11240411000170
#         data    valor
# 0 2018-12-01  23731.9
# 1 2019-01-01  60902.1
# 2 2019-02-01  24486.8
# 3 2019-03-01  29127.0
# 4 2019-04-01  20367.1
# 5 2019-05-01  29563.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 672.7636363636365
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11253353000110
#         data     valor
# 0 2018-12-01  10262.80
# 1 2019-01-01   9216.32
# 2 2019-02-01  11418.40
# 3 2019-03-01   8360.54
# 4 2019-04-01  12753.30
# 5 2019-05-01  14398.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 813.5212121212122
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11260310000676
#         data    valor
# 0 2018-12-01     0.10
# 1 2019-01-01  7831.23
# 2 2019-02-01  9483.75
# 3 2019-03-01  3980.93
# 4 2019-04-01  6721.78
# 5 2019-05-01  5168.71
# probabilidade_zeros :0.0
# SCORE INICIAL : 646.4181818181819
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11340751000173
#         data    valor
# 0 2018-12-01  5499.18
# 1 2019-01-01  6109.28
# 2 2019-02-01  4824.20
# 3 2019-03-01  3094.92
# 4 2019-04-01  5476.43
# 5 2019-05-01  3468.74
# probabilidade_zeros :0.0
# SCORE INICIAL : 672.1151515151514
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11485379000193
#         data     valor
# 0 2018-12-01  25343.90
# 1 2019-01-01  11324.00
# 2 2019-02-01  10428.70
# 3 2019-03-01   6940.62
# 4 2019-04-01    511.66
# 5 2019-05-01  13134.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 670.2545454545456
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11903993000128
#         data    valor
# 0 2018-12-01  16445.8
# 1 2019-01-01  21015.1
# 2 2019-02-01  15059.9
# 3 2019-03-01  26940.1
# 4 2019-04-01  37386.6
# 5 2019-05-01  20029.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 684.3363636363637
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 11978779000130
#         data     valor
# 0 2018-12-01  15122.20
# 1 2019-01-01  14357.20
# 2 2019-02-01  12808.40
# 3 2019-03-01   9938.71
# 4 2019-04-01  10198.40
# 5 2019-05-01   6655.22
# probabilidade_zeros :0.0
# SCORE INICIAL : 464.64646464646466
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 12158043000189
#         data    valor
# 0 2018-12-01  66627.1
# 1 2019-01-01  57059.9
# 2 2019-02-01  50941.9
# 3 2019-03-01  53953.6
# 4 2019-04-01  48999.6
# 5 2019-05-01  65711.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 748.8727272727273
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 12337841000178
#         data     valor
# 0 2018-12-01  15379.60
# 1 2019-01-01   9509.79
# 2 2019-02-01  14869.20
# 3 2019-03-01  14864.10
# 4 2019-04-01  14934.10
# 5 2019-05-01  12863.20
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 12359129000170
#         data    valor
# 0 2018-12-01  19768.6
# 1 2019-01-01  17841.7
# 2 2019-02-01  10367.2
# 3 2019-03-01  17816.7
# 4 2019-04-01  20919.5
# 5 2019-05-01  16153.0
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 12401497000139
#         data     valor
# 0 2018-12-01   7192.65
# 1 2019-01-01   9111.36
# 2 2019-02-01   8990.66
# 3 2019-03-01   7265.81
# 4 2019-04-01   6027.81
# 5 2019-05-01  12263.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 848.5030303030303
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 12436421000149
#         data     valor
# 0 2018-12-01      0.98
# 1 2019-01-01   1541.11
# 2 2019-02-01   8251.36
# 3 2019-03-01  10247.50
# 4 2019-04-01   5500.00
# 5 2019-05-01   6541.93
# probabilidade_zeros :0.0
# SCORE INICIAL : 689.4363636363636
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 13005501000102
#         data     valor
# 0 2018-12-01  15430.10
# 1 2019-01-01  10542.40
# 2 2019-02-01  10467.30
# 3 2019-03-01   3057.53
# 4 2019-04-01  10955.20
# 5 2019-05-01  16083.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 825.848484848485
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 13703589000136
#         data    valor
# 0 2018-12-01  26933.3
# 1 2019-01-01  38314.6
# 2 2019-02-01  21187.7
# 3 2019-03-01  20501.5
# 4 2019-04-01  18931.3
# 5 2019-05-01  22928.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 704.4060606060607
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 13751075000156
#         data     valor
# 0 2018-12-01  14508.00
# 1 2019-01-01  11856.20
# 2 2019-02-01  16251.50
# 3 2019-03-01  11152.00
# 4 2019-04-01   8821.53
# 5 2019-05-01  17952.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 811.839393939394
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 13962219000113
#         data    valor
# 0 2018-12-01  56797.4
# 1 2019-01-01  44703.9
# 2 2019-02-01  64204.7
# 3 2019-03-01  39737.2
# 4 2019-04-01  45605.0
# 5 2019-05-01  43704.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 698.3515151515152
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 14136967000100
#         data     valor
# 0 2018-12-01   9532.67
# 1 2019-01-01  11066.80
# 2 2019-02-01   5551.64
# 3 2019-03-01   5330.99
# 4 2019-04-01   6978.88
# 5 2019-05-01   6392.77
# probabilidade_zeros :0.0
# SCORE INICIAL : 699.0424242424242
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 14219934000123
#         data    valor
# 0 2018-12-01  20663.4
# 1 2019-01-01  23126.8
# 2 2019-02-01  15306.9
# 3 2019-03-01  13731.5
# 4 2019-04-01  16730.0
# 5 2019-05-01  17219.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 715.1696969696969
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 14549293000175
#         data     valor
# 0 2018-12-01    954.97
# 1 2019-01-01  18930.40
# 2 2019-02-01  10231.50
# 3 2019-03-01  13605.50
# 4 2019-04-01  14625.60
# 5 2019-05-01  18569.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 806.1757575757575
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 14760070000152
#         data     valor
# 0 2018-12-01  16359.80
# 1 2019-01-01  10652.10
# 2 2019-02-01   5347.84
# 3 2019-03-01   7959.47
# 4 2019-04-01   7937.95
# 5 2019-05-01   7672.60
# probabilidade_zeros :0.0
# SCORE INICIAL : 681.7333333333333
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 15521792000117
#         data     valor
# 0 2018-12-01  19009.10
# 1 2019-01-01  24405.50
# 2 2019-02-01  25034.10
# 3 2019-03-01  12411.40
# 4 2019-04-01   6552.55
# 5 2019-05-01  22463.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 754.7757575757574
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 16098066000104
#         data     valor
# 0 2018-12-01   6582.73
# 1 2019-01-01   4263.77
# 2 2019-02-01   6011.87
# 3 2019-03-01   6740.79
# 4 2019-04-01   6410.61
# 5 2019-05-01  12263.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 913.3030303030304
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 16590208000148
#         data     valor
# 0 2018-12-01  20193.30
# 1 2019-01-01  16752.60
# 2 2019-02-01   9925.38
# 3 2019-03-01  10603.00
# 4 2019-04-01   9707.37
# 5 2019-05-01  15726.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 742.1757575757575
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 16950630000167
#         data    valor
# 0 2018-12-01  5414.00
# 1 2019-01-01  5998.79
# 2 2019-02-01  2843.58
# 3 2019-03-01  1994.32
# 4 2019-04-01  6385.77
# 5 2019-05-01  3489.99
# probabilidade_zeros :0.0
# SCORE INICIAL : 660.5545454545455
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 16972970000199
#         data    valor
# 0 2018-12-01  21881.9
# 1 2019-01-01  18067.7
# 2 2019-02-01  19121.1
# 3 2019-03-01  17139.2
# 4 2019-04-01  14249.3
# 5 2019-05-01  17709.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 713.8242424242426
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 17096779000193
#         data     valor
# 0 2018-12-01   2926.16
# 1 2019-01-01   8260.26
# 2 2019-02-01  18515.10
# 3 2019-03-01  13032.30
# 4 2019-04-01  16021.40
# 5 2019-05-01  10292.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 662.3606060606061
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 17267491000134
#         data    valor
# 0 2018-12-01  1624.75
# 1 2019-01-01  6746.91
# 2 2019-02-01  4149.04
# 3 2019-03-01  4162.27
# 4 2019-04-01  5953.91
# 5 2019-05-01  4232.14
# probabilidade_zeros :0.0
# SCORE INICIAL : 688.7696969696968
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 17322294000170
#         data    valor
# 0 2018-12-01  32150.8
# 1 2019-01-01  31285.2
# 2 2019-02-01  34189.3
# 3 2019-03-01  27109.8
# 4 2019-04-01  27164.1
# 5 2019-05-01  21119.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 672.4515151515151
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 17359266000128
#         data    valor
# 0 2018-12-01  41517.1
# 1 2019-01-01  26381.7
# 2 2019-02-01  44667.7
# 3 2019-03-01  45458.1
# 4 2019-04-01  36364.1
# 5 2019-05-01  44733.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 816.8848484848485
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 17521459000133
#         data    valor
# 0 2018-12-01  22338.3
# 1 2019-01-01  14207.7
# 2 2019-02-01  16693.5
# 3 2019-03-01  10115.2
# 4 2019-04-01  15749.3
# 5 2019-05-01  10950.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 672.1151515151514
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 17815262000107
#         data    valor
# 0 2018-12-01  23299.5
# 1 2019-01-01  21226.9
# 2 2019-02-01  20901.7
# 3 2019-03-01  27092.2
# 4 2019-04-01  15377.4
# 5 2019-05-01  25058.2
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 17981111000129
#         data     valor
# 0 2018-12-01    713.33
# 1 2019-01-01   9879.29
# 2 2019-02-01   6776.12
# 3 2019-03-01   8735.73
# 4 2019-04-01   7284.51
# 5 2019-05-01  13815.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 883.6575757575756
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 18095739000190
#         data     valor
# 0 2018-12-01   9694.09
# 1 2019-01-01  19815.50
# 2 2019-02-01  18304.60
# 3 2019-03-01  10626.50
# 4 2019-04-01   4855.92
# 5 2019-05-01   8044.75
# probabilidade_zeros :0.0
# SCORE INICIAL : 587.5959595959595
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 18440088000128
#         data    valor
# 0 2018-12-01  55988.3
# 1 2019-01-01  39705.2
# 2 2019-02-01  22142.5
# 3 2019-03-01  26947.2
# 4 2019-04-01  45644.6
# 5 2019-05-01  45227.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 772.460606060606
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 18678132000132
#         data    valor
# 0 2018-12-01  6110.86
# 1 2019-01-01  4817.58
# 2 2019-02-01  3935.85
# 3 2019-03-01  3392.91
# 4 2019-04-01  8601.50
# 5 2019-05-01  4271.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 673.9212121212121
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 19529133000188
#         data    valor
# 0 2018-12-01  17446.1
# 1 2019-01-01  13941.7
# 2 2019-02-01  17168.1
# 3 2019-03-01  30698.3
# 4 2019-04-01  17463.0
# 5 2019-05-01  30066.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 831.430303030303
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 19574940000112
#         data    valor
# 0 2018-12-01  15261.9
# 1 2019-01-01  24452.1
# 2 2019-02-01  23866.9
# 3 2019-03-01  22261.4
# 4 2019-04-01  24704.5
# 5 2019-05-01  36871.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 864.312121212121
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 19802600000100
#         data     valor
# 0 2018-12-01   87466.8
# 1 2019-01-01  111718.0
# 2 2019-02-01   73772.2
# 3 2019-03-01  108710.0
# 4 2019-04-01   85031.8
# 5 2019-05-01   88235.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 738.1090909090912
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20496386000181
#         data    valor
# 0 2018-12-01  12502.0
# 1 2019-01-01  17060.1
# 2 2019-02-01  15427.3
# 3 2019-03-01  21565.7
# 4 2019-04-01  28268.2
# 5 2019-05-01  24457.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 805.4484848484849
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20593518000274
#         data     valor
# 0 2018-12-01  105739.0
# 1 2019-01-01  233959.0
# 2 2019-02-01   75871.2
# 3 2019-03-01   57246.6
# 4 2019-04-01   81230.5
# 5 2019-05-01   77032.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 610.1181818181817
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20593518000355
#         data     valor
# 0 2018-12-01  127538.0
# 1 2019-01-01  280359.0
# 2 2019-02-01   82940.9
# 3 2019-03-01   85743.6
# 4 2019-04-01   87762.1
# 5 2019-05-01   76380.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 465.3198653198653
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20604000000299
#         data     valor
# 0 2018-12-01  179646.0
# 1 2019-01-01  442194.0
# 2 2019-02-01  102060.0
# 3 2019-03-01   94248.0
# 4 2019-04-01   88019.3
# 5 2019-05-01  110928.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 488.8922558922559
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20604000000370
#         data    valor
# 0 2018-12-01  46051.8
# 1 2019-01-01  80104.6
# 2 2019-02-01  32157.3
# 3 2019-03-01  26700.8
# 4 2019-04-01  28951.2
# 5 2019-05-01  29601.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 631.4484848484848
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20737475000334
#         data     valor
# 0 2018-12-01   69782.9
# 1 2019-01-01  127938.0
# 2 2019-02-01   30131.2
# 3 2019-03-01   47117.9
# 4 2019-04-01   16262.8
# 5 2019-05-01   40354.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 589.4484848484848
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20777622000138
#         data     valor
# 0 2018-12-01  21067.20
# 1 2019-01-01  35887.10
# 2 2019-02-01  14558.60
# 3 2019-03-01   4136.44
# 4 2019-04-01   8746.27
# 5 2019-05-01  21942.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 713.1454545454545
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20792928000163
#         data    valor
# 0 2018-12-01  14803.0
# 1 2019-01-01  16000.4
# 2 2019-02-01  17495.4
# 3 2019-03-01  10327.2
# 4 2019-04-01  14645.6
# 5 2019-05-01  13126.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 713.1515151515154
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 20972015000129
#         data     valor
# 0 2018-12-01  11892.60
# 1 2019-01-01   8331.87
# 2 2019-02-01   8506.26
# 3 2019-03-01  18399.80
# 4 2019-04-01  15887.80
# 5 2019-05-01  15941.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 858.969696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21128497000106
#         data    valor
# 0 2018-12-01  24780.1
# 1 2019-01-01  32412.1
# 2 2019-02-01  39577.1
# 3 2019-03-01  72860.9
# 4 2019-04-01  88133.6
# 5 2019-05-01  71754.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 832.4646464646463
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21211061000178
#         data     valor
# 0 2018-12-01   9737.89
# 1 2019-01-01  17677.90
# 2 2019-02-01   5059.38
# 3 2019-03-01  12575.00
# 4 2019-04-01   9953.12
# 5 2019-05-01  11513.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 708.9090909090909
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21232229000121
#         data    valor
# 0 2018-12-01  53163.4
# 1 2019-01-01  75192.0
# 2 2019-02-01  50953.2
# 3 2019-03-01  29245.7
# 4 2019-04-01  44824.3
# 5 2019-05-01  32313.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 621.6464646464647
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21296784000117
#         data     valor
# 0 2018-12-01   66674.4
# 1 2019-01-01  125751.0
# 2 2019-02-01   40635.4
# 3 2019-03-01   29680.1
# 4 2019-04-01   30505.2
# 5 2019-05-01   33501.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 448.919191919192
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21301561000109
#         data    valor
# 0 2018-12-01  10273.5
# 1 2019-01-01  18555.7
# 2 2019-02-01  20928.3
# 3 2019-03-01  28817.0
# 4 2019-04-01  37948.8
# 5 2019-05-01  20334.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 676.0242424242425
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21301964000140
#         data     valor
# 0 2018-12-01   96642.0
# 1 2019-01-01  160912.0
# 2 2019-02-01   36617.1
# 3 2019-03-01   88995.0
# 4 2019-04-01   77555.4
# 5 2019-05-01   61175.4
# probabilidade_zeros :0.0
# SCORE INICIAL : 626.9988215488216
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21301964000220
#         data    valor
# 0 2018-12-01  47355.8
# 1 2019-01-01  66941.3
# 2 2019-02-01  19060.2
# 3 2019-03-01  22684.9
# 4 2019-04-01  26285.4
# 5 2019-05-01  25922.4
# probabilidade_zeros :0.0
# SCORE INICIAL : 628.1393939393939
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21403747000160
#         data    valor
# 0 2018-12-01  16880.0
# 1 2019-01-01  10088.1
# 2 2019-02-01  22536.8
# 3 2019-03-01  29968.0
# 4 2019-04-01  39490.4
# 5 2019-05-01  44593.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 862.6969696969695
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 21983948000184
#         data     valor
# 0 2018-12-01   5033.50
# 1 2019-01-01   3220.86
# 2 2019-02-01  15042.70
# 3 2019-03-01   7686.78
# 4 2019-04-01   2636.41
# 5 2019-05-01   4913.29
# probabilidade_zeros :0.0
# SCORE INICIAL : 596.8333333333334
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 22837646000160
#         data    valor
# 0 2018-12-01  30389.9
# 1 2019-01-01  11051.2
# 2 2019-02-01  35008.6
# 3 2019-03-01  20235.2
# 4 2019-04-01  23277.7
# 5 2019-05-01  53031.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 912.569696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 22930864000145
#         data    valor
# 0 2018-12-01  21417.6
# 1 2019-01-01  23183.9
# 2 2019-02-01  25575.3
# 3 2019-03-01  18540.3
# 4 2019-04-01  21557.6
# 5 2019-05-01  32483.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 820.9212121212122
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 22941675000178
#         data    valor
# 0 2018-12-01  37346.1
# 1 2019-01-01  24469.1
# 2 2019-02-01  16071.3
# 3 2019-03-01  12305.4
# 4 2019-04-01  14194.2
# 5 2019-05-01  16661.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 655.2575757575756
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 23210204000152
#         data    valor
# 0 2018-12-01  41366.7
# 1 2019-01-01  38200.2
# 2 2019-02-01  30803.2
# 3 2019-03-01  44200.5
# 4 2019-04-01  44431.1
# 5 2019-05-01  50259.4
# probabilidade_zeros :0.0
# SCORE INICIAL : 797.187878787879
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 23254457000128
#         data     valor
# 0 2018-12-01   8158.15
# 1 2019-01-01   4291.13
# 2 2019-02-01   4054.18
# 3 2019-03-01   2478.24
# 4 2019-04-01  14952.10
# 5 2019-05-01   9935.79
# probabilidade_zeros :0.0
# SCORE INICIAL : 752.2363636363635
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 23375019000118
#         data     valor
# 0 2018-12-01  19555.40
# 1 2019-01-01  25832.40
# 2 2019-02-01   2419.37
# 3 2019-03-01  10728.30
# 4 2019-04-01  20756.30
# 5 2019-05-01  14437.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 658.7393939393941
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 23731361000103
#         data     valor
# 0 2018-12-01  13614.40
# 1 2019-01-01  17452.70
# 2 2019-02-01  11969.60
# 3 2019-03-01  12164.70
# 4 2019-04-01  14617.80
# 5 2019-05-01   7719.24
# probabilidade_zeros :0.0
# SCORE INICIAL : 494.9494949494949
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 24020751000138
#         data     valor
# 0 2018-12-01   5015.59
# 1 2019-01-01  16388.00
# 2 2019-02-01   8781.60
# 3 2019-03-01   5740.11
# 4 2019-04-01   8713.13
# 5 2019-05-01   6060.44
# probabilidade_zeros :0.0
# SCORE INICIAL : 631.4303030303031
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 24216232000140
#         data    valor
# 0 2018-12-01  5253.21
# 1 2019-01-01  1159.36
# 2 2019-02-01  1697.55
# 3 2019-03-01  6194.60
# 4 2019-04-01  8011.91
# 5 2019-05-01  5415.88
# probabilidade_zeros :0.0
# SCORE INICIAL : 702.6121212121211
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 24339290000160
#         data    valor
# 0 2018-12-01  6542.39
# 1 2019-01-01  2314.14
# 2 2019-02-01  6077.81
# 3 2019-03-01  4376.47
# 4 2019-04-01  3449.90
# 5 2019-05-01  5193.98
# probabilidade_zeros :0.0
# SCORE INICIAL : 728.4767676767675
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 24554146000147
#         data     valor
# 0 2018-12-01   3494.87
# 1 2019-01-01    403.58
# 2 2019-02-01   3846.40
# 3 2019-03-01  13057.50
# 4 2019-04-01   4378.48
# 5 2019-05-01   6019.45
# probabilidade_zeros :0.0
# SCORE INICIAL : 650.2363636363636
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 24626838000153
#         data    valor
# 0 2018-12-01  45105.2
# 1 2019-01-01  13824.9
# 2 2019-02-01  37613.3
# 3 2019-03-01  49026.2
# 4 2019-04-01  48154.9
# 5 2019-05-01  35481.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 696.0787878787879
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 24694207000171
#         data     valor
# 0 2018-12-01    314.47
# 1 2019-01-01   5787.45
# 2 2019-02-01  14810.70
# 3 2019-03-01  12022.10
# 4 2019-04-01   7136.30
# 5 2019-05-01   6127.65
# probabilidade_zeros :0.0
# SCORE INICIAL : 611.5454545454546
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 24796335000126
#         data    valor
# 0 2018-12-01  32981.7
# 1 2019-01-01  10268.8
# 2 2019-02-01  12109.1
# 3 2019-03-01  11158.8
# 4 2019-04-01  14158.4
# 5 2019-05-01  15961.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 672.1878787878787
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 25132480000175
#         data     valor
# 0 2018-12-01   5347.18
# 1 2019-01-01  23106.20
# 2 2019-02-01  21878.10
# 3 2019-03-01  34068.80
# 4 2019-04-01  33451.80
# 5 2019-05-01  30420.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 749.4545454545455
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 25255687000137
#         data     valor
# 0 2018-12-01  14616.20
# 1 2019-01-01   5548.23
# 2 2019-02-01  10109.60
# 3 2019-03-01  24463.50
# 4 2019-04-01  30257.20
# 5 2019-05-01  27089.60
# probabilidade_zeros :0.0
# SCORE INICIAL : 867.1545454545454
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 25362878000106
#         data     valor
# 0 2018-12-01      0.01
# 1 2019-01-01  12194.80
# 2 2019-02-01  19672.30
# 3 2019-03-01  15828.50
# 4 2019-04-01  18800.90
# 5 2019-05-01  10051.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 628.5333333333333
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 25424244000122
#         data     valor
# 0 2018-12-01   5427.35
# 1 2019-01-01   5235.33
# 2 2019-02-01   5041.16
# 3 2019-03-01   5391.74
# 4 2019-04-01  13461.80
# 5 2019-05-01   5112.44
# probabilidade_zeros :0.0
# SCORE INICIAL : 638.1787878787878
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26108672000109
#         data    valor
# 0 2018-12-01   8727.4
# 1 2019-01-01  13857.2
# 2 2019-02-01  10902.7
# 3 2019-03-01  15675.0
# 4 2019-04-01  20036.5
# 5 2019-05-01  12575.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 704.069696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26172206000192
#         data    valor
# 0 2018-12-01  1086.80
# 1 2019-01-01  2469.34
# 2 2019-02-01  5608.80
# 3 2019-03-01  4380.71
# 4 2019-04-01  5546.79
# 5 2019-05-01  4362.52
# probabilidade_zeros :0.0
# SCORE INICIAL : 849.187878787879
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26203624000108
#         data    valor
# 0 2018-12-01  63601.6
# 1 2019-01-01  65914.6
# 2 2019-02-01  67747.6
# 3 2019-03-01  70165.4
# 4 2019-04-01  76347.3
# 5 2019-05-01  59009.9
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26262638000194
#         data    valor
# 0 2018-12-01  7339.27
# 1 2019-01-01  8094.09
# 2 2019-02-01  7308.06
# 3 2019-03-01  9274.48
# 4 2019-04-01  7395.39
# 5 2019-05-01  6429.36
# probabilidade_zeros :0.0
# SCORE INICIAL : 690.6151515151515
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26262638000275
#         data    valor
# 0 2018-12-01  55473.9
# 1 2019-01-01  32275.9
# 2 2019-02-01  45615.9
# 3 2019-03-01  38252.5
# 4 2019-04-01  32970.6
# 5 2019-05-01  30994.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 720.2151515151514
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26389228000109
#         data     valor
# 0 2018-12-01  110115.0
# 1 2019-01-01   85112.1
# 2 2019-02-01   49332.4
# 3 2019-03-01   34605.3
# 4 2019-04-01   77264.1
# 5 2019-05-01   52061.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 656.5
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26395024000180
#         data    valor
# 0 2018-12-01  18235.3
# 1 2019-01-01  20142.1
# 2 2019-02-01  35913.0
# 3 2019-03-01  30112.2
# 4 2019-04-01  25891.3
# 5 2019-05-01  27868.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 835.3848484848486
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26687312000109
#         data     valor
# 0 2018-12-01  10372.80
# 1 2019-01-01   9636.02
# 2 2019-02-01  10527.10
# 3 2019-03-01   9489.27
# 4 2019-04-01  10873.40
# 5 2019-05-01  11417.70
# probabilidade_zeros :0.0
# SCORE INICIAL : 737.1432900432901
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26868707000108
#         data    valor
# 0 2018-12-01     0.10
# 1 2019-01-01  1234.19
# 2 2019-02-01  3694.64
# 3 2019-03-01  5478.03
# 4 2019-04-01  4109.46
# 5 2019-05-01  9413.63
# probabilidade_zeros :0.0
# SCORE INICIAL : 895.3333333333334
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26884792000106
#         data     valor
# 0 2018-12-01  11325.40
# 1 2019-01-01  30044.50
# 2 2019-02-01   8082.03
# 3 2019-03-01  18938.70
# 4 2019-04-01  44858.10
# 5 2019-05-01  24828.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 673.9696969696969
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 26889468000172
#         data     valor
# 0 2018-12-01   5242.50
# 1 2019-01-01   9261.67
# 2 2019-02-01   3998.87
# 3 2019-03-01  10109.50
# 4 2019-04-01  16521.50
# 5 2019-05-01  17348.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 885.9878787878787
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27049818000155
#         data     valor
# 0 2018-12-01  12280.70
# 1 2019-01-01   3290.46
# 2 2019-02-01  11874.80
# 3 2019-03-01   6581.17
# 4 2019-04-01   6544.22
# 5 2019-05-01  12190.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 801.6545454545457
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27072462000170
#         data     valor
# 0 2018-12-01   7515.55
# 1 2019-01-01   9786.91
# 2 2019-02-01   7143.04
# 3 2019-03-01  13090.80
# 4 2019-04-01   6887.94
# 5 2019-05-01   7251.85
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27074288000103
#         data     valor
# 0 2018-12-01  11459.60
# 1 2019-01-01   7730.30
# 2 2019-02-01   4208.43
# 3 2019-03-01   6015.27
# 4 2019-04-01   6649.46
# 5 2019-05-01   7117.59
# probabilidade_zeros :0.0
# SCORE INICIAL : 717.5878787878786
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27180412000107
#         data     valor
# 0 2018-12-01   1952.09
# 1 2019-01-01   8987.72
# 2 2019-02-01  21111.30
# 3 2019-03-01  14408.80
# 4 2019-04-01   2100.85
# 5 2019-05-01  13403.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 715.0848484848485
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27234997000109
#         data     valor
# 0 2018-12-01    156.38
# 1 2019-01-01  10375.80
# 2 2019-02-01   1636.33
# 3 2019-03-01   8323.90
# 4 2019-04-01   7879.38
# 5 2019-05-01  10272.70
# probabilidade_zeros :0.0
# SCORE INICIAL : 811.2545454545456
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27269245000175
#         data    valor
# 0 2018-12-01  19378.9
# 1 2019-01-01  33869.6
# 2 2019-02-01  21266.7
# 3 2019-03-01  13192.8
# 4 2019-04-01  24505.9
# 5 2019-05-01  27682.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 760.6575757575756
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27421286000135
#         data      valor
# 0 2018-12-01  100829.00
# 1 2019-01-01   42248.40
# 2 2019-02-01   10782.90
# 3 2019-03-01    7396.24
# 4 2019-04-01   22572.00
# 5 2019-05-01   26321.60
# probabilidade_zeros :0.0
# SCORE INICIAL : 549.8939393939394
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27532710000119
#         data     valor
# 0 2018-12-01   8516.70
# 1 2019-01-01   7101.33
# 2 2019-02-01   9094.06
# 3 2019-03-01  13617.30
# 4 2019-04-01   9365.39
# 5 2019-05-01   8733.66
# probabilidade_zeros :0.0
# SCORE INICIAL : 705.0787878787879
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 27710283000111
#         data     valor
# 0 2018-12-01   9071.14
# 1 2019-01-01   7305.77
# 2 2019-02-01   7735.20
# 3 2019-03-01   4603.95
# 4 2019-04-01   8659.89
# 5 2019-05-01  11998.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 852.539393939394
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 28097781000101
#         data     valor
# 0 2018-12-01   2552.66
# 1 2019-01-01  37561.80
# 2 2019-02-01  16652.30
# 3 2019-03-01  20349.40
# 4 2019-04-01   7949.58
# 5 2019-05-01  13280.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 599.2363636363636
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 28385886000158
#         data     valor
# 0 2018-12-01  17868.60
# 1 2019-01-01  10999.90
# 2 2019-02-01  14426.50
# 3 2019-03-01   7466.70
# 4 2019-04-01   8524.09
# 5 2019-05-01   6807.94
# probabilidade_zeros :0.0
# SCORE INICIAL : 509.6195286195287
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 28987165000118
#         data     valor
# 0 2018-12-01   1779.49
# 1 2019-01-01   9651.60
# 2 2019-02-01  10618.70
# 3 2019-03-01  11507.50
# 4 2019-04-01  10930.00
# 5 2019-05-01   9624.46
# probabilidade_zeros :0.0
# SCORE INICIAL : 883.7333333333332
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 29055148000105
#         data    valor
# 0 2018-12-01      0.1
# 1 2019-01-01  35432.6
# 2 2019-02-01   8298.4
# 3 2019-03-01  12117.3
# 4 2019-04-01  15196.6
# 5 2019-05-01  19637.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 702.7372294372295
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 29822763000108
#         data    valor
# 0 2018-12-01  28127.8
# 1 2019-01-01  22914.3
# 2 2019-02-01  23521.1
# 3 2019-03-01  20230.5
# 4 2019-04-01  26384.9
# 5 2019-05-01  29477.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 764.3454545454546
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 29842987000173
#         data     valor
# 0 2018-12-01  32882.90
# 1 2019-01-01  10640.80
# 2 2019-02-01  30438.60
# 3 2019-03-01   8295.65
# 4 2019-04-01  17183.10
# 5 2019-05-01  11993.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 522.7575757575758
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 29849013000111
#         data    valor
# 0 2018-12-01  14683.2
# 1 2019-01-01  16393.2
# 2 2019-02-01  18905.3
# 3 2019-03-01  37416.9
# 4 2019-04-01  37171.6
# 5 2019-05-01  37296.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 868.2969696969698
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 29854525000176
#         data     valor
# 0 2018-12-01  17458.80
# 1 2019-01-01   9506.40
# 2 2019-02-01   4742.06
# 3 2019-03-01  10322.70
# 4 2019-04-01  24049.60
# 5 2019-05-01  19538.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 842.5515151515151
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 29895389000162
#         data     valor
# 0 2018-12-01   7374.08
# 1 2019-01-01  24765.70
# 2 2019-02-01  11452.10
# 3 2019-03-01  13042.00
# 4 2019-04-01   3537.44
# 5 2019-05-01  15911.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 729.5272727272728
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 29971311000180
#         data     valor
# 0 2018-12-01   5550.44
# 1 2019-01-01  12165.90
# 2 2019-02-01   4231.62
# 3 2019-03-01   6233.84
# 4 2019-04-01   2649.07
# 5 2019-05-01   3906.71
# probabilidade_zeros :0.0
# SCORE INICIAL : 569.2457912457912
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 29988990000108
#         data    valor
# 0 2018-12-01  5811.44
# 1 2019-01-01  5373.33
# 2 2019-02-01  1336.22
# 3 2019-03-01  3982.40
# 4 2019-04-01  4864.77
# 5 2019-05-01  4231.87
# probabilidade_zeros :0.0
# SCORE INICIAL : 747.9939393939394
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 30141207000147
#         data    valor
# 0 2018-12-01  86905.0
# 1 2019-01-01  74411.4
# 2 2019-02-01  67687.7
# 3 2019-03-01  81078.1
# 4 2019-04-01  78602.1
# 5 2019-05-01  61161.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 703.3969696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 30360106000167
#         data    valor
# 0 2018-12-01  24338.6
# 1 2019-01-01  10667.6
# 2 2019-02-01  30674.8
# 3 2019-03-01  25844.4
# 4 2019-04-01  29795.6
# 5 2019-05-01  18102.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 674.521212121212
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 30420875000103
#         data     valor
# 0 2018-12-01  11028.20
# 1 2019-01-01   7451.72
# 2 2019-02-01   8899.57
# 3 2019-03-01  16106.80
# 4 2019-04-01  19263.00
# 5 2019-05-01  29671.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 931.469696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 30589922000147
#         data     valor
# 0 2018-12-01  11606.80
# 1 2019-01-01   8221.68
# 2 2019-02-01  19585.60
# 3 2019-03-01   4589.87
# 4 2019-04-01   9666.59
# 5 2019-05-01  11230.90
# probabilidade_zeros :0.0
# SCORE INICIAL : 691.5757575757575
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 30684923000170
#         data    valor
# 0 2018-12-01    37.37
# 1 2019-01-01  7490.08
# 2 2019-02-01  2954.43
# 3 2019-03-01  4275.41
# 4 2019-04-01  4513.54
# 5 2019-05-01  7066.09
# probabilidade_zeros :0.0
# SCORE INICIAL : 827.6242424242423
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 30948249000194
#         data    valor
# 0 2018-12-01  2288.14
# 1 2019-01-01  4174.33
# 2 2019-02-01  3257.25
# 3 2019-03-01  3111.22
# 4 2019-04-01  5409.05
# 5 2019-05-01  4633.12
# probabilidade_zeros :0.0
# SCORE INICIAL : 816.2121212121211
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 31144973000128
#         data    valor
# 0 2018-12-01  26942.2
# 1 2019-01-01  82640.4
# 2 2019-02-01  37591.6
# 3 2019-03-01  58976.9
# 4 2019-04-01  66613.4
# 5 2019-05-01  65901.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 742.9333333333334
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 31512268000136
#         data     valor
# 0 2018-12-01   6102.37
# 1 2019-01-01  12237.40
# 2 2019-02-01   9131.08
# 3 2019-03-01   8541.61
# 4 2019-04-01   6136.77
# 5 2019-05-01  10849.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 775.7818181818183
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 31526219000152
#         data    valor
# 0 2018-12-01  43182.9
# 1 2019-01-01  32390.5
# 2 2019-02-01  35287.7
# 3 2019-03-01  62221.8
# 4 2019-04-01  51197.0
# 5 2019-05-01  87534.4
# probabilidade_zeros :0.0
# SCORE INICIAL : 895.1575757575757
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 31703330000177
#         data     valor
# 0 2018-12-01   8970.52
# 1 2019-01-01  10201.90
# 2 2019-02-01   1784.64
# 3 2019-03-01  12494.40
# 4 2019-04-01  10512.30
# 5 2019-05-01   5329.60
# probabilidade_zeros :0.0
# SCORE INICIAL : 547.1582491582491
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 31713681000169
#         data    valor
# 0 2018-12-01  22287.1
# 1 2019-01-01  33130.6
# 2 2019-02-01  28048.3
# 3 2019-03-01  19939.9
# 4 2019-04-01  48571.8
# 5 2019-05-01  21104.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 657.1181818181817
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 45028404000393
#         data     valor
# 0 2018-12-01    736.79
# 1 2019-01-01  20617.60
# 2 2019-02-01   7532.48
# 3 2019-03-01   4326.10
# 4 2019-04-01   6369.31
# 5 2019-05-01   8911.75
# probabilidade_zeros :0.0
# SCORE INICIAL : 629.2777777777777
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 51524486000106
#         data     valor
# 0 2018-12-01   8869.57
# 1 2019-01-01  40107.10
# 2 2019-02-01  44916.00
# 3 2019-03-01  43291.70
# 4 2019-04-01  45989.70
# 5 2019-05-01  56596.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 817.4121212121212
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 64605611000146
#         data    valor
# 0 2018-12-01  19674.9
# 1 2019-01-01  62945.8
# 2 2019-02-01  16822.6
# 3 2019-03-01  15434.0
# 4 2019-04-01  18320.9
# 5 2019-05-01  20416.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 601.2151515151515
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 70359633000176
#         data    valor
# 0 2018-12-01  13636.2
# 1 2019-01-01  15313.3
# 2 2019-02-01  21352.1
# 3 2019-03-01  77142.6
# 4 2019-04-01  20056.0
# 5 2019-05-01  65356.4
# probabilidade_zeros :0.0
# SCORE INICIAL : 856.5787878787878
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 71102289000106
#         data    valor
# 0 2018-12-01  18265.2
# 1 2019-01-01  15026.5
# 2 2019-02-01  27686.0
# 3 2019-03-01  17062.1
# 4 2019-04-01  14142.0
# 5 2019-05-01  20620.8
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 73505216000425
#         data     valor
# 0 2018-12-01  20939.90
# 1 2019-01-01  15946.80
# 2 2019-02-01  20853.10
# 3 2019-03-01  20839.40
# 4 2019-04-01  13222.80
# 5 2019-05-01   9400.01
# probabilidade_zeros :0.0
# SCORE INICIAL : 427.60942760942754
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 80694730000179
#         data     valor
# 0 2018-12-01  11329.60
# 1 2019-01-01   6353.57
# 2 2019-02-01   7329.34
# 3 2019-03-01  11209.40
# 4 2019-04-01  20173.40
# 5 2019-05-01  19050.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 871.3969696969697
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 97542416000173
#         data    valor
# 0 2018-12-01  20818.4
# 1 2019-01-01  36132.9
# 2 2019-02-01  25006.4
# 3 2019-03-01  15247.2
# 4 2019-04-01  15742.2
# 5 2019-05-01  29339.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 770.4787878787879
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7

# %%
err.__len__()
# Out:
# 118

# %%
sem_dividas = [list(el.keys())[0] for el in resp if len(list(el.values())[0])==0 ]

# %%
sem_divida.__len__()
# Out:
# 114

# %%
_e = [el for el in err if el not in sem_divida]

# %%
_e
# Out:
# ['08744783000120', '17815262000107', '27180412000107', '71102289000106']

# %%
dfcalc = pd.concat(fr)

# %%
dfcalc.head()
# Out:
#   segmento  ocorrencias  probabilidade  valor_divida  composicao  \
# 0  credito           19       0.863636     619564.83    0.987585
# 1    infra            2       0.090909        288.31    0.000460
# 2   outros            1       0.045455       7500.00    0.011955
# 0   outros            8       1.000000      30659.53    1.000000
# 0   outros            2       1.000000       6864.04    1.000000
#
#       fat_medio         pi     lambda  impacto_segmento     risco      dscore  \
# 0  15490.366667  13.332261  13.166747          4.041687  3.490548    0.000000
# 1  15490.366667   0.006204   0.000003          0.250001  0.022727  369.799975
# 2  15490.366667   0.161391   0.001929          0.000482  0.000022  378.391703
# 0   5168.208333   1.977444   1.977444          0.494361  0.494361    0.000000
# 0  21809.431667   0.104909   0.104909          0.026227  0.026227  465.073823
#
#              cnpj
# 0  00842847000113
# 1  00842847000113
# 2  00842847000113
# 0  01147087000197
# 0  01246934000170

# %%
dfcalc[dfcalc["cnpj"]=='00842847000113']
# Out:
#   segmento  ocorrencias  probabilidade  valor_divida  composicao  \
# 0  credito           19       0.863636     619564.83    0.987585
# 1    infra            2       0.090909        288.31    0.000460
# 2   outros            1       0.045455       7500.00    0.011955
#
#       fat_medio         pi     lambda  impacto_segmento     risco      dscore  \
# 0  15490.366667  13.332261  13.166747          4.041687  3.490548    0.000000
# 1  15490.366667   0.006204   0.000003          0.250001  0.022727  369.799975
# 2  15490.366667   0.161391   0.001929          0.000482  0.000022  378.391703
#
#              cnpj
# 0  00842847000113
# 1  00842847000113
# 2  00842847000113

# %%
fr_scores = []
for el in resp:
    print(el)
    _df = pd.DataFrame()
    cnpj = list(el.keys())[0]
    print(cnpj)
    _df["cnpj"] = [cnpj]
    ret = el.get(cnpj)
    _df['credito'] = [ret.get("credito")]
    _df['processos'] = [ret.get("processos")]
    _df['infra'] = [ret.get("infra")]
    _df['outros'] = [ret.get("outros")]
    _df['lscore'] = [el.get("lscore")]
    _df["dscore"] = [el.get("dscore")]
    _df["score"] = [el.get("score")]
    fr_scores.append(_df)
# Out:
# {'00150714000186': {}}
# 00150714000186
# {'00686810000143': {}}
# 00686810000143
# {'00842847000113': {'credito': 0, 'infra': 369, 'outros': 378, 'lscore': 473, 'dscore': 249, 'score': 361}}
# 00842847000113
# {'00874646000289': {}}
# 00874646000289
# {'00934773000145': {}}
# 00934773000145
# {'01147087000197': {'outros': 0, 'lscore': 606, 'dscore': 0, 'score': 303}}
# 01147087000197
# {'01242387000155': {}}
# 01242387000155
# {'01246934000170': {'outros': 465, 'lscore': 597, 'dscore': 465, 'score': 531}}
# 01246934000170
# {'01368548000151': {}}
# 01368548000151
# {'01698637000166': {'credito': 0, 'outros': 234, 'lscore': 293, 'dscore': 117, 'score': 205}}
# 01698637000166
# {'01698637000328': {'credito': 0, 'outros': 267, 'lscore': 335, 'dscore': 133, 'score': 234}}
# 01698637000328
# {'01760044000182': {}}
# 01760044000182
# {'02125400000159': {'outros': 451, 'lscore': 566, 'dscore': 451, 'score': 508}}
# 02125400000159
# {'02407917000130': {}}
# 02407917000130
# {'02801654000220': {'credito': 436, 'infra': 419, 'outros': 451, 'lscore': 576, 'dscore': 435, 'score': 505}}
# 02801654000220
# {'02802892000170': {'outros': 480, 'lscore': 608, 'dscore': 480, 'score': 544}}
# 02802892000170
# {'03300735000129': {'credito': 102, 'lscore': 596, 'dscore': 102, 'score': 349}}
# 03300735000129
# {'04293170000162': {}}
# 04293170000162
# {'04474793000131': {}}
# 04474793000131
# {'04608458000189': {'outros': 426, 'lscore': 576, 'dscore': 426, 'score': 501}}
# 04608458000189
# {'04943517000175': {}}
# 04943517000175
# {'05074012000184': {}}
# 05074012000184
# {'05093466000100': {}}
# 05093466000100
# {'05115981000136': {'outros': 452, 'lscore': 566, 'dscore': 452, 'score': 509}}
# 05115981000136
# {'05336959000116': {}}
# 05336959000116
# {'05583640000195': {'credito': 0, 'outros': 398, 'lscore': 510, 'dscore': 199, 'score': 354}}
# 05583640000195
# {'05634767000358': {}}
# 05634767000358
# {'05766218000175': {}}
# 05766218000175
# {'05891070000109': {}}
# 05891070000109
# {'06096281000104': {}}
# 06096281000104
# {'06213352000101': {}}
# 06213352000101
# {'07176964000134': {'outros': 354, 'lscore': 467, 'dscore': 354, 'score': 410}}
# 07176964000134
# {'07406557000176': {'outros': 452, 'lscore': 566, 'dscore': 452, 'score': 509}}
# 07406557000176
# {'07449710000142': {}}
# 07449710000142
# {'07513220000168': {}}
# 07513220000168
# {'07874345000113': {}}
# 07874345000113
# {'07942208000179': {'outros': 497, 'lscore': 636, 'dscore': 497, 'score': 566}}
# 07942208000179
# {'08312804000138': {'credito': 0, 'outros': 0, 'lscore': 558, 'dscore': 0, 'score': 279}}
# 08312804000138
# {'08601921000111': {'credito': 0, 'outros': 0, 'lscore': 428, 'dscore': 0, 'score': 214}}
# 08601921000111
# {'08656814000190': {}}
# 08656814000190
# {'08792506000192': {}}
# 08792506000192
# {'08982475000213': {}}
# 08982475000213
# {'08992524000118': {'credito': 80, 'lscore': 562, 'dscore': 80, 'score': 321}}
# 08992524000118
# {'08993567000118': {'credito': 0, 'outros': 0, 'lscore': 452, 'dscore': 0, 'score': 226}}
# 08993567000118
# {'09165878000151': {}}
# 09165878000151
# {'09214739000170': {'outros': 402, 'lscore': 510, 'dscore': 402, 'score': 456}}
# 09214739000170
# {'09434547000170': {'outros': 454, 'lscore': 572, 'dscore': 454, 'score': 513}}
# 09434547000170
# {'10258160000199': {}}
# 10258160000199
# {'10277108000180': {'outros': 493, 'lscore': 626, 'dscore': 493, 'score': 559}}
# 10277108000180
# {'10380621000100': {}}
# 10380621000100
# {'10690679000141': {'credito': 271, 'outros': 361, 'processos': 351, 'lscore': 462, 'dscore': 328, 'score': 395}}
# 10690679000141
# {'10714656000120': {}}
# 10714656000120
# {'10819214000148': {}}
# 10819214000148
# {'10819466000177': {}}
# 10819466000177
# {'10946187000174': {'credito': 88, 'lscore': 498, 'dscore': 88, 'score': 293}}
# 10946187000174
# {'11014236000101': {}}
# 11014236000101
# {'11018748001703': {'infra': 351, 'outros': 0, 'lscore': 470, 'dscore': 175, 'score': 322}}
# 11018748001703
# {'11018748002009': {'infra': 232, 'outros': 0, 'lscore': 313, 'dscore': 116, 'score': 214}}
# 11018748002009
# {'11020761000121': {'outros': 521, 'lscore': 658, 'dscore': 521, 'score': 589}}
# 11020761000121
# {'11029156000200': {'credito': 0, 'outros': 0, 'processos': 382, 'lscore': 492, 'dscore': 127, 'score': 309}}
# 11029156000200
# {'11226953000270': {'outros': 387, 'lscore': 497, 'dscore': 387, 'score': 442}}
# 11226953000270
# {'11240411000170': {}}
# 11240411000170
# {'11253353000110': {'credito': 0, 'outros': 440, 'lscore': 569, 'dscore': 220, 'score': 394}}
# 11253353000110
# {'11260310000676': {}}
# 11260310000676
# {'11340751000173': {'outros': 358, 'lscore': 470, 'dscore': 358, 'score': 414}}
# 11340751000173
# {'11485379000193': {}}
# 11485379000193
# {'11903993000128': {}}
# 11903993000128
# {'11978779000130': {}}
# 11978779000130
# {'12158043000189': {}}
# 12158043000189
# {'12337841000178': {'outros': 0, 'lscore': 517, 'dscore': 0, 'score': 258}}
# 12337841000178
# {'12359129000170': {'credito': 0, 'outros': 0, 'lscore': 503, 'dscore': 0, 'score': 251}}
# 12359129000170
# {'12401497000139': {}}
# 12401497000139
# {'12436421000149': {'credito': 239, 'outros': 385, 'lscore': 482, 'dscore': 312, 'score': 397}}
# 12436421000149
# {'13005501000102': {}}
# 13005501000102
# {'13703589000136': {'outros': 393, 'lscore': 493, 'dscore': 393, 'score': 443}}
# 13703589000136
# {'13751075000156': {'infra': 431, 'outros': 451, 'lscore': 568, 'dscore': 441, 'score': 504}}
# 13751075000156
# {'13962219000113': {}}
# 13962219000113
# {'14136967000100': {}}
# 14136967000100
# {'14219934000123': {}}
# 14219934000123
# {'14549293000175': {}}
# 14549293000175
# {'14760070000152': {'outros': 355, 'lscore': 477, 'dscore': 355, 'score': 416}}
# 14760070000152
# {'15521792000117': {}}
# 15521792000117
# {'16098066000104': {}}
# 16098066000104
# {'16590208000148': {}}
# 16590208000148
# {'16950630000167': {'outros': 355, 'lscore': 462, 'dscore': 355, 'score': 408}}
# 16950630000167
# {'16972970000199': {}}
# 16972970000199
# {'17096779000193': {'credito': 88, 'lscore': 463, 'dscore': 88, 'score': 275}}
# 17096779000193
# {'17267491000134': {'outros': 360, 'lscore': 482, 'dscore': 360, 'score': 421}}
# 17267491000134
# {'17322294000170': {}}
# 17322294000170
# {'17359266000128': {}}
# 17359266000128
# {'17521459000133': {}}
# 17521459000133
# {'17981111000129': {'outros': 490, 'lscore': 618, 'dscore': 490, 'score': 554}}
# 17981111000129
# {'18095739000190': {'outros': 325, 'lscore': 411, 'dscore': 325, 'score': 368}}
# 18095739000190
# {'18440088000128': {}}
# 18440088000128
# {'18678132000132': {}}
# 18678132000132
# {'19529133000188': {}}
# 19529133000188
# {'19574940000112': {'processos': 238, 'lscore': 605, 'dscore': 238, 'score': 421}}
# 19574940000112
# {'19802600000100': {}}
# 19802600000100
# {'20496386000181': {}}
# 20496386000181
# {'20593518000274': {}}
# 20593518000274
# {'20593518000355': {}}
# 20593518000355
# {'20604000000299': {'outros': 273, 'lscore': 342, 'dscore': 273, 'score': 307}}
# 20604000000299
# {'20604000000370': {'outros': 351, 'lscore': 442, 'dscore': 351, 'score': 396}}
# 20604000000370
# {'20737475000334': {}}
# 20737475000334
# {'20777622000138': {}}
# 20777622000138
# {'20792928000163': {}}
# 20792928000163
# {'20972015000129': {}}
# 20972015000129
# {'21128497000106': {}}
# 21128497000106
# {'21211061000178': {'outros': 0, 'lscore': 496, 'dscore': 0, 'score': 248}}
# 21211061000178
# {'21232229000121': {}}
# 21232229000121
# {'21296784000117': {'infra': 213, 'processos': 186, 'lscore': 314, 'dscore': 199, 'score': 256}}
# 21296784000117
# {'21301561000109': {'outros': 375, 'lscore': 473, 'dscore': 375, 'score': 424}}
# 21301561000109
# {'21301964000140': {'infra': 337, 'outros': 350, 'processos': 326, 'lscore': 438, 'dscore': 338, 'score': 388}}
# 21301964000140
# {'21301964000220': {'infra': 335, 'outros': 351, 'processos': 324, 'lscore': 439, 'dscore': 337, 'score': 388}}
# 21301964000220
# {'21403747000160': {'outros': 402, 'lscore': 603, 'dscore': 402, 'score': 502}}
# 21403747000160
# {'21983948000184': {'infra': 323, 'outros': 292, 'lscore': 417, 'dscore': 307, 'score': 362}}
# 21983948000184
# {'22837646000160': {}}
# 22837646000160
# {'22930864000145': {}}
# 22930864000145
# {'22941675000178': {'outros': 0, 'lscore': 458, 'dscore': 0, 'score': 229}}
# 22941675000178
# {'23210204000152': {'outros': 438, 'lscore': 558, 'dscore': 438, 'score': 498}}
# 23210204000152
# {'23254457000128': {'credito': 383, 'outros': 368, 'lscore': 526, 'dscore': 376, 'score': 451}}
# 23254457000128
# {'23375019000118': {}}
# 23375019000118
# {'23731361000103': {}}
# 23731361000103
# {'24020751000138': {'outros': 350, 'lscore': 442, 'dscore': 350, 'score': 396}}
# 24020751000138
# {'24216232000140': {}}
# 24216232000140
# {'24339290000160': {}}
# 24339290000160
# {'24554146000147': {'outros': 317, 'lscore': 455, 'dscore': 317, 'score': 386}}
# 24554146000147
# {'24626838000153': {'outros': 332, 'lscore': 487, 'dscore': 332, 'score': 409}}
# 24626838000153
# {'24694207000171': {}}
# 24694207000171
# {'24796335000126': {}}
# 24796335000126
# {'25132480000175': {}}
# 25132480000175
# {'25255687000137': {}}
# 25255687000137
# {'25362878000106': {}}
# 25362878000106
# {'25424244000122': {}}
# 25424244000122
# {'26108672000109': {}}
# 26108672000109
# {'26172206000192': {}}
# 26172206000192
# {'26203624000108': {}}
# 26203624000108
# {'26262638000194': {}}
# 26262638000194
# {'26262638000275': {}}
# 26262638000275
# {'26389228000109': {'outros': 364, 'lscore': 459, 'dscore': 364, 'score': 411}}
# 26389228000109
# {'26395024000180': {'outros': 446, 'lscore': 584, 'dscore': 446, 'score': 515}}
# 26395024000180
# {'26687312000109': {'outros': 356, 'lscore': 516, 'dscore': 356, 'score': 436}}
# 26687312000109
# {'26868707000108': {'infra': 374, 'lscore': 626, 'dscore': 374, 'score': 500}}
# 26868707000108
# {'26884792000106': {}}
# 26884792000106
# {'26889468000172': {}}
# 26889468000172
# {'27049818000155': {}}
# 27049818000155
# {'27072462000170': {}}
# 27072462000170
# {'27074288000103': {}}
# 27074288000103
# {'27234997000109': {}}
# 27234997000109
# {'27269245000175': {'outros': 371, 'lscore': 532, 'dscore': 371, 'score': 451}}
# 27269245000175
# {'27421286000135': {}}
# 27421286000135
# {'27532710000119': {}}
# 27532710000119
# {'27710283000111': {}}
# 27710283000111
# {'28097781000101': {}}
# 28097781000101
# {'28385886000158': {'outros': 248, 'lscore': 356, 'dscore': 248, 'score': 302}}
# 28385886000158
# {'28987165000118': {}}
# 28987165000118
# {'29055148000105': {'outros': 392, 'lscore': 491, 'dscore': 392, 'score': 441}}
# 29055148000105
# {'29822763000108': {}}
# 29822763000108
# {'29842987000173': {}}
# 29842987000173
# {'29849013000111': {}}
# 29849013000111
# {'29854525000176': {}}
# 29854525000176
# {'29895389000162': {}}
# 29895389000162
# {'29971311000180': {}}
# 29971311000180
# {'29988990000108': {}}
# 29988990000108
# {'30141207000147': {}}
# 30141207000147
# {'30360106000167': {}}
# 30360106000167
# {'30420875000103': {}}
# 30420875000103
# {'30589922000147': {}}
# 30589922000147
# {'30684923000170': {'outros': 0, 'lscore': 579, 'dscore': 0, 'score': 289}}
# 30684923000170
# {'30948249000194': {}}
# 30948249000194
# {'31144973000128': {}}
# 31144973000128
# {'31512268000136': {}}
# 31512268000136
# {'31526219000152': {}}
# 31526219000152
# {'31703330000177': {}}
# 31703330000177
# {'31713681000169': {}}
# 31713681000169
# {'45028404000393': {'outros': 351, 'processos': 261, 'lscore': 440, 'dscore': 306, 'score': 373}}
# 45028404000393
# {'51524486000106': {}}
# 51524486000106
# {'64605611000146': {}}
# 64605611000146
# {'70359633000176': {'credito': 359, 'processos': 0, 'lscore': 599, 'dscore': 179, 'score': 389}}
# 70359633000176
# {'73505216000425': {}}
# 73505216000425
# {'80694730000179': {}}
# 80694730000179
# {'97542416000173': {}}
# 97542416000173

# %%
