# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sqlalchemy import create_engine
import requests
from time import sleep
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("HistoricoCobranca.xlsx")

# %%
df["doc"] = df.apply(lambda x : x["CNPJ"].replace(".", "").replace("-", "").replace("/", ""), axis=1)

# %%
df.head()
# Out:
#     PRODUTO                                 EMPRESA                CNPJ  \
# 0  WIRECARD           CLAUDEMIR DE SOUZA FRANCISCO   12.549.813/0001-14
# 1  WIRECARD                  LITTLE BABY GYN EIRELI  21.666.147/0001-95
# 2  WIRECARD   SAFETICKET SERVICOS PARA EVENTOS LTDA  26.555.778/0001-50
# 3  TOMATICO  TISSAH BRAND COMERCIO DE ROUPAS EIRELI  28.900.576/0001-24
# 4  TOMATICO  TISSAH BRAND COMERCIO DE ROUPAS EIRELI  28.900.576/0002-05
#
#   DATA_ALERTA                                  MOTIVO DO CONTATO DATA_CONTATO  \
# 0  2019-03-13                               Queda no faturamento        43538
# 1  2019-03-13  Queda no faturamento + ultimo movimento dia 06/03        43538
# 2  2019-03-13                               Queda no faturamento        43540
# 3  2019-03-20                               Queda no faturamento        43556
# 4  2019-03-20                     Sem Pagamento desde 08/05/2019        43556
#
#       JUSTIFICATIVA DO ALERTA               RESULTADO DO CONTATO  \
# 0          Queda no movimento        Aumento de retenção para 8%
# 1   Problemas com o site Elo7  Espera para tomada de faturamento
# 2          Queda no movimento       Aumento de retenção para 10%
# 3  Queda nas vendas de cartão       Aumento de retenção para 20%
# 4               Fechou a Loja       Proposta de pagamento aceita
#
#               doc
# 0  12549813000114
# 1  21666147000195
# 2  26555778000150
# 3  28900576000124
# 4  28900576000205

# %%
df["MOTIVO DO CONTATO"].unique().tolist()
# Out:
# ['Queda no faturamento',
#  'Queda no faturamento + ultimo movimento dia 06/03',
#  'Sem Pagamento desde 08/05/2019',
#  'Sem Pagamento desde 13/03/2019',
#  'Sem Pagamento desde a cessao',
#  'Sem Pagamento desde 03/04/2019',
#  'Sem Pagamento desde 16/04/2019',
#  'Sem Pagamento desde 09/04/2019',
#  'Não voltou a faturar',
#  'Queda no faturamento + ultimo movimento dia 17/05',
#  'Sem Pagamento desde 29/04/2019',
#  'Queda no faturamento + ultimo movimento dia 08/05',
#  'Sem Pagamento desde 22/04/2019',
#  'Queda no faturamento + ultimo movimento dia 16/05',
#  'Queda no faturamento + ultimo movimento dia 15/05']

# %%
df["JUSTIFICATIVA DO ALERTA"].unique().tolist()
# Out:
# ['Queda no movimento',
#  'Problemas com o site Elo7',
#  'Queda nas vendas de cartão',
#  'Fechou a Loja',
#  'Fechou a Empresa',
#  'Parou de fazer antecipação',
#  'Sem resposta',
#  'Sem movimento no cartão',
#  'Queda no movimento, problemas com o site Elo7',
#  'Queda no movimento, mudança estrutural no site',
#  'Movimento fraco',
#  'Maquininha quebrada',
#  'Muitas taxas na venda de cartão',
#  'Promoção pagamentos a vista',
#  'Mudança de local de trabalho']

# %%
df[df['JUSTIFICATIVA DO ALERTA'].isin(["Fechou a Loja", "Fechou a Empresa"])]
# Out:
#     PRODUTO                                 EMPRESA                CNPJ  \
# 4  TOMATICO  TISSAH BRAND COMERCIO DE ROUPAS EIRELI  28.900.576/0002-05
# 6  TOMATICO               ADNAEL SANTOS DE OLIVEIRA  22.861.508/0001-17
#
#   DATA_ALERTA               MOTIVO DO CONTATO   DATA_CONTATO  \
# 4  2019-03-20  Sem Pagamento desde 08/05/2019          43556
# 6  2019-04-13  Sem Pagamento desde 13/03/2019  16/04 a 24/05
#
#   JUSTIFICATIVA DO ALERTA          RESULTADO DO CONTATO
# 4           Fechou a Loja  Proposta de pagamento aceita
# 6        Fechou a Empresa  Proposta de pagamento aceita

# %%
engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/creditoDigital")
con = engine.connect()
dfop = pd.read_sql("select * from desembolso", con)
con.close()

# %%
df_data = dfop[["cnpj", "dataDesembolso"]]

# %%
df_data["dataDesembolso"] = df_data.apply(lambda x : x["dataDesembolso"].date(), axis=1)

# %%
df.shape
# Out:
# (39, 9)

# %%
res = df.merge(df_data, left_on='doc', right_on='cnpj', how='left')

# %%
res[res["doc"]=='11117460000110']
# Out:
#          PRODUTO                      EMPRESA                CNPJ DATA_ALERTA  \
# 18  CREDITOVELOZ  NOVA ERA DESPACHANTES LTDA   11.117.460/0001-10  2019-04-26
# 27  CREDITOVELOZ  NOVA ERA DESPACHANTES LTDA   11.117.460/0001-10  2019-05-20
#
#        MOTIVO DO CONTATO DATA_CONTATO     JUSTIFICATIVA DO ALERTA  \
# 18  Queda no faturamento        43582  Queda nas vendas de cartão
# 27  Queda no faturamento        43615             Movimento fraco
#
#                                  RESULTADO DO CONTATO             doc  \
# 18                  Espera para tomada de faturamento  11117460000110
# 27  Mais um Ultimo periodo de espera para retomada...  11117460000110
#
#               cnpj dataDesembolso
# 18  11117460000110     2019-02-28
# 27  11117460000110     2019-02-28

# %%
res.drop(columns=["cnpj"], axis=1, inplace=True)

# %%
res["dataDesembolso"].iloc[0]
# Out:
# datetime.date(2019, 2, 14)

# %%
res.sort_values("dataDesembolso")
# Out:
#          PRODUTO                                    EMPRESA  \
# 2       WIRECARD      SAFETICKET SERVICOS PARA EVENTOS LTDA
# 24      WIRECARD      SAFETICKET SERVICOS PARA EVENTOS LTDA
# 4       TOMATICO     TISSAH BRAND COMERCIO DE ROUPAS EIRELI
# 5       TOMATICO     TISSAH BRAND COMERCIO DE ROUPAS EIRELI
# 6       TOMATICO  TDG COSMETICOS - COMERCIO E SERVICOS LTDA
# 10      TOMATICO  TDG COSMETICOS - COMERCIO E SERVICOS LTDA
# 7       TOMATICO  TDG COSMETICOS - COMERCIO E SERVICOS LTDA
# 11      TOMATICO  TDG COSMETICOS - COMERCIO E SERVICOS LTDA
# 12      TOMATICO                           THAIS SCARLATE
# 29      TOMATICO                           THAIS SCARLATE
# 35      TOMATICO         NISMOCAR SERVICOS AUTOMOTIVOS LTDA
# 13      TOMATICO         NISMOCAR SERVICOS AUTOMOTIVOS LTDA
# 8       TOMATICO                  ADNAEL SANTOS DE OLIVEIRA
# 1       WIRECARD                     LITTLE BABY GYN EIRELI
# 14  12.919.292/0001-40  2019-04-26
# 3   26.555.778/0001-50  2019-03-13
# 27  11.117.460/0001-10  2019-05-20
# 20  12.919.292/0001-40  2019-05-15
# 25  26.555.778/0001-50  2019-05-15
# 18  11.117.460/0001-10  2019-04-26
# 39  26.789.018/0001-08  2019-05-22
# 36  30.815.523/0001-57  2019-05-22
# 41  11.266.581/0001-24  2019-05-27
# 19  07.295.481/0001-59  2019-04-26
# 37  20.672.012/0001-70  2019-05-22
# 40  03.111.629/0001-05  2019-05-27
# 32  07.902.589/0001-62  2019-05-21
# 38  19.955.230/0001-32  2019-05-22
# 9   26.386.968/0001-91  2019-04-13
# 33  24.500.363/0001-54  2019-05-21
# 34  30.520.284/0001-08  2019-05-21
# 26  04.015.113/0001-11  2019-05-15
# 30  13.409.564/0001-24  2019-05-21
# 42  20.694.842/0001-06  2019-05-30
#
#                                     MOTIVO DO CONTATO  \
# 2                                Queda no faturamento
# 24                               Queda no faturamento
# 4                                Queda no faturamento
# 5                      Sem Pagamento desde 08/05/2019
# 6                                Queda no faturamento
# 10                               Queda no faturamento
# 7                                Queda no faturamento
# 11                               Queda no faturamento
# 12                               Queda no faturamento
# 29                     Sem Pagamento desde 29/04/2019
# 35                               Queda no faturamento
# 13                               Queda no faturamento
# 8                      Sem Pagamento desde 13/03/2019
# 1   Queda no faturamento + ultimo movimento dia 06/03
# 28  Queda no faturamento + ultimo movimento dia 17/05
# 31                               Queda no faturamento
# 0                                Queda no faturamento
# 23                               Queda no faturamento
# 22                               Queda no faturamento
# 21                               Não voltou a faturar
# 15                     Sem Pagamento desde 16/04/2019
# 17                     Sem Pagamento desde 09/04/2019
# 16                     Sem Pagamento desde 09/04/2019
# 14                     Sem Pagamento desde 03/04/2019
# 3                                Queda no faturamento
# 27                               Queda no faturamento
# 20                               Não voltou a faturar
# 25                               Queda no faturamento
# 18                               Queda no faturamento
# 39                               Queda no faturamento
# 36  Queda no faturamento + ultimo movimento dia 08/05
# 41                               Queda no faturamento
# 19                               Queda no faturamento
# 37                               Queda no faturamento
# 40  Queda no faturamento + ultimo movimento dia 16/05
# 32                               Queda no faturamento
# 38                     Sem Pagamento desde 22/04/2019
# 9                        Sem Pagamento desde a cessao
# 33                               Queda no faturamento
# 34                               Queda no faturamento
# 26                     Sem Pagamento desde 08/05/2019
# 30                     Sem Pagamento desde 29/04/2019
# 42  Queda no faturamento + ultimo movimento dia 15/05
#
#                  DATA_CONTATO                         JUSTIFICATIVA DO ALERTA  \
# 2                       43540                              Queda no movimento
# 24                      43605  Queda no movimento, mudança estrutural no site
# 4                       43556                      Queda nas vendas de cartão
# 5                       43556                                   Fechou a Loja
# 6                       43545                              Queda no movimento
# 10                      43578                              Queda no movimento
# 7                       43545                              Queda no movimento
# 11                      43578                              Queda no movimento
# 12                      43581                              Queda no movimento
# 29                      43607                              Queda no movimento
# 35                      43607                     Promoção pagamentos a vista
# 13                      43581                      Parou de fazer antecipação
# 8               16/04 a 24/05                                Fechou a Empresa
# 1                       43538                       Problemas com o site Elo7
# 28  Sem contato até o momento   Queda no movimento, problemas com o site Elo7
# 34                  Espera para tomada de faturamento  30520284000108
# 26                       Proposta de pagamento aceita  04015113000111
# 30                  Ficou de pagar R$ 960,00 em 31/05  13409564000124
# 42                       Proposta de pagamento aceita  20694842000106
#
#    dataDesembolso
# 2      2018-09-13
# 24     2018-09-13
# 4      2018-10-24
# 5      2018-10-24
# 6      2018-11-05
# 10     2018-11-05
# 7      2018-12-04
# 11     2018-12-04
# 12     2018-12-05
# 29     2018-12-05
# 35     2018-12-13
# 13     2018-12-13
# 8      2018-12-21
# 1      2019-01-08
# 28     2019-01-08
# 31     2019-02-07
# 0      2019-02-14
# 23     2019-02-14
# 22     2019-02-27
# 21     2019-02-27
# 15     2019-02-27
# 17     2019-02-27
# 16     2019-02-27
# 14     2019-02-28
# 3      2019-02-28
# 27     2019-02-28
# 20     2019-02-28
# 25     2019-02-28
# 18     2019-02-28
# 39     2019-03-08
# 36     2019-03-13
# 41     2019-03-15
# 19     2019-03-15
# 37     2019-03-15
# 40     2019-03-18
# 32     2019-03-21
# 38     2019-03-22
# 9      2019-03-22
# 33     2019-03-28
# 34     2019-04-01
# 26     2019-04-11
# 30     2019-04-17
# 42     2019-04-24

# %%
res[res['dataDesembolso']<datetime(2019, 1,1).date()].shape
# Out:
# (13, 10)

# %%
res.shape[0] - 13
# Out:
# 30

# %%
res.head()
# Out:
#     PRODUTO                                 EMPRESA                CNPJ  \
# 0  WIRECARD           CLAUDEMIR DE SOUZA FRANCISCO   12.549.813/0001-14
# 1  WIRECARD                  LITTLE BABY GYN EIRELI  21.666.147/0001-95
# 2  WIRECARD   SAFETICKET SERVICOS PARA EVENTOS LTDA  26.555.778/0001-50
# 3  WIRECARD   SAFETICKET SERVICOS PARA EVENTOS LTDA  26.555.778/0001-50
# 4  TOMATICO  TISSAH BRAND COMERCIO DE ROUPAS EIRELI  28.900.576/0001-24
#
#   DATA_ALERTA                                  MOTIVO DO CONTATO DATA_CONTATO  \
# 0  2019-03-13                               Queda no faturamento        43538
# 1  2019-03-13  Queda no faturamento + ultimo movimento dia 06/03        43538
# 2  2019-03-13                               Queda no faturamento        43540
# 3  2019-03-13                               Queda no faturamento        43540
# 4  2019-03-20                               Queda no faturamento        43556
#
#       JUSTIFICATIVA DO ALERTA               RESULTADO DO CONTATO  \
# 0          Queda no movimento        Aumento de retenção para 8%
# 1   Problemas com o site Elo7  Espera para tomada de faturamento
# 2          Queda no movimento       Aumento de retenção para 10%
# 3          Queda no movimento       Aumento de retenção para 10%
# 4  Queda nas vendas de cartão       Aumento de retenção para 20%
#
#               doc dataDesembolso
# 0  12549813000114     2019-02-14
# 1  21666147000195     2019-01-08
# 2  26555778000150     2018-09-13
# 3  26555778000150     2019-02-28
# 4  28900576000124     2018-10-24

# %%
def get_numero_consulta(cnpj):
    engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
    con = engine.connect()
    query = "select data_ref, numero_consulta from consultas_idwall_operacoes where cnpj_cpf='{}'".format(cnpj)
    df = pd.read_sql(query, con)
    numero = df[df['data_ref']==df['data_ref'].max()]["numero_consulta"].iloc[0]
    con.close()
    
    return numero
    

def get_details(numero):
    URL = "https://api-v2.idwall.co/relatorios"
    authorization = "b3818f92-5807-4acf-ade8-78a1f6d7996b"
    url_details = URL + "/{}".format(numero) + "/dados"
    while True:
        dets = requests.get(url_details, headers={"authorization": authorization})
        djson = dets.json()
        sleep(1)
        if djson['result']['status'] == "CONCLUIDO":
            break

    return dets.json()

def get_idade(cnpj):
    numero = get_numero_consulta(cnpj)
    print(numero)
    js = get_details(numero)
    data_abertura = js.get("result").get("cnpj").get("data_abertura")
    data_abertura = data_abertura.replace("/", "-")
    data = datetime.strptime(data_abertura, "%d-%m-%Y").date()
    idade = ((datetime.now().date() - data).days/366)
    idade_empresa = np.around(idade, 2)
    return idade_empresa

# %%
get_idade("12549813000114")
# Out:
# 27d21972-0874-4681-926f-a5ff73400c92
# 8.69

# %%
res
# Out:
#          PRODUTO                                    EMPRESA  \
# 0       WIRECARD              CLAUDEMIR DE SOUZA FRANCISCO
# 1       WIRECARD                     LITTLE BABY GYN EIRELI
# 2       WIRECARD      SAFETICKET SERVICOS PARA EVENTOS LTDA
# 3       WIRECARD      SAFETICKET SERVICOS PARA EVENTOS LTDA
# 4       TOMATICO     TISSAH BRAND COMERCIO DE ROUPAS EIRELI
# 5       TOMATICO     TISSAH BRAND COMERCIO DE ROUPAS EIRELI
# 6       TOMATICO  TDG COSMETICOS - COMERCIO E SERVICOS LTDA
# 7       TOMATICO  TDG COSMETICOS - COMERCIO E SERVICOS LTDA
# 8       TOMATICO                  ADNAEL SANTOS DE OLIVEIRA
# 9   CREDITOVELOZ                      HERMANN MOTORS EIRELI
# 10      TOMATICO  TDG COSMETICOS - COMERCIO E SERVICOS LTDA
# 11      TOMATICO  TDG COSMETICOS - COMERCIO E SERVICOS LTDA
# 12      TOMATICO                           THAIS SCARLATE
# 13      TOMATICO         NISMOCAR SERVICOS AUTOMOTIVOS LTDA
# 14  CREDITOVELOZ              RICHARD ROCHA SANTOS VEICULOS
# 15  CREDITOVELOZ                     JEFERSON DE PAULA LIMA
# 16  CREDITOVELOZ                          K F C BELEM MOTOS
# 17  CREDITOVELOZ             EVO MOTO CENTER COMERCIO LTDA
# 18  CREDITOVELOZ                NOVA ERA DESPACHANTES LTDA
# 19  CREDITOVELOZ       WR PNEUS SERVICOS E ACESSORIOS LTDA
# 20  CREDITOVELOZ              RICHARD ROCHA SANTOS VEICULOS
# 21  CREDITOVELOZ             EVO MOTO CENTER COMERCIO LTDA
# 22  CREDITOVELOZ                          K F C BELEM MOTOS
# 23      WIRECARD              CLAUDEMIR DE SOUZA FRANCISCO
# 24      WIRECARD      SAFETICKET SERVICOS PARA EVENTOS LTDA
# 25      WIRECARD      SAFETICKET SERVICOS PARA EVENTOS LTDA
# 26  CREDITOVELOZ                            CFC ALBUQUERQUE
# 27  CREDITOVELOZ                NOVA ERA DESPACHANTES LTDA
# 28      WIRECARD                     LITTLE BABY GYN EIRELI
# 29      TOMATICO                           THAIS SCARLATE
# 30      TOMATICO                TATIANA DE ARAUJO TRINDADE
# 8                      Sem Pagamento desde 13/03/2019
# 9                        Sem Pagamento desde a cessao
# 10                               Queda no faturamento
# 11                               Queda no faturamento
# 12                               Queda no faturamento
# 13                               Queda no faturamento
# 14                     Sem Pagamento desde 03/04/2019
# 15                     Sem Pagamento desde 16/04/2019
# 16                     Sem Pagamento desde 09/04/2019
# 17                     Sem Pagamento desde 09/04/2019
# 18                               Queda no faturamento
# 19                               Queda no faturamento
# 20                               Não voltou a faturar
# 21                               Não voltou a faturar
# 22                               Queda no faturamento
# 23                               Queda no faturamento
# 24                               Queda no faturamento
# 25                               Queda no faturamento
# 26                     Sem Pagamento desde 08/05/2019
# 27                               Queda no faturamento
# 28  Queda no faturamento + ultimo movimento dia 17/05
# 29                     Sem Pagamento desde 29/04/2019
# 30                     Sem Pagamento desde 29/04/2019
# 31                               Queda no faturamento
# 32                               Queda no faturamento
# 33                               Queda no faturamento
# 34                               Queda no faturamento
# 35                               Queda no faturamento
# 36  Queda no faturamento + ultimo movimento dia 08/05
# 37                               Queda no faturamento
# 38                     Sem Pagamento desde 22/04/2019
# 39                               Queda no faturamento
# 40  Queda no faturamento + ultimo movimento dia 16/05
# 41                               Queda no faturamento
# 42  Queda no faturamento + ultimo movimento dia 15/05
#
#                  DATA_CONTATO                         JUSTIFICATIVA DO ALERTA  \
# 0                       43538                              Queda no movimento
# 1                       43538                       Problemas com o site Elo7
# 2                       43540                              Queda no movimento
# 3                       43540                              Queda no movimento
# 4                       43556                      Queda nas vendas de cartão
# 5                       43556                                   Fechou a Loja
# 6                       43545                              Queda no movimento
# 7                       43545                              Queda no movimento
# 8               16/04 a 24/05                                Fechou a Empresa
# 9               15/04 a 03/05                              Queda no movimento
# 10                      43578                              Queda no movimento
# 11                      43578                              Queda no movimento
# 12                      43581                              Queda no movimento
# 13                      43581                      Parou de fazer antecipação
# 14                      43582                      Queda nas vendas de cartão
# 15  Sem contato até o momento                                    Sem resposta
# 16                      43582                              Queda no movimento
# 17                      43582                              Queda no movimento
# 18                      43582                      Queda nas vendas de cartão
# 19                      43582                              Queda no movimento
# 20              16/05 a 28/05                         Sem movimento no cartão
# 21              16/05 a 22/05                      Queda nas vendas de cartão
# 22                      43607                              Queda no movimento
# 23                      43601   Queda no movimento, problemas com o site Elo7
# 24                      43605  Queda no movimento, mudança estrutural no site
# 25                      43605  Queda no movimento, mudança estrutural no site
# 26                      43571                              Queda no movimento
# 27                      43615                                 Movimento fraco
# 28  Sem contato até o momento   Queda no movimento, problemas com o site Elo7
# 29                      43607                              Queda no movimento
# 30                      43612                             Maquininha quebrada
# 31                      43612                              Queda no movimento
# 32                      43612                                    Sem resposta
# 33                      43612                 Muitas taxas na venda de cartão
# 34                      43612                              Queda no movimento
# 35                      43607                     Promoção pagamentos a vista
# 36                      43607                    Mudança de local de trabalho
# 37                      43607                      Queda nas vendas de cartão
# 38                      43607                             Maquininha quebrada
# 39                      43607                      Queda nas vendas de cartão
# 40  Sem contato até o momento                                    Sem resposta
# 41                      43612                              Queda no movimento
# 42                      43615                 Muitas taxas na venda de cartão
