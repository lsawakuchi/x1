# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine

# %%
df = pd.read_excel("atualizacao_201905_justa.xlsx")

# %%
df["data"] = datetime(2019, 5, 1).date()

# %%
df["cnpj"].iloc[0]
# Out:
# 24339800000108

# %%
df["cnpj"] = df["cnpj"].astype(str)

# %%
df["cnpj"] = df.apply(lambda x : "00" + x["cnpj"] if len(x["cnpj"])==12 else
                      ("0" + x["cnpj"] if len(x["cnpj"])==13 else x["cnpj"]), axis=1)

# %%
df["cnpj"] = df.apply(lambda x : "0" + x["cnpj"] if len(x["cnpj"])==10 else x["cnpj"], axis=1)

# %%
df["flag_cnpj"] = df.apply(lambda x : int(len(x["cnpj"])==14), axis=1)

# %%
df["data_posicao"] = datetime.now().date()
df["flag_aprovacao"] = None

# %%
df.rename(columns={"valor_liquido" : "valor"}, inplace=True)

# %%
engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
con = engine.connect()
df.to_sql("fluxo_justa", schema="varejo", con=con, if_exists='append', index=False)
con.close()

# %%
engine = create_engine("mysql+pymysql://capmaster:#jackpot123#@captalysdev.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
con = engine.connect()
df.to_sql("fluxo_justa", schema="varejo", con=con, if_exists='append', index=False)
con.close()

# %%
from sqlalchemy import create_engine
from pricing.service.scoring.dscore import DScoring

# %%
from pricing.service.scoring.lscore import LScoring
from pricing.utils import formata_cnpj
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta

class PreAnalysis(object):
    def __init__(self, cnpj, produto):
        self.cnpj = cnpj
        self.produto = produto
        self.dados = None
        self.flag_faturamento = None
        self.flag_transacoes = None
        self.flag_cheques = None
        self.flag_dividas = None
        self.data_consulta = None
        self.scoring = None
        
    def get_dados(self):
        if self.produto in ["tomatico", "padrao"]:
            engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/credito-digital")
            con = engine.connect()
        else:
            engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
            con = engine.connect()
        
        query_wirecard = "select cnpj, data, valor, numero_transacoes from fluxo_wirecard where cnpj='{}'".format(self.cnpj)
        query_pv = "select cpf_cnpj as cnpj, data, valor, numero_transacoes from fluxo_pv where cpf_cnpj='{}'".format(formata_cnpj(self.cnpj))
        query_tomatico = "select cnpj, dataFluxo as data, valorFluxo as valor from tb_Fluxo where cnpj='{}'".format(self.cnpj)
        query_justa = "select cnpj, data, valor from fluxo_justa where cnpj='{}'".format(self.cnpj)
        dict_query = {"tomatico" : query_tomatico,
                    "padrao" : query_tomatico,
                    "wirecard" : query_wirecard,
                    "moip" : query_wirecard,
                    "pagueveloz" : query_pv,
                    "justa" : query_justa
                }
        query = dict_query.get(self.produto)
        df = pd.read_sql(query, con)
        con.close()
        df = df.groupby("data").sum().reset_index()
        try:
            df["data"] = df.apply(lambda x : x["data"].date(), axis=1)
        except:
            pass
        self.dados = df
        
        return
    
    @staticmethod
    def mensaliza(df):
        df.index = pd.to_datetime(df.data)
        df = df.resample('MS').sum().reset_index()
        return df
    
    def check_faturamento(self):
        df = self.dados[["data", "valor"]]
        df = self.mensaliza(df)
        df = df.sort_values("data", ascending=False).iloc[:6, :]
        df["data"] = df.apply(lambda x : x["data"].date(), axis=1)
        flag_faturamento = int((len(df)==6) and (0 not in df["valor"].tolist()) and (df["data"].max()==datetime.now().date().replace(day=1) - relativedelta(months=1)))
        self.flag_faturamento = flag_faturamento
        return
    
    def check_transacoes(self):
        try:
            df = self.dados[["data", "numero_transacoes"]]
            df = self.mensaliza(df)
            df = df.iloc[:12, :]
            media_transacoes = df["numero_transacoes"].mean()
            flag_transacoes = int(media_transacoes > 12)
            self.flag_transacoes = flag_transacoes
        except:
            self.flag_transacoes = 1
        return
    
    def get_dividas(self):
        engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
        con = engine.connect()
        query = "select * from consultas_idwall_operacoes where cnpj_cpf='{}'".format(self.cnpj)
        df = pd.read_sql(query, con)
        con.close()
        if df.empty:
            return df
        df = df[df['data_ref']==df['data_ref'].max()]
        lista_consultas = df['numero_consulta'].unique().tolist()
        print(lista_consultas)
        df = df[(df['data_ref']==df['data_ref'].max()) & (df['numero_consulta']==lista_consultas[0])]
        return df
    
    def check_cheques(self):
        dfdiv = self.get_dividas()
        
        if dfdiv.empty:
            flag_cheques = 1
            data_consulta = None
        else:
            flag_cheques = int('cheques' not in dfdiv["tipo"].tolist())
            data_consulta = dfdiv["data_ref"].max()
        self.flag_cheques = flag_cheques
        self.data_consulta = data_consulta
        return 
    
    def check_dividas(self):
        try:
            ds = DScoring(cnpj=self.cnpj, produto=self.produto)
            res, dfcalc = ds.calcula()
        
            self.scoring = res
            if not len(res) == 0:
                lista_ = list(res.keys())
                segmentos = [el for el in lista_ if el not in ["lscore", "dscore", "score"]]

                elegibilidade = [res.get(el) for el in segmentos]

                flag_dividas = int(0 not in elegibilidade)
            else:
                flag_dividas = 1

            self.flag_dividas = flag_dividas
        except:
            self.flag_dividas = 1
        return
    
    def analisa(self):
        self.get_dados()
        self.check_faturamento()
#         self.check_transacoes()
        self.check_cheques()
        self.check_dividas()
        return

# %%
engine = create_engine("mysql+pymysql://capMaster:#jackpot123#@captalys.cmrbivuuu7sv.sa-east-1.rds.amazonaws.com:23306/varejo")
con = engine.connect()
dfw = pd.read_sql("select distinct cnpj, flag_cnpj from fluxo_justa", con)
con.close()

# %%
dfw = dfw[dfw["flag_cnpj"]==1]

# %%
lista_analise = dfw["cnpj"].unique().tolist()

# %%
from tqdm import tqdm_notebook

resp = []
lista_score = []
err = []
for el in tqdm_notebook(lista_analise):
    try:
        print(el)
        pa = PreAnalysis(cnpj=el, produto='justa')
        pa.analisa()
        _df = pd.DataFrame()
        _df["cnpj"] = [el]
        _df["flag_faturamento"] = [pa.flag_faturamento]
#         _df["flag_transacoes"] = [pa.flag_transacoes]
        _df["flag_cheques"] = [pa.flag_cheques]
        _df["flag_dividas"] = [pa.flag_dividas]
        _df["historico"] = [len(pa.dados)]
        _df["data_consulta"] = [pa.data_consulta]
        resp.append(_df)
        lista_score.append({el : pa.scoring})
    except:
        err.append(el)
# Out:
# HBox(children=(IntProgress(value=0, max=1570), HTML(value='')))
# 00121514000103
#         data  valor
# 0 2019-05-01    0.0
# 00147048000127
# ['b124dde4-f374-480e-a114-bc490fbb3308']
#         data    valor
# 0 2019-03-01  20710.1
# 1 2019-04-01  44418.7
# 2 2019-05-01  33867.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 715.6151515151518
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 00147569000184
#         data  valor
# 0 2019-05-01    0.0
# 00150714000186
# ['7d269dc5-8b40-48df-aeef-a1ed078eab21']
#         data     valor
# 0 2018-11-01   3995.38
# 1 2018-12-01   4311.87
# 2 2019-01-01   9195.56
# 3 2019-02-01  11127.60
# 4 2019-03-01  12082.30
# 5 2019-04-01   7528.29
# 6 2019-05-01   7666.94
# probabilidade_zeros :0.0
# SCORE INICIAL : 693.4666666666667
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 00160703000187
#         data    valor
# 0 2019-03-01  1547.75
# 1 2019-04-01  1049.15
# 2 2019-05-01  8005.61
# probabilidade_zeros :0.0
# SCORE INICIAL : 843.6666666666666
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 00327378000102
#         data     valor
# 0 2019-03-01   1330.53
# 1 2019-04-01  15184.30
# 2 2019-05-01   8304.32
# probabilidade_zeros :0.0
# SCORE INICIAL : 613.1999999999999
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 00431292000117
#         data  valor
# 0 2019-05-01    0.0
# 00440094000110
#         data  valor
# 0 2019-05-01   2.07
# 00451803000162
#         data  valor
# 0 2019-05-01    0.0
# 00451803000324
#         data  valor
# 0 2019-05-01    0.0
# 00489194000130
#         data     valor
# 0 2018-11-01   97156.5
# 1 2018-12-01  127135.0
# 2 2019-01-01  111358.0
# 3 2019-02-01   97240.0
# 4 2019-03-01   46926.9
# 5 2019-04-01       0.0
# 6 2019-05-01       0.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 275.6666666666667
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 00686810000143
# ['ae8da94c-4f64-4c1a-bcce-d2730d9a5165']
#         data    valor
# 0 2018-11-01  17046.6
# 1 2018-12-01  28100.6
# 2 2019-01-01  23499.0
# 3 2019-02-01  18850.0
# 4 2019-03-01  15413.2
# 5 2019-04-01  18899.9
# 6 2019-05-01  23789.7
# probabilidade_zeros :0.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 00704375000132
#         data  valor
# 0 2019-02-01   0.01
# 1 2019-03-01   0.00
# 2 2019-04-01   0.00
# 3 2019-05-01   0.00
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 00729716000124
#         data    valor
# 0 2018-12-01   176.74
# 1 2019-01-01   923.35
# 2 2019-02-01  2248.07
# 3 2019-03-01     0.00
# 4 2019-04-01     0.00
# 5 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 110.33333333333333
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 00753909000110
#         data  valor
# 0 2019-05-01    0.0
# 00842847000113
# ['3ffe6232-edd9-4db1-b856-da608df3f47e']
#         data    valor
# 0 2018-11-01  15039.2
# 1 2018-12-01  15871.7
# 2 2019-01-01  15352.9
# 3 2019-02-01  17385.3
# 4 2019-03-01  17599.8
# 5 2019-04-01  11693.3
# 6 2019-05-01  10379.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 675.8151515151516
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 00844335000196
#         data  valor
# 0 2019-02-01   0.01
# 1 2019-03-01   0.00
# 2 2019-04-01   0.00
# 3 2019-05-01   0.00
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 00844335000609
#         data  valor
# 0 2018-11-01   0.98
# 1 2018-12-01   0.00
# 2 2019-01-01   0.00
# 3 2019-02-01   0.01
# 4 2019-03-01   0.00
# 5 2019-04-01   0.00
# 6 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 00874646000106
#         data     valor
# 0 2018-11-01  12753.10
# 1 2018-12-01  66546.60
# 2 2019-01-01   2067.57
# 3 2019-02-01   1408.97
# 4 2019-03-01   3522.24
# 5 2019-04-01   7092.96
# 6 2019-05-01   4221.44
# probabilidade_zeros :0.0
# SCORE INICIAL : 61.333333333333336
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 00874646000289
# ['303e80f5-8446-43f6-bfbb-7be8957054b9']
#         data    valor
# 0 2018-11-01  7064.19
# 1 2018-12-01  2752.12
# 2 2019-01-01  3386.54
# 3 2019-02-01  3849.75
# 4 2019-03-01  1936.75
# 5 2019-04-01  5938.08
# 6 2019-05-01  8361.35
# probabilidade_zeros :0.0
# SCORE INICIAL : 858.3515151515152
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 00874646000360
#         data     valor
# 0 2018-11-01  12836.20
# 1 2018-12-01  57985.70
# 2 2019-01-01   7824.55
# 3 2019-02-01   7865.06
# 4 2019-03-01  10831.00
# 5 2019-04-01   8386.96
# 6 2019-05-01   7062.71
# probabilidade_zeros :0.0
# SCORE INICIAL : 219.53872053872053
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 00874646000440
#         data    valor
# 0 2018-11-01  5280.32
# 1 2018-12-01  2394.89
# 2 2019-01-01  5329.34
# 3 2019-02-01  3520.42
# 4 2019-03-01  3778.00
# 5 2019-04-01  2888.30
# 6 2019-05-01  6820.99
# probabilidade_zeros :0.0
# SCORE INICIAL : 849.6333333333336
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 00905636000182
#         data  valor
# 0 2019-05-01    0.0
# 00910459000122
#         data  valor
# 0 2019-05-01    0.0
# 00934773000145
# ['4b5dab01-ca33-458f-b80a-46d96e598767']
#         data    valor
# 0 2018-11-01  16057.4
# 1 2018-12-01  51227.7
# 2 2019-01-01  34836.9
# 3 2019-02-01  33232.4
# 4 2019-03-01  26755.9
# 5 2019-04-01  64251.0
# 6 2019-05-01  29829.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 663.6212121212121
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 00941051000118
#         data  valor
# 0 2019-05-01    0.0
# 01046339000191
#         data    valor
# 0 2018-11-01  1223.04
# 1 2018-12-01  4717.32
# 2 2019-01-01  5869.41
# 3 2019-02-01  3695.99
# 4 2019-03-01  3354.84
# 5 2019-04-01  3927.43
# 6 2019-05-01  2269.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 631.1515151515154
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01080801000177
#         data  valor
# 0 2019-05-01    0.0
# 01098518000172
#         data  valor
# 0 2019-05-01    0.0
# 01113005000193
#         data    valor
# 0 2019-05-01  5098.52
# 01113005000274
#         data    valor
# 0 2019-03-01  15428.6
# 1 2019-04-01  22234.3
# 2 2019-05-01  29734.7
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 01137255000325
#         data  valor
# 0 2019-05-01    0.0
# 01147087000197
# ['d35d7d60-675b-40e9-804e-ca206eb84da4']
#         data    valor
# 0 2018-11-01  2513.00
# 1 2018-12-01  7246.60
# 2 2019-01-01  4818.61
# 3 2019-02-01  3733.46
# 4 2019-03-01  4397.72
# 5 2019-04-01  8299.86
# 6 2019-05-01  6547.37
# probabilidade_zeros :0.0
# SCORE INICIAL : 744.3151515151516
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# /home/lidi/Documents/Captalys/Gitlab/api-pricing/pricing/service/scoring/dscore.py:147: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   df = pd.concat(fr)
# 01170960000162
#         data  valor
# 0 2019-05-01    0.0
# 01203607000131
#         data  valor
# 0 2019-05-01    0.0
# 01203607000212
#         data  valor
# 0 2019-05-01    0.0
# 01234695000139
#         data  valor
# 0 2019-05-01    0.0
# 01242387000155
# ['d9f7c86d-c0e5-4edb-a424-08eeeaac9b06']
#         data     valor
# 0 2018-11-01   6800.82
# 1 2018-12-01  27024.30
# 2 2019-01-01  14727.50
# 3 2019-02-01  10245.60
# 4 2019-03-01  31876.50
# 5 2019-04-01  28434.70
# 6 2019-05-01  18990.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 674.4727272727273
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01246934000170
# ['feb104b2-86c0-4c88-8acb-264aef800343']
#         data     valor
# 0 2018-11-01    253.52
# 1 2018-12-01   7720.57
# 2 2019-01-01  27407.00
# 3 2019-02-01  25582.40
# 4 2019-03-01  32220.20
# 5 2019-04-01  37672.90
# 6 2019-05-01  46999.10
# probabilidade_zeros :0.14285714285714285
# SCORE INICIAL : 853.221212121212
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01344220000103
#         data  valor
# 0 2019-05-01    0.0
# 01368548000100
#         data  valor
# 0 2019-05-01    0.0
# 01368548000151
# ['ef5d8bd2-d325-47fd-ab54-b479403189c9']
#         data     valor
# 0 2018-11-01  14072.30
# 1 2018-12-01   4690.91
# 2 2019-01-01   9496.40
# 3 2019-02-01   4531.23
# 4 2019-03-01   3843.55
# 5 2019-04-01  29575.40
# 6 2019-05-01   6799.54
# probabilidade_zeros :0.0
# SCORE INICIAL : 553.4492929292929
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01449511000158
# ['5c5fe2a4-64ba-4236-8206-21a0b5255b68']
#         data     valor
# 0 2018-11-01    418.90
# 1 2018-12-01  17639.20
# 2 2019-01-01  17208.40
# 3 2019-02-01   8571.47
# 4 2019-03-01   8135.20
# 5 2019-04-01   1988.65
# 6 2019-05-01     97.61
# probabilidade_zeros :0.14285714285714285
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01475236000147
#         data  valor
# 0 2019-05-01    0.0
# 01499203000137
#         data     valor
# 0 2019-03-01   1876.17
# 1 2019-04-01  20895.10
# 2 2019-05-01      0.00
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 01575727000160
#         data    valor
# 0 2018-11-01  1710.90
# 1 2018-12-01  3260.38
# 2 2019-01-01  1234.70
# 3 2019-02-01   441.65
# 4 2019-03-01  1020.37
# 5 2019-04-01  1624.80
# 6 2019-05-01   592.06
# probabilidade_zeros :0.0
# SCORE INICIAL : 287.93602693602696
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01642844000107
#         data  valor
# 0 2019-05-01    0.0
# 01698637000166
# ['185f0c57-d4c7-4417-aa15-d770aa3aedaf']
#         data     valor
# 0 2018-11-01   78300.6
# 1 2018-12-01  152685.0
# 2 2019-01-01   49690.2
# 3 2019-02-01   51065.2
# 4 2019-03-01   61952.6
# 5 2019-04-01   42298.7
# 6 2019-05-01   71141.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 671.4969696969697
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01698637000328
# ['a35f72d1-8c95-4ff7-9bbe-2720bcec4931']
#         data    valor
# 0 2018-11-01  38085.8
# 1 2018-12-01  78370.0
# 2 2019-01-01  26429.8
# 3 2019-02-01  42485.8
# 4 2019-03-01  29908.6
# 5 2019-04-01  24395.6
# 6 2019-05-01  29730.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 648.9030303030303
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01721348000130
#         data  valor
# 0 2019-05-01    0.0
# 01760044000182
# ['db8fe028-a3ff-40e7-a194-15097b2add73']
#         data     valor
# 0 2018-11-01   2751.15
# 1 2018-12-01  16515.10
# 2 2019-01-01   5899.02
# 3 2019-02-01  47292.10
# 4 2019-03-01  27005.90
# 5 2019-04-01  50340.50
# 6 2019-05-01  11347.90
# probabilidade_zeros :0.14285714285714285
# SCORE INICIAL : 355.6127946127947
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 01800741000110
#         data  valor
# 0 2019-05-01    0.0
# 01807998000101
#         data  valor
# 0 2019-05-01    0.0
# 01916117000182
#         data  valor
# 0 2019-05-01    0.0
# 02012558000112
#         data    valor
# 0 2018-11-01  2516.21
# 1 2018-12-01  2935.46
# 2 2019-01-01  6107.16
# 3 2019-02-01  6185.22
# 4 2019-03-01  3534.04
# 5 2019-04-01  2759.30
# 6 2019-05-01  4830.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 730.5212121212122
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 02030832000186
#         data    valor
# 0 2019-03-01  5337.06
# 1 2019-04-01   117.75
# 2 2019-05-01   117.47
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 02061925000178
#         data     valor
# 0 2018-11-01  17054.10
# 1 2018-12-01  14706.90
# 2 2019-01-01  33308.90
# 3 2019-02-01  14618.60
# 4 2019-03-01   9238.49
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 247.33333333333334
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02105111000198
#         data  valor
# 0 2019-05-01    0.0
# 02125400000159
# ['4e88b3f2-075a-4ced-ac55-651f336de640']
#         data    valor
# 0 2018-11-01  31873.7
# 1 2018-12-01  14099.4
# 2 2019-01-01  36872.4
# 3 2019-02-01  28995.7
# 4 2019-03-01  23873.2
# 5 2019-04-01  38987.8
# 6 2019-05-01  31027.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 724.5878787878786
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 02131235000148
#         data  valor
# 0 2018-11-01   0.03
# 1 2018-12-01   0.00
# 2 2019-01-01   0.00
# 3 2019-02-01   0.00
# 4 2019-03-01   0.00
# 5 2019-04-01   0.00
# 6 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02168511000142
#         data     valor
# 0 2019-02-01   5733.89
# 1 2019-03-01  21475.20
# 2 2019-04-01  27593.10
# 3 2019-05-01  23196.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 948.8727272727274
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 02173303000131
#         data   valor
# 0 2018-11-01  7020.5
# 1 2018-12-01  5749.1
# 2 2019-01-01     0.0
# 3 2019-02-01     0.0
# 4 2019-03-01     0.0
# 5 2019-04-01     0.0
# 6 2019-05-01     0.0
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02266154000155
#         data    valor
# 0 2019-03-01  3672.15
# 1 2019-04-01     0.00
# 2 2019-05-01     0.00
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 02319190000130
#         data     valor
# 0 2018-11-01   7234.09
# 1 2018-12-01   2887.27
# 2 2019-01-01  17292.60
# 3 2019-02-01      0.00
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 98.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02341608000105
#         data  valor
# 0 2019-05-01    0.0
# 02407917000130
# ['c201020e-104e-4121-8e47-1ac00c9d95ad']
#         data    valor
# 0 2018-11-01  12048.2
# 1 2018-12-01  10684.9
# 2 2019-01-01  13817.5
# 3 2019-02-01  16632.7
# 4 2019-03-01  19339.1
# 5 2019-04-01  15703.1
# 6 2019-05-01  20219.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 784.5272727272728
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 02414248000124
#         data     valor
# 0 2019-02-01   6710.46
# 1 2019-03-01  14758.30
# 2 2019-04-01  15837.10
# 3 2019-05-01  12977.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 897.7242424242426
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 02445859000130
#         data  valor
# 0 2019-03-01   9.36
# 1 2019-04-01   0.00
# 2 2019-05-01   0.00
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 02533857000100
#         data    valor
# 0 2019-03-01  23586.1
# 1 2019-04-01  27974.5
# 2 2019-05-01  19782.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 464.64646464646466
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 02569733000177
#         data    valor
# 0 2018-11-01  4809.05
# 1 2018-12-01  2020.81
# 2 2019-01-01     0.00
# 3 2019-02-01     0.00
# 4 2019-03-01     0.00
# 5 2019-04-01     0.00
# 6 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 52.333333333333336
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02589023000109
#         data  valor
# 0 2019-05-01    0.0
# 02589023000290
#         data  valor
# 0 2019-05-01    0.0
# 02595814000141
#         data     valor
# 0 2018-12-01  15772.50
# 1 2019-01-01  41733.30
# 2 2019-02-01  30110.10
# 3 2019-03-01   9253.68
# 4 2019-04-01   9847.19
# 5 2019-05-01   3385.42
# probabilidade_zeros :0.0
# SCORE INICIAL : 235.66666666666666
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02731653000257
#         data     valor
# 0 2018-12-01   2245.09
# 1 2019-01-01   2178.28
# 2 2019-02-01   1636.36
# 3 2019-03-01   1223.33
# 4 2019-04-01   7912.15
# 5 2019-05-01  11515.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 871.6666666666666
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02739283000113
#         data  valor
# 0 2019-05-01    0.0
# 02773969000120
#         data    valor
# 0 2018-11-01  6377.38
# 1 2018-12-01  2692.41
# 2 2019-01-01  1423.06
# 3 2019-02-01  1865.35
# 4 2019-03-01   413.01
# 5 2019-04-01     0.00
# 6 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 180.33333333333334
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02801654000220
# ['2fe1a448-6424-47d5-bec3-e068aa0ccd7f']
#         data     valor
# 0 2018-11-01  10430.00
# 1 2018-12-01   5670.52
# 2 2019-01-01  10901.00
# 3 2019-02-01  11893.80
# 4 2019-03-01  11824.00
# 5 2019-04-01  11873.40
# 6 2019-05-01   8151.27
# probabilidade_zeros :0.0
# SCORE INICIAL : 738.7818181818183
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 02802892000170
# ['8a1feee5-916d-4c4e-9187-35cde409a2f7']
#         data     valor
# 0 2018-11-01   7589.99
# 1 2018-12-01   6944.44
# 2 2019-01-01   5772.95
# 3 2019-02-01  12005.80
# 4 2019-03-01  13817.90
# 5 2019-04-01  16967.20
# 6 2019-05-01  18419.90
# probabilidade_zeros :0.0
# SCORE INICIAL : 835.2848484848486
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 02823053000138
#         data  valor
# 0 2019-05-01    0.0
# 02834243000150
#         data     valor
# 0 2018-12-01   7629.83
# 1 2019-01-01   8765.92
# 2 2019-02-01  26154.30
# 3 2019-03-01   8735.17
# 4 2019-04-01  15625.50
# 5 2019-05-01  23161.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 825.781818181818
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02864456000125
#         data  valor
# 0 2019-02-01   0.01
# 1 2019-03-01   0.00
# 2 2019-04-01   0.00
# 3 2019-05-01   0.00
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 02899969000171
#         data    valor
# 0 2018-11-01  1301.21
# 1 2018-12-01  5528.07
# 2 2019-01-01   466.38
# 3 2019-02-01     0.01
# 4 2019-03-01     0.00
# 5 2019-04-01     0.00
# 6 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 41.666666666666664
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 02902878000148
#         data    valor
# 0 2018-12-01     0.06
# 1 2019-01-01     0.00
# 2 2019-02-01   867.58
# 3 2019-03-01  1249.76
# 4 2019-04-01     0.00
# 5 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 116.33333333333333
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 02952926000293
#         data   valor
# 0 2019-01-01  216.46
# 1 2019-02-01    0.00
# 2 2019-03-01    0.00
# 3 2019-04-01    0.00
# 4 2019-05-01    0.00
# probabilidade_zeros :0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 02962064000107
#         data  valor
# 0 2019-05-01    0.0
# 02964225000193
#         data    valor
# 0 2018-12-01  12021.1
# 1 2019-01-01      0.0
# 2 2019-02-01      0.0
# 3 2019-03-01      0.0
# 4 2019-04-01      0.0
# 5 2019-05-01      0.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 03011329000146
#         data     valor
# 0 2018-11-01  18985.10
# 1 2018-12-01  14559.50
# 2 2019-01-01   7090.39
# 3 2019-02-01   1762.18
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 03031088000105
#         data   valor
# 0 2019-01-01  244.25
# 1 2019-02-01    0.00
# 2 2019-03-01    0.00
# 3 2019-04-01    0.00
# 4 2019-05-01    0.00
# probabilidade_zeros :0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 03092428000108
#         data  valor
# 0 2019-05-01    0.0
# 03101708000100
#         data  valor
# 0 2019-05-01    0.0
# 03101708000127
#         data    valor
# 0 2018-11-01  62780.9
# 1 2018-12-01  11073.6
# 2 2019-01-01      0.0
# 3 2019-02-01      0.0
# 4 2019-03-01      0.0
# 5 2019-04-01      0.0
# 6 2019-05-01      0.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 03139670000181
#         data  valor
# 0 2018-11-01    0.1
# 1 2018-12-01    0.0
# 2 2019-01-01    0.0
# 3 2019-02-01    0.0
# 4 2019-03-01    0.0
# 5 2019-04-01    0.0
# 6 2019-05-01    0.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 03139670000424
#         data  valor
# 0 2018-12-01  19.93
# 1 2019-01-01   0.00
# 2 2019-02-01   0.00
# 3 2019-03-01   0.00
# 4 2019-04-01   0.00
# 5 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 03144650000107
#         data  valor
# 0 2019-04-01   0.02
# 1 2019-05-01   0.00
# 03300735000129
# ['2b174507-a620-4006-95fd-68a484922e59']
#         data     valor
# 0 2018-11-01  13108.60
# 1 2018-12-01  14258.00
# 2 2019-01-01  22824.00
# 3 2019-02-01  20834.60
# 4 2019-03-01   9954.06
# 5 2019-04-01  26990.70
# 6 2019-05-01  26320.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 829.4242424242424
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 03335875000132
#         data  valor
# 0 2019-05-01    0.0
# 03339786000164
#         data     valor
# 0 2019-01-01   86522.4
# 1 2019-02-01  101057.0
# 2 2019-03-01   19936.9
# 3 2019-04-01   21524.8
# 4 2019-05-01   34874.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 376.2626262626263
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 03385268000187
#         data    valor
# 0 2019-05-01  17376.2
# 03395792000139
#         data    valor
# 0 2019-05-01  25508.9
# 03457730000104
#         data     valor
# 0 2018-11-01  71874.90
# 1 2018-12-01  66735.50
# 2 2019-01-01  97027.80
# 3 2019-02-01  78402.50
# 4 2019-03-01  28424.00
# 5 2019-04-01   8247.52
# 6 2019-05-01   4398.25
# probabilidade_zeros :0.0
# SCORE INICIAL : 250.33333333333334
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 03474096000118
#         data  valor
# 0 2019-05-01    0.0
# 03497842000199
#         data    valor
# 0 2019-02-01  30898.4
# 1 2019-03-01  18163.1
# 2 2019-04-01  14502.9
# 3 2019-05-01  10763.8
# probabilidade_zeros :0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 03512626000175
#         data     valor
# 0 2019-02-01   5407.85
# 1 2019-03-01  26919.10
# 2 2019-04-01  25441.50
# 3 2019-05-01  32609.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 955.6666666666666
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 03520702000194
#         data    valor
# 0 2018-11-01  7337.13
# 1 2018-12-01  3992.00
# 2 2019-01-01  5227.54
# 3 2019-02-01   855.24
# 4 2019-03-01  2326.28
# 5 2019-04-01  3968.85
# 6 2019-05-01  3601.02
# probabilidade_zeros :0.0
# SCORE INICIAL : 671.8484848484848
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 03526981000101
#         data  valor
# 0 2019-05-01    0.0
# 03535170000169
#         data  valor
# 0 2018-11-01   0.98
# 1 2018-12-01   0.00
# 2 2019-01-01   0.00
# 3 2019-02-01   0.00
# 4 2019-03-01   0.00
# 5 2019-04-01   0.00
# 6 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 03647689000139
#         data    valor
# 0 2019-04-01  42477.6
# 1 2019-05-01  98903.7
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 03687021000115
#         data  valor
# 0 2019-05-01    0.0
# 03690238000184
#         data    valor
# 0 2019-04-01  3132.88
# 1 2019-05-01  4854.99
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 03729616000196
#         data    valor
# 0 2019-04-01  2819.65
# 1 2019-05-01  6479.28
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 03734008000170
#         data    valor
# 0 2019-05-01  7172.56
# 03749323000251
#         data  valor
# 0 2019-05-01    0.0
# 03756929000133
#         data  valor
# 0 2019-05-01    0.0
# 03797726000195
#         data  valor
# 0 2019-05-01    0.0
# 03811285000139
#         data      valor
# 0 2019-01-01       0.01
# 1 2019-02-01  131987.00
# 2 2019-03-01       0.00
# 3 2019-04-01       0.00
# 4 2019-05-01       0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 03825003000152
#         data  valor
# 0 2019-05-01    0.0
# 03825003000233
#         data  valor
# 0 2018-11-01   0.14
# 1 2018-12-01   0.00
# 2 2019-01-01   0.00
# 3 2019-02-01   0.00
# 4 2019-03-01   0.00
# 5 2019-04-01   0.00
# 6 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 03869173000139
#         data    valor
# 0 2018-12-01  4809.05
# 1 2019-01-01  2020.81
# 2 2019-02-01     0.00
# 3 2019-03-01     0.00
# 4 2019-04-01     0.00
# 5 2019-05-01     0.00
# probabilidade_zeros :0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 03895731000130
#         data  valor
# 0 2019-04-01   0.99
# 1 2019-05-01   0.00
# 03907277000190
#         data  valor
# 0 2019-05-01   0.01
# 03941893000168
# ['fa99444a-8c06-428a-a1c2-a90b4de5692c']
#         data     valor
# 0 2019-02-01   9083.85
# 1 2019-03-01  26114.80
# 2 2019-04-01  47192.30
# 3 2019-05-01  55622.60
# probabilidade_zeros :0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 03964035000139
#         data  valor
# 0 2019-05-01    0.0
# 03988811000483
#         data  valor
# 0 2019-05-01    0.0
# 04058732000193
#         data  valor
# 0 2019-05-01    0.0
# 04065545000137
#         data    valor
# 0 2019-05-01  4069.65
# 04070722000173
#         data  valor
# 0 2019-05-01    0.0
# 04070722000254
#         data  valor
# 0 2019-05-01    0.0
# 04070908000122
#         data  valor
# 0 2019-05-01    0.0
# 04120660000167
#         data    valor
# 0 2018-11-01  43806.4
# 1 2018-12-01  47891.6
# 2 2019-01-01  11713.1
# 3 2019-02-01  87605.2
# 4 2019-03-01  17763.0
# 5 2019-04-01  17439.3
# 6 2019-05-01  12898.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 232.33333333333334
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04128022000192
#         data  valor
# 0 2019-05-01    0.0
# 04154314000108
#         data     valor
# 0 2018-11-01  22451.30
# 1 2018-12-01  21046.80
# 2 2019-01-01  26050.60
# 3 2019-02-01   5529.60
# 4 2019-03-01   6110.34
# 5 2019-04-01   4756.90
# 6 2019-05-01   3616.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 241.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04168923000108
#         data    valor
# 0 2018-11-01     0.44
# 1 2018-12-01  2025.20
# 2 2019-01-01  1401.81
# 3 2019-02-01  1739.49
# 4 2019-03-01  1981.08
# 5 2019-04-01  1683.99
# 6 2019-05-01   355.97
# probabilidade_zeros :0.14285714285714285
# SCORE INICIAL : 271.3333333333333
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04211433000147
#         data  valor
# 0 2019-05-01    0.0
# 04232566000108
#         data     valor
# 0 2019-02-01   1660.96
# 1 2019-03-01      0.00
# 2 2019-04-01    784.88
# 3 2019-05-01  11589.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 755.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 04293170000162
# ['0d080e4b-3a55-4a6e-a48c-d1eb01a4d0a5']
#         data     valor
# 0 2018-11-01   87371.5
# 1 2018-12-01  162864.0
# 2 2019-01-01   81023.0
# 3 2019-02-01   97462.2
# 4 2019-03-01  103626.0
# 5 2019-04-01  101782.0
# 6 2019-05-01  108456.0
# probabilidade_zeros :0.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04314714000125
#         data    valor
# 0 2019-05-01  3883.22
# 04321438000122
#         data    valor
# 0 2018-12-01   423.53
# 1 2019-01-01  5505.43
# 2 2019-02-01   206.83
# 3 2019-03-01  3080.12
# 4 2019-04-01   131.75
# 5 2019-05-01   649.94
# probabilidade_zeros :0.0
# SCORE INICIAL : 135.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04356007000100
#         data    valor
# 0 2019-05-01  1697.22
# 04356544000141
#         data  valor
# 0 2018-12-01   0.11
# 1 2019-01-01   0.00
# 2 2019-02-01   0.00
# 3 2019-03-01   0.00
# 4 2019-04-01   0.00
# 5 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 04367325000168
#         data    valor
# 0 2018-12-01  6604.92
# 1 2019-01-01   426.93
# 2 2019-02-01  3164.88
# 3 2019-03-01  1357.45
# 4 2019-04-01   477.16
# 5 2019-05-01  1146.21
# probabilidade_zeros :0.0
# SCORE INICIAL : 217.03703703703704
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04373646000175
#         data  valor
# 0 2019-05-01    0.0
# 04406139000190
#         data  valor
# 0 2019-05-01    0.0
# 04412248000110
#         data  valor
# 0 2019-05-01    0.0
# 04419153000129
#         data    valor
# 0 2018-12-01  9913.57
# 1 2019-01-01     0.00
# 2 2019-02-01     0.00
# 3 2019-03-01     0.00
# 4 2019-04-01     0.00
# 5 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 04419913000106
#         data   valor
# 0 2019-05-01  350.99
# 04462098000150
#         data  valor
# 0 2019-05-01    0.0
# 04473601000172
#         data  valor
# 0 2019-05-01    0.0
# 04474793000131
# ['a0850de8-61ee-4fa7-b32c-a7c75dab33d1']
#         data     valor
# 0 2018-11-01   86725.1
# 1 2018-12-01  117787.0
# 2 2019-01-01   83341.4
# 3 2019-02-01   61009.1
# 4 2019-03-01   63278.5
# 5 2019-04-01   84204.0
# 6 2019-05-01   99516.5
# probabilidade_zeros :0.0
# SCORE INICIAL : 746.1818181818184
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04516904000125
#         data  valor
# 0 2019-05-01    0.0
# 04522672000118
#         data     valor
# 0 2018-11-01   9635.79
# 1 2018-12-01  33052.40
# 2 2019-01-01   3011.88
# 3 2019-02-01      0.00
# 4 2019-03-01    465.59
# 5 2019-04-01  17150.80
# 6 2019-05-01    169.08
# probabilidade_zeros :0.0
# SCORE INICIAL : 125.33333333333333
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04526732000170
#         data     valor
# 0 2018-11-01   5776.11
# 1 2018-12-01   8593.08
# 2 2019-01-01  12114.20
# 3 2019-02-01   1121.10
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01   3396.87
# probabilidade_zeros :0.0
# SCORE INICIAL : 537.5606060606061
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04587016000101
#         data  valor
# 0 2019-05-01    0.0
# 04608458000189
# ['67bd9819-3b4e-4a22-aa89-49c5febd16fa']
#         data    valor
# 0 2018-11-01  26880.6
# 1 2018-12-01  56212.3
# 2 2019-01-01  57116.8
# 3 2019-02-01  37797.3
# 4 2019-03-01  78617.5
# 5 2019-04-01  66646.7
# 6 2019-05-01  52841.9
# probabilidade_zeros :0.0
# SCORE INICIAL : 710.1636363636363
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04615901000149
#         data    valor
# 0 2018-11-01     0.10
# 1 2018-12-01     0.00
# 2 2019-01-01  1225.23
# 3 2019-02-01     0.00
# 4 2019-03-01   694.66
# 5 2019-04-01    88.08
# 6 2019-05-01     0.00
# probabilidade_zeros :0.16666666666666666
# SCORE INICIAL : 91.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04622432000195
#         data     valor
# 0 2018-12-01   6960.63
# 1 2019-01-01  12396.80
# 2 2019-02-01   5335.54
# 3 2019-03-01      0.00
# 4 2019-04-01      0.00
# 5 2019-05-01      0.00
# probabilidade_zeros :0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 04626583000111
#         data     valor
# 0 2019-03-01   1383.54
# 1 2019-04-01  13479.20
# 2 2019-05-01  17653.30
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 04643766000145
# ['a13f68b0-2196-4459-addb-fdf3d187502d']
#         data     valor
# 0 2018-12-01   8441.88
# 1 2019-01-01  22640.70
# 2 2019-02-01  17039.00
# 3 2019-03-01  23569.40
# 4 2019-04-01  23807.20
# 5 2019-05-01  30673.90
# probabilidade_zeros :0.0
# SCORE INICIAL : 840.8727272727274
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04703570000107
#         data     valor
# 0 2018-11-01  14762.20
# 1 2018-12-01  26539.00
# 2 2019-01-01  19677.20
# 3 2019-02-01  16440.00
# 4 2019-03-01  23002.30
# 5 2019-04-01   6044.29
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 313.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04891249000195
#         data    valor
# 0 2018-11-01  10397.2
# 1 2018-12-01  26932.0
# 2 2019-01-01  15798.2
# 3 2019-02-01      0.0
# 4 2019-03-01      0.0
# 5 2019-04-01      0.0
# 6 2019-05-01      0.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 146.66666666666666
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04929149000100
#         data  valor
# 0 2019-05-01    0.0
# 04940306000189
#         data     valor
# 0 2018-11-01  10334.00
# 1 2018-12-01  11971.70
# 2 2019-01-01   9756.40
# 3 2019-02-01   6010.61
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 04943517000175
# ['bb37feec-9a86-44ec-afe4-be54d4ee2c7d']
#         data     valor
# 0 2018-11-01   7035.65
# 1 2018-12-01   8292.30
# 2 2019-01-01  12711.00
# 3 2019-02-01   7682.81
# 4 2019-03-01   8778.21
# 5 2019-04-01   5224.73
# 6 2019-05-01   7748.07
# probabilidade_zeros :0.0
# SCORE INICIAL : 709.1151515151514
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 04943564000119
#         data  valor
# 0 2019-05-01    0.0
# 04968923000192
#         data    valor
# 0 2019-04-01  25194.0
# 1 2019-05-01  18255.9
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 05023840000193
#         data     valor
# 0 2019-03-01  12067.20
# 1 2019-04-01  12293.00
# 2 2019-05-01   9833.89
# probabilidade_zeros :0.0
# SCORE INICIAL : 692.2969696969698
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 05029183000191
#         data     valor
# 0 2019-01-01   7309.62
# 1 2019-02-01  56301.00
# 2 2019-03-01  53609.50
# 3 2019-04-01  45071.30
# 4 2019-05-01  66465.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 839.8424242424243
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 05038413000189
#         data    valor
# 0 2018-12-01  10704.7
# 1 2019-01-01  14067.5
# 2 2019-02-01  17667.5
# 3 2019-03-01  17265.6
# 4 2019-04-01  15513.3
# 5 2019-05-01  22903.3
# probabilidade_zeros :0.0
# SCORE INICIAL : 833.030303030303
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05074012000184
# ['0976b951-4f48-4aea-95d0-18b63b08235f']
#         data      valor
# 0 2018-11-01       0.06
# 1 2018-12-01  218279.00
# 2 2019-01-01   29946.30
# 3 2019-02-01   26716.50
# 4 2019-03-01   32086.30
# 5 2019-04-01   45117.20
# 6 2019-05-01   37414.40
# probabilidade_zeros :0.14285714285714285
# SCORE INICIAL : 472.4424242424241
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05093466000100
# ['c45622dd-56ed-4194-814e-8df503530706']
#         data    valor
# 0 2018-11-01  16574.8
# 1 2018-12-01  11231.4
# 2 2019-01-01  13471.4
# 3 2019-02-01  11607.0
# 4 2019-03-01  14060.9
# 5 2019-04-01  20959.3
# 6 2019-05-01  17018.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 765.690909090909
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05115981000136
# ['0d32962a-9de1-480c-9f73-d4ef6d6cc756']
#         data     valor
# 0 2018-11-01   3301.85
# 1 2018-12-01  18841.90
# 2 2019-01-01   7111.67
# 3 2019-02-01   5303.83
# 4 2019-03-01   6459.27
# 5 2019-04-01  14457.40
# 6 2019-05-01   8153.78
# probabilidade_zeros :0.0
# SCORE INICIAL : 641.7212121212119
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05128220000119
#         data    valor
# 0 2019-05-01  1532.78
# 05145671000164
#         data     valor
# 0 2018-12-01  15588.30
# 1 2019-01-01   5832.30
# 2 2019-02-01    738.05
# 3 2019-03-01  10833.30
# 4 2019-04-01      0.00
# 5 2019-05-01   3616.49
# probabilidade_zeros :0.0
# SCORE INICIAL : 351.8821548821548
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05197286000160
#         data  valor
# 0 2019-05-01    0.0
# 05204387000111
#         data  valor
# 0 2019-05-01    0.0
# 05245408000147
#         data  valor
# 0 2019-02-01  290.5
# 1 2019-03-01    0.0
# 2 2019-04-01    0.0
# 3 2019-05-01    0.0
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 05302893000143
#         data  valor
# 0 2019-05-01    0.0
# 05303147000174
#         data     valor
# 0 2019-02-01      0.01
# 1 2019-03-01  11330.20
# 2 2019-04-01  10544.80
# 3 2019-05-01   4958.11
# probabilidade_zeros :0.0
# SCORE INICIAL : 345.0774410774411
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 05321848000136
#         data     valor
# 0 2018-11-01  11945.00
# 1 2018-12-01   2010.32
# 2 2019-01-01      0.00
# 3 2019-02-01   3415.43
# 4 2019-03-01   9821.09
# 5 2019-04-01  13242.70
# 6 2019-05-01   9657.96
# probabilidade_zeros :0.0
# SCORE INICIAL : 711.8861471861474
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05336959000116
# ['94ce8c1b-fdca-4905-b5ba-126226541d66']
#         data    valor
# 0 2018-11-01  25973.4
# 1 2018-12-01  40821.2
# 2 2019-01-01  22432.1
# 3 2019-02-01  19780.5
# 4 2019-03-01  23515.4
# 5 2019-04-01  26933.8
# 6 2019-05-01  37520.2
# probabilidade_zeros :0.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05403347000107
#         data    valor
# 0 2018-11-01  2533.09
# 1 2018-12-01  5988.79
# 2 2019-01-01  4537.08
# 3 2019-02-01  6516.95
# 4 2019-03-01  3416.78
# 5 2019-04-01  1809.26
# 6 2019-05-01  1078.36
# probabilidade_zeros :0.0
# SCORE INICIAL : 282.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05432809000106
#         data     valor
# 0 2019-03-01   7790.98
# 1 2019-04-01  24517.70
# 2 2019-05-01  22332.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 960.6666666666666
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 05433844000140
#         data   valor
# 0 2018-11-01   77.74
# 1 2018-12-01  352.03
# 2 2019-01-01  115.84
# 3 2019-02-01  126.31
# 4 2019-03-01  303.02
# 5 2019-04-01   62.60
# 6 2019-05-01  763.93
# probabilidade_zeros :0.0
# SCORE INICIAL : 868.3333333333334
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05436354000105
#         data  valor
# 0 2018-11-01   0.22
# 1 2018-12-01   0.05
# 2 2019-01-01   0.00
# 3 2019-02-01   0.00
# 4 2019-03-01   0.00
# 5 2019-04-01   0.00
# 6 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 8.333333333333334
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05436354000288
#         data   valor
# 0 2018-12-01  257.56
# 1 2019-01-01    0.00
# 2 2019-02-01    0.00
# 3 2019-03-01    0.00
# 4 2019-04-01    0.00
# 5 2019-05-01    0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 05439203000100
#         data     valor
# 0 2019-03-01   5275.03
# 1 2019-04-01  29513.80
# 2 2019-05-01  53618.70
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 05457045000103
#         data    valor
# 0 2018-11-01  1185.55
# 1 2018-12-01   533.65
# 2 2019-01-01     0.00
# 3 2019-02-01     0.00
# 4 2019-03-01     0.01
# 5 2019-04-01     0.00
# 6 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 57.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05582611000109
#         data  valor
# 0 2019-05-01    0.0
# 05583640000195
# ['5f344782-f863-4a7d-b305-648e65cdb29c']
#         data     valor
# 0 2018-11-01  20696.60
# 1 2018-12-01  12057.40
# 2 2019-01-01   9491.89
# 3 2019-02-01  13067.50
# 4 2019-03-01  16180.50
# 5 2019-04-01  14555.30
# 6 2019-05-01  23378.30
# probabilidade_zeros :0.0
# SCORE INICIAL : 834.4
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05590801000410
#         data  valor
# 0 2019-05-01    0.0
# 05634767000358
# ['e57c2fcf-0093-45f5-bb9a-86a22500a93c']
#         data     valor
# 0 2018-11-01  56483.60
# 1 2018-12-01  89081.60
# 2 2019-01-01  37709.60
# 3 2019-02-01  14374.70
# 4 2019-03-01  43590.60
# 5 2019-04-01  29673.90
# 6 2019-05-01   2699.58
# probabilidade_zeros :0.0
# SCORE INICIAL : 249.33333333333334
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05678873000171
#         data   valor
# 0 2019-05-01  609.04
# 05696475000188
# ['67c9e14a-dac2-4624-a4b8-840c73104001']
#         data     valor
# 0 2018-12-01   3967.32
# 1 2019-01-01  27185.10
# 2 2019-02-01  19757.60
# 3 2019-03-01  24527.60
# 4 2019-04-01  25091.60
# 5 2019-05-01  34922.70
# probabilidade_zeros :0.0
# SCORE INICIAL : 842.1272727272727
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 05744270000120
#         data     valor
# 0 2019-02-01   3977.35
# 1 2019-03-01  15850.30
# 2 2019-04-01   6628.60
# 3 2019-05-01  19320.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 933.3333333333334
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 05765355000195
#         data     valor
# 0 2019-04-01  14254.00
# 1 2019-05-01   2717.27
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 05766218000175
# ['1e2bb877-6d0d-4e0b-a2c8-a9a4eeafcd55']
#         data     valor
# 0 2018-11-01   4106.04
# 1 2018-12-01   5137.21
# 2 2019-01-01   2965.32
# 3 2019-02-01   3471.32
# 4 2019-03-01   2260.01
# 5 2019-04-01   9407.86
# 6 2019-05-01  10800.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 922.1818181818181
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05773276000126
#         data  valor
# 0 2019-05-01    0.0
# 05810167000131
#         data     valor
# 0 2018-11-01    123.40
# 1 2018-12-01      0.00
# 2 2019-01-01  10698.80
# 3 2019-02-01  16562.80
# 4 2019-03-01   6483.63
# 5 2019-04-01   8832.12
# 6 2019-05-01  28407.40
# probabilidade_zeros :0.14285714285714285
# SCORE INICIAL : 866.6666666666666
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05816672000193
#         data  valor
# 0 2019-05-01    0.0
# 05828526000188
#         data  valor
# 0 2019-05-01    0.0
# 05891070000109
# ['fc3a71d3-3589-4582-af51-cc342e86a8fc']
#         data    valor
# 0 2018-11-01  21246.4
# 1 2018-12-01  36609.5
# 2 2019-01-01  37633.5
# 3 2019-02-01  25881.3
# 4 2019-03-01  27553.4
# 5 2019-04-01  32092.2
# 6 2019-05-01  35379.2
# probabilidade_zeros :0.0
# SCORE INICIAL : 839.7575757575756
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05936654000145
#         data     valor
# 0 2019-01-01  11924.30
# 1 2019-02-01    879.67
# 2 2019-03-01   2256.72
# 3 2019-04-01   6504.48
# 4 2019-05-01   6092.83
# probabilidade_zeros :0.0
# SCORE INICIAL : 717.5060606060606
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 05969635000115
#         data     valor
# 0 2018-11-01  20340.60
# 1 2018-12-01  21689.00
# 2 2019-01-01  17680.00
# 3 2019-02-01  17183.60
# 4 2019-03-01  19300.60
# 5 2019-04-01   7563.82
# 6 2019-05-01      0.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 286.3333333333333
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 05973715000144
#         data    valor
# 0 2019-02-01  18548.3
# 1 2019-03-01  37380.6
# 2 2019-04-01  34422.9
# 3 2019-05-01  33728.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 918.5333333333334
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 05989474000121
#         data  valor
# 0 2019-05-01    0.0
# 06034464000103
#         data    valor
# 0 2019-04-01  1486.14
# 1 2019-05-01  2478.08
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 06064918000180
#         data    valor
# 0 2018-12-01  3867.77
# 1 2019-01-01  2907.17
# 2 2019-02-01  2664.27
# 3 2019-03-01  3923.14
# 4 2019-04-01  3250.26
# 5 2019-05-01  1548.14
# probabilidade_zeros :0.0
# SCORE INICIAL : 355.2188552188552
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 06070845000130
#         data  valor
# 0 2019-05-01    0.0
# 06096281000104
# ['b404a5e1-c39d-41fd-9bd6-c9d66c4ffedc']
#         data     valor
# 0 2018-11-01  12957.70
# 1 2018-12-01   9730.81
# 2 2019-01-01  15963.80
# 3 2019-02-01  18724.50
# 4 2019-03-01  14586.00
# 5 2019-04-01  41216.90
# 6 2019-05-01  49123.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 928.3333333333334
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 06148813000100
#         data    valor
# 0 2019-05-01  2174.08
# 06167101000138
#         data     valor
# 0 2018-11-01  10949.70
# 1 2018-12-01  10245.70
# 2 2019-01-01  13637.50
# 3 2019-02-01   7713.87
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 231.33333333333334
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 06168168000197
#         data  valor
# 0 2019-05-01    0.0
# 06185549000184
#         data  valor
# 0 2019-05-01    0.0
# 06193689000102
#         data  valor
# 0 2019-05-01    0.0
# 06209983000157
#         data     valor
# 0 2019-02-01   8678.14
# 1 2019-03-01  11609.50
# 2 2019-04-01  14280.80
# 3 2019-05-01   5184.69
# probabilidade_zeros :0.0
# SCORE INICIAL : 315.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 06210600000160
#         data    valor
# 0 2019-05-01  3954.03
# 06213352000101
# ['37219709-d527-48d2-8c49-01970781949f']
#         data    valor
# 0 2018-11-01  31632.9
# 1 2018-12-01  14435.4
# 2 2019-01-01  32660.6
# 3 2019-02-01  14822.0
# 4 2019-03-01  21713.2
# 5 2019-04-01  23934.5
# 6 2019-05-01  18758.6
# probabilidade_zeros :0.0
# SCORE INICIAL : 687.9757575757576
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 06221593000100
#         data   valor
# 0 2019-05-01  587.67
# 06243403000148
#         data  valor
# 0 2019-05-01    0.0
# 06252458000114
#         data    valor
# 0 2019-01-01  5367.79
# 1 2019-02-01  8457.74
# 2 2019-03-01  6306.21
# 3 2019-04-01  3475.37
# 4 2019-05-01   158.06
# probabilidade_zeros :0.0
# SCORE INICIAL : 262.6666666666667
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 06258188000159
#         data     valor
# 0 2018-11-01  16103.00
# 1 2018-12-01  35863.90
# 2 2019-01-01  29322.80
# 3 2019-02-01  27946.80
# 4 2019-03-01   5351.48
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 245.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 06273795000198
# ['1d29c78c-b90d-4c9f-b9dd-fc99ece790ea']
#         data     valor
# 0 2018-12-01   4090.22
# 1 2019-01-01  20909.80
# 2 2019-02-01  12798.20
# 3 2019-03-01  20905.70
# 4 2019-04-01  22882.50
# 5 2019-05-01  35148.50
# probabilidade_zeros :0.0
# SCORE INICIAL : 896.4848484848484
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 06281916000143
#         data  valor
# 0 2019-05-01    0.0
# 06284748000140
#         data     valor
# 0 2019-02-01  36968.60
# 1 2019-03-01  19250.20
# 2 2019-04-01   3941.88
# 3 2019-05-01    554.30
# probabilidade_zeros :0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 06322873000100
#         data  valor
# 0 2019-05-01    0.0
# 06322873000105
#         data     valor
# 0 2019-01-01   69644.3
# 1 2019-02-01   97095.8
# 2 2019-03-01  104950.0
# 3 2019-04-01  112198.0
# 4 2019-05-01  135691.0
# probabilidade_zeros :0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 06539814000185
#         data  valor
# 0 2019-03-01   0.21
# 1 2019-04-01   0.00
# 2 2019-05-01   0.00
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 06745689000160
#         data  valor
# 0 2019-05-01    0.0
# 06983261000155
#         data    valor
# 0 2019-05-01  13425.9
# 07118692000116
#         data  valor
# 0 2019-05-01    0.0
# 07123655000104
#         data  valor
# 0 2018-11-01   0.02
# 1 2018-12-01   0.00
# 2 2019-01-01   0.00
# 3 2019-02-01   0.00
# 4 2019-03-01   0.00
# 5 2019-04-01   0.00
# 6 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07176964000134
# ['8445d3ba-1266-4ea3-951e-183bf4370cfe']
#         data    valor
# 0 2018-11-01  9395.79
# 1 2018-12-01  2537.83
# 2 2019-01-01  3956.72
# 3 2019-02-01  3857.69
# 4 2019-03-01  2410.92
# 5 2019-04-01  4598.17
# 6 2019-05-01  6564.43
# probabilidade_zeros :0.0
# SCORE INICIAL : 761.7757575757578
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 07189896000148
#         data     valor
# 0 2018-11-01   2446.83
# 1 2018-12-01      0.00
# 2 2019-01-01   3885.51
# 3 2019-02-01   6254.54
# 4 2019-03-01   9673.62
# 5 2019-04-01  12683.40
# 6 2019-05-01  46629.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 789.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 07244992000141
#         data     valor
# 0 2019-04-01  75471.20
# 1 2019-05-01   3783.17
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 07255739000193
#         data  valor
# 0 2019-05-01    0.0
# 07268049000179
#         data  valor
# 0 2019-05-01    0.0
# 07269228000120
#         data    valor
# 0 2019-04-01  1807.39
# 1 2019-05-01  4640.90
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 07323509000114
#         data      valor
# 0 2018-12-01    5023.19
# 1 2019-01-01    8558.81
# 2 2019-02-01  116542.00
# 3 2019-03-01   17162.80
# 4 2019-04-01   16734.80
# 5 2019-05-01    8018.06
# probabilidade_zeros :0.0
# SCORE INICIAL : 95.66666666666667
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07383312000170
#         data  valor
# 0 2019-05-01    0.0
# 07383387000151
#         data  valor
# 0 2019-02-01   0.12
# 1 2019-03-01   9.60
# 2 2019-04-01   0.00
# 3 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 58.666666666666664
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 07385526000186
#         data  valor
# 0 2019-05-01    0.0
# 07397449000184
#         data    valor
# 0 2019-03-01   9164.5
# 1 2019-04-01  32674.1
# 2 2019-05-01  35191.1
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 07401069000176
#         data    valor
# 0 2018-12-01  1020.16
# 1 2019-01-01     0.00
# 2 2019-02-01     0.00
# 3 2019-03-01     0.00
# 4 2019-04-01     0.00
# 5 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 07406557000176
# ['6a2db274-7a2b-4370-922f-0731433b5e4d']
#         data    valor
# 0 2018-11-01  16148.0
# 1 2018-12-01  19888.3
# 2 2019-01-01  17926.8
# 3 2019-02-01  20778.0
# 4 2019-03-01  17371.7
# 5 2019-04-01  26245.6
# 6 2019-05-01  38635.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 879.6060606060606
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 07420323000183
#         data    valor
# 0 2018-11-01  27619.9
# 1 2018-12-01  52675.2
# 2 2019-01-01  29537.9
# 3 2019-02-01  36214.3
# 4 2019-03-01  45566.3
# 5 2019-04-01  11613.7
# 6 2019-05-01  12023.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 292.6666666666667
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 07449710000142
# ['217b4f3a-82d0-4b1f-a827-86b5d6bb8620']
#         data     valor
# 0 2018-11-01   4334.67
# 1 2018-12-01  13087.30
# 2 2019-01-01  42768.00
# 3 2019-02-01  28491.30
# 4 2019-03-01  39592.30
# 5 2019-04-01  44588.60
# 6 2019-05-01  52379.40
# probabilidade_zeros :0.14285714285714285
# SCORE INICIAL : 819.0818181818182
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 07457060000187
#         data    valor
# 0 2018-11-01  67873.2
# 1 2018-12-01      0.0
# 2 2019-01-01      0.0
# 3 2019-02-01  25283.3
# 4 2019-03-01      0.0
# 5 2019-04-01  56240.6
# 6 2019-05-01  81739.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 849.3333333333334
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 07513220000168
# ['69b1d2de-3f0c-4f4a-87b9-7bfb3f6fc7b8']
#         data     valor
# 0 2018-11-01    186.80
# 1 2018-12-01   2994.89
# 2 2019-01-01   3344.30
# 3 2019-02-01   8937.61
# 4 2019-03-01   8614.95
# 5 2019-04-01  13706.10
# 6 2019-05-01  24992.60
# probabilidade_zeros :0.14285714285714285
# SCORE INICIAL : 875.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 07526716000176
#         data    valor
# 0 2018-11-01  1587.14
# 1 2018-12-01     0.00
# 2 2019-01-01     0.00
# 3 2019-02-01     0.00
# 4 2019-03-01     0.00
# 5 2019-04-01     0.00
# 6 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07530669000134
#         data     valor
# 0 2019-03-01   2002.00
# 1 2019-04-01   4088.03
# 2 2019-05-01  12388.40
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 07531319000192
#         data  valor
# 0 2019-05-01    0.0
# 07556425000201
#         data  valor
# 0 2019-05-01    0.0
# 07571546000141
#         data  valor
# 0 2019-03-01   9.97
# 1 2019-04-01   0.00
# 2 2019-05-01   0.00
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 07580539000106
#         data  valor
# 0 2019-04-01   8.38
# 1 2019-05-01   0.00
# 07605505000129
#         data  valor
# 0 2019-05-01    0.0
# 07633539000122
#         data  valor
# 0 2019-05-01    0.0
# 07633539000127
#         data    valor
# 0 2018-11-01  3940.11
# 1 2018-12-01  2077.05
# 2 2019-01-01  4181.47
# 3 2019-02-01  2528.03
# 4 2019-03-01  2665.22
# 5 2019-04-01  3970.46
# 6 2019-05-01  3632.56
# probabilidade_zeros :0.0
# SCORE INICIAL : 731.5757575757575
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 07637701000185
#         data  valor
# 0 2019-05-01    0.0
# 07662833000167
#         data    valor
# 0 2019-05-01  9576.17
# 07687085000177
#         data  valor
# 0 2019-05-01    0.0
# 07722609000113
#         data  valor
# 0 2019-05-01    0.0
# 07757060000100
#         data  valor
# 0 2019-02-01  900.0
# 1 2019-03-01    0.0
# 2 2019-04-01    0.0
# 3 2019-05-01    0.0
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 07770077000190
#         data  valor
# 0 2019-05-01    0.0
# 07794585000108
#         data     valor
# 0 2018-11-01  18364.60
# 1 2018-12-01   3761.65
# 2 2019-01-01   1089.52
# 3 2019-02-01   2721.15
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 72.66666666666667
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07816261000123
#         data  valor
# 0 2019-05-01    0.0
# 07816261000204
#         data  valor
# 0 2019-05-01    0.0
# 07816261000395
#         data  valor
# 0 2019-05-01    0.0
# 07816261000476
#         data  valor
# 0 2019-05-01    0.0
# 07816261000500
#         data  valor
# 0 2019-05-01    0.0
# 07816261000557
#         data  valor
# 0 2019-05-01    0.0
# 07816261000638
#         data  valor
# 0 2019-05-01    0.0
# 07826726000127
#         data    valor
# 0 2018-11-01  1128.00
# 1 2018-12-01  3077.97
# 2 2019-01-01  2993.52
# 3 2019-02-01  2321.44
# 4 2019-03-01     0.00
# 5 2019-04-01   546.45
# 6 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 239.66666666666666
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 07829973000187
#         data  valor
# 0 2019-05-01    0.0
# 07851187000186
#         data     valor
# ...
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 32337186000165
#         data  valor
# 0 2019-05-01    0.0
# 32401589000126
#         data    valor
# 0 2019-03-01   284.22
# 1 2019-04-01  1080.21
# 2 2019-05-01  1125.98
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 32410416000174
#         data  valor
# 0 2019-01-01   0.23
# 1 2019-02-01   0.06
# 2 2019-03-01   0.00
# 3 2019-04-01   0.00
# 4 2019-05-01   0.00
# probabilidade_zeros :0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 32423129000107
#         data  valor
# 0 2019-05-01    0.0
# 32429272000106
#         data  valor
# 0 2019-05-01    0.0
# 32459720000106
#         data    valor
# 0 2019-05-01  9204.13
# 32525858000166
#         data  valor
# 0 2019-05-01    0.0
# 32540691000102
#         data  valor
# 0 2019-05-01    0.0
# 32584158000142
#         data   valor
# 0 2019-02-01  101.16
# 1 2019-03-01   66.71
# 2 2019-04-01    0.00
# 3 2019-05-01    0.00
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 32622958000100
#         data  valor
# 0 2019-05-01    0.0
# 32691096000178
#         data    valor
# 0 2019-03-01   348.64
# 1 2019-04-01  7571.97
# 2 2019-05-01  7450.94
# probabilidade_zeros :0.0
# SCORE INICIAL : 900.3333333333334
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 32707858000187
#         data     valor
# 0 2019-04-01   1691.77
# 1 2019-05-01  22488.70
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 32709402000156
#         data    valor
# 0 2019-02-01   252.16
# 1 2019-03-01  1717.14
# 2 2019-04-01  4517.54
# 3 2019-05-01  3570.37
# probabilidade_zeros :0.0
# SCORE INICIAL : 910.3333333333334
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 32767924000104
#         data    valor
# 0 2019-04-01  8557.59
# 1 2019-05-01  1280.17
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 32819283000194
#         data   valor
# 0 2019-05-01  777.18
# 32853772000162
#         data  valor
# 0 2019-03-01   0.01
# 1 2019-04-01   0.00
# 2 2019-05-01   0.00
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 32901292000120
#         data     valor
# 0 2019-03-01   1233.67
# 1 2019-04-01  38308.20
# 2 2019-05-01  24677.20
# probabilidade_zeros :0.0
# SCORE INICIAL : 713.9757575757576
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 32931899000152
#         data  valor
# 0 2019-05-01   0.01
# 32988505000100
#         data     valor
# 0 2019-04-01  10882.90
# 1 2019-05-01    172.24
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 32989077000122
#         data    valor
# 0 2019-04-01  24842.9
# 1 2019-05-01      0.0
# 33015632000188
#         data   valor
# 0 2019-05-01  911.57
# 33114066000161
#         data    valor
# 0 2019-05-01  3013.25
# 33115853000128
#         data  valor
# 0 2019-05-01    0.0
# 33133309000109
#         data    valor
# 0 2019-04-01  67166.7
# 1 2019-05-01  82710.5
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 33137206000117
#         data  valor
# 0 2019-05-01    0.0
# 33224248000195
#         data    valor
# 0 2019-04-01   6076.6
# 1 2019-05-01  19481.2
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 33469219000193
#         data      valor
# 0 2019-04-01       0.01
# 1 2019-05-01  173083.00
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 33704720000197
#         data    valor
# 0 2019-05-01  3330.95
# 35474584000111
#         data  valor
# 0 2019-05-01    0.0
# 35474584000200
#         data  valor
# 0 2019-05-01    0.0
# 35474584000383
#         data  valor
# 0 2019-05-01    0.0
# 35474584000464
#         data  valor
# 0 2019-05-01    0.0
# 35474584000545
#         data  valor
# 0 2019-05-01    0.0
# 35474584000626
#         data  valor
# 0 2019-05-01    0.0
# 37372182000131
#         data  valor
# 0 2019-05-01    0.0
# 37833670000107
#         data  valor
# 0 2019-05-01    0.0
# 40770901000187
#         data  valor
# 0 2019-05-01    0.0
# 42013748000179
#         data    valor
# 0 2019-01-01   231.69
# 1 2019-02-01  5334.36
# 2 2019-03-01  9336.54
# 3 2019-04-01  9196.77
# 4 2019-05-01  9514.90
# probabilidade_zeros :0.0
# SCORE INICIAL : 809.4121212121214
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 43732908000100
#         data  valor
# 0 2019-05-01    0.0
# 44471928000120
#         data    valor
# 0 2019-03-01  1716.40
# 1 2019-04-01  4409.42
# 2 2019-05-01  3700.76
# probabilidade_zeros :0.0
# SCORE INICIAL : 975.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 45028404000121
#         data     valor
# 0 2018-11-01  17012.70
# 1 2018-12-01  47070.10
# 2 2019-01-01   8039.23
# 3 2019-02-01  10852.00
# 4 2019-03-01  10267.80
# 5 2019-04-01   1048.89
# 6 2019-05-01    287.79
# probabilidade_zeros :0.0
# SCORE INICIAL : 161.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 45028404000393
# ['1709d605-a9bc-442a-8805-1b022df84aee']
#         data     valor
# 0 2018-11-01    736.79
# 1 2018-12-01  20617.60
# 2 2019-01-01   7532.48
# 3 2019-02-01   4326.10
# 4 2019-03-01   6369.31
# 5 2019-04-01   8911.75
# 6 2019-05-01   7344.59
# probabilidade_zeros :0.14285714285714285
# SCORE INICIAL : 612.4181818181819
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 46140224000108
#         data     valor
# 0 2019-02-01   7486.91
# 1 2019-03-01  11706.60
# 2 2019-04-01   1189.82
# 3 2019-05-01    566.82
# probabilidade_zeros :0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 47641451000171
#         data     valor
# 0 2018-12-01  30087.80
# 1 2019-01-01  10811.30
# 2 2019-02-01   8907.43
# 3 2019-03-01  13762.80
# 4 2019-04-01  20261.90
# 5 2019-05-01  26191.90
# probabilidade_zeros :0.0
# SCORE INICIAL : 809.1151515151515
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 49862246000161
#         data    valor
# 0 2019-02-01   207.96
# 1 2019-03-01  4199.58
# 2 2019-04-01  7485.65
# 3 2019-05-01   622.43
# probabilidade_zeros :0.0
# SCORE INICIAL : 178.33333333333334
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 50201391000180
#         data     valor
# 0 2018-12-01  108293.0
# 1 2019-01-01   90360.2
# 2 2019-02-01   79042.2
# 3 2019-03-01  111027.0
# 4 2019-04-01   74999.8
# 5 2019-05-01   60057.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 647.5672138047138
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 51524486000106
# ['c633548a-f59b-4841-83d8-d86a0c0ce6b3']
#         data     valor
# 0 2018-11-01   8869.57
# 1 2018-12-01  40107.10
# 2 2019-01-01  44916.00
# 3 2019-02-01  43291.70
# 4 2019-03-01  45989.70
# 5 2019-04-01  56596.30
# 6 2019-05-01  56239.80
# probabilidade_zeros :0.0
# SCORE INICIAL : 775.5878787878788
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 52708898000150
#         data   valor
# 0 2019-03-01  934.94
# 1 2019-04-01    0.00
# 2 2019-05-01    0.00
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 53549887000138
#         data    valor
# 0 2019-03-01  1390.44
# 1 2019-04-01  2766.64
# 2 2019-05-01  4170.61
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 54702774000193
#         data     valor
# 0 2018-11-01  10139.90
# 1 2018-12-01  10315.50
# 2 2019-01-01      0.00
# 3 2019-02-01   1163.52
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 55023154000190
#         data    valor
# 0 2019-05-01  30333.6
# 56335649000118
#         data    valor
# 0 2019-02-01  17561.5
# 1 2019-03-01  25394.6
# 2 2019-04-01  27009.0
# 3 2019-05-01  25493.1
# probabilidade_zeros :0.0
# SCORE INICIAL : 828.3212121212123
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 56554629000138
#         data     valor
# 0 2018-11-01  15534.60
# 1 2018-12-01  10005.50
# 2 2019-01-01   8718.68
# 3 2019-02-01   6672.94
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 57119018000477
#         data  valor
# 0 2019-05-01    0.0
# 59723601000175
#         data  valor
# 0 2018-11-01   0.99
# 1 2018-12-01   0.00
# 2 2019-01-01   0.00
# 3 2019-02-01   0.00
# 4 2019-03-01   0.00
# 5 2019-04-01   0.00
# 6 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 61539920000177
#         data     valor
# 0 2018-11-01   8479.49
# 1 2018-12-01  21814.80
# 2 2019-01-01   8914.75
# 3 2019-02-01      0.00
# 4 2019-03-01  22242.40
# 5 2019-04-01   5955.94
# 6 2019-05-01  15578.10
# probabilidade_zeros :0.0
# SCORE INICIAL : 708.218181818182
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 63222921000119
#         data    valor
# 0 2019-03-01   6788.6
# 1 2019-04-01  16139.2
# 2 2019-05-01  18905.5
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 64309636000100
#         data    valor
# 0 2018-12-01  3705.31
# 1 2019-01-01     0.00
# 2 2019-02-01     0.00
# 3 2019-03-01     0.00
# 4 2019-04-01     0.00
# 5 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 64453475000205
#         data  valor
# 0 2019-05-01   0.02
# 64605611000146
# ['fdd61167-506b-4e7d-b83e-e0752c00ca27']
#         data    valor
# 0 2018-11-01  19674.9
# 1 2018-12-01  62945.8
# 2 2019-01-01  16822.6
# 3 2019-02-01  15434.0
# 4 2019-03-01  18320.9
# 5 2019-04-01  20416.6
# 6 2019-05-01  19369.8
# probabilidade_zeros :0.0
# SCORE INICIAL : 611.2484848484847
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 64756257000150
#         data  valor
# 0 2019-02-01   0.03
# 1 2019-03-01  28.93
# 2 2019-04-01   0.00
# 3 2019-05-01   0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 53.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 65338964000190
#         data  valor
# 0 2019-05-01    0.0
# 67845511000185
#         data  valor
# 0 2019-05-01    0.0
# 70181615000147
#         data  valor
# 0 2019-05-01    0.0
# 70359633000176
# ['bd396678-c91e-4d47-a2ce-7f324cf8fc85']
#         data    valor
# 0 2018-11-01  13636.2
# 1 2018-12-01  15313.3
# 2 2019-01-01  21352.1
# 3 2019-02-01  77142.6
# 4 2019-03-01  20056.0
# 5 2019-04-01  65356.4
# 6 2019-05-01  16830.7
# probabilidade_zeros :0.0
# SCORE INICIAL : 391.2491582491582
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 71102289000106
# ['3cb79d26-6f91-4509-aa31-622d808692e2']
#         data    valor
# 0 2018-11-01  18265.2
# 1 2018-12-01  15026.5
# 2 2019-01-01  27686.0
# 3 2019-02-01  17062.1
# 4 2019-03-01  14142.0
# 5 2019-04-01  20620.8
# 6 2019-05-01  16906.7
# probabilidade_zeros :0.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 71105027000197
#         data    valor
# 0 2018-11-01  20224.2
# 1 2018-12-01  16424.5
# 2 2019-01-01  11874.3
# 3 2019-02-01      0.0
# 4 2019-03-01      0.0
# 5 2019-04-01      0.0
# 6 2019-05-01      0.0
# probabilidade_zeros :0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 71499453000152
# ['613873c5-1948-4361-9c64-c0cdd2bc8bbd']
#         data     valor
# 0 2018-12-01   5393.34
# 1 2019-01-01  26404.50
# 2 2019-02-01  12266.40
# 3 2019-03-01  15770.40
# 4 2019-04-01  19191.30
# 5 2019-05-01  35162.70
# probabilidade_zeros :0.0
# SCORE INICIAL : 904.9272727272728
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 71673487000111
#         data    valor
# 0 2019-01-01  4799.72
# 1 2019-02-01     0.00
# 2 2019-03-01     0.00
# 3 2019-04-01     0.00
# 4 2019-05-01     0.00
# probabilidade_zeros :0.0
# HISTORICO : 4
# CORRECAO HISTORICO : 1
# 72653967000183
#         data    valor
# 0 2019-03-01  2797.23
# 1 2019-04-01   199.96
# 2 2019-05-01    44.26
# probabilidade_zeros :0.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 72796170000216
#         data    valor
# 0 2018-11-01     0.10
# 1 2018-12-01  1657.04
# 2 2019-01-01     0.00
# 3 2019-02-01   721.79
# 4 2019-03-01     0.00
# 5 2019-04-01     0.00
# 6 2019-05-01     0.00
# probabilidade_zeros :0.16666666666666666
# SCORE INICIAL : 54.666666666666664
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 73116386000175
#         data     valor
# 0 2019-02-01   31760.2
# 1 2019-03-01  118798.0
# 2 2019-04-01   13884.1
# 3 2019-05-01       0.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 191.33333333333334
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 73505216000182
#         data    valor
# 0 2018-11-01  12448.0
# 1 2018-12-01      0.0
# 2 2019-01-01      0.0
# 3 2019-02-01      0.0
# 4 2019-03-01      0.0
# 5 2019-04-01      0.0
# 6 2019-05-01      0.0
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 73505216000425
# ['cff5f2bc-7b04-4867-b4bf-aa8a1b1d41ce']
#         data     valor
# 0 2018-11-01  20939.90
# 1 2018-12-01  15946.80
# 2 2019-01-01  20853.10
# 3 2019-02-01  20839.40
# 4 2019-03-01  13222.80
# 5 2019-04-01   9400.01
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 427.60942760942754
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 73665598000101
#         data  valor
# 0 2019-05-01    0.0
# 74264953000101
#         data   valor
# 0 2019-03-01    0.01
# 1 2019-04-01    0.00
# 2 2019-05-01  498.65
# probabilidade_zeros :0.0
# SCORE INICIAL : 719.0
# HISTORICO : 3
# CORRECAO HISTORICO : 1
# 77369973000127
#         data  valor
# 0 2019-05-01   0.01
# 79651766000196
#         data  valor
# 0 2019-05-01    0.0
# 79651766000277
#         data  valor
# 0 2019-05-01    0.0
# 79985479000112
#         data  valor
# 0 2019-05-01    0.0
# 80694730000179
# ['c310cc78-8f98-4cf7-961a-6b7ab4f5a382']
#         data     valor
# 0 2018-11-01  11329.60
# 1 2018-12-01   6353.57
# 2 2019-01-01   7329.34
# 3 2019-02-01  11209.40
# 4 2019-03-01  20173.40
# 5 2019-04-01  19050.10
# 6 2019-05-01  11908.40
# probabilidade_zeros :0.0
# SCORE INICIAL : 685.460606060606
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 81156846000117
#         data    valor
# 0 2019-05-01  14585.8
# 81817017000138
#         data  valor
# 0 2019-05-01    0.0
# 81849143000174
#         data  valor
# 0 2019-05-01    0.0
# 82088121000100
#         data     valor
# 0 2019-04-01   5851.92
# 1 2019-05-01  15142.80
# probabilidade_zeros :0.0
# HISTORICO : 2
# CORRECAO HISTORICO : 1
# 83103804000143
#         data    valor
# 0 2019-05-01  3803.73
# 83325498000190
#         data  valor
# 0 2019-05-01    0.0
# 86505419000110
#         data  valor
# 0 2019-05-01    0.0
# 87188546000100
#         data  valor
# 0 2019-05-01    0.0
# 87188546000104
#         data   valor
# 0 2018-11-01    0.59
# 1 2018-12-01  135.13
# 2 2019-01-01    0.00
# 3 2019-02-01    0.06
# 4 2019-03-01    0.00
# 5 2019-04-01    0.00
# 6 2019-05-01    0.00
# probabilidade_zeros :0.16666666666666666
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 87189106000163
#         data   valor
# 0 2018-11-01  516.00
# 1 2018-12-01    0.00
# 2 2019-01-01    0.00
# 3 2019-02-01  167.58
# 4 2019-03-01    0.00
# 5 2019-04-01    0.00
# 6 2019-05-01    0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 34.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 87247102000194
#         data  valor
# 0 2019-05-01    0.0
# 90147216000177
#         data     valor
# 0 2018-11-01   6989.19
# 1 2018-12-01  12257.50
# 2 2019-01-01   8879.28
# 3 2019-02-01      0.00
# 4 2019-03-01      0.00
# 5 2019-04-01      0.00
# 6 2019-05-01      0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 165.66666666666666
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 90917261000163
#         data  valor
# 0 2019-05-01    0.0
# 91157743000125
#         data  valor
# 0 2019-05-01    0.0
# 91320028000161
#         data    valor
# 0 2018-11-01  3107.67
# 1 2018-12-01   385.59
# 2 2019-01-01     0.00
# 3 2019-02-01     0.00
# 4 2019-03-01     0.00
# 5 2019-04-01     0.00
# 6 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 6
# CORRECAO HISTORICO : 0.7
# 92195528000181
#         data    valor
# 0 2018-11-01  5284.68
# 1 2018-12-01     0.00
# 2 2019-01-01     0.00
# 3 2019-02-01   457.34
# 4 2019-03-01  3890.78
# 5 2019-04-01  3683.21
# 6 2019-05-01  1386.55
# probabilidade_zeros :0.0
# SCORE INICIAL : 527.7636363636365
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 93354744000195
#         data  valor
# 0 2019-05-01    0.0
# 93379337000132
#         data     valor
# 0 2018-11-01  12546.00
# 1 2018-12-01  10152.90
# 2 2019-01-01   9000.19
# 3 2019-02-01   4822.83
# 4 2019-03-01   8948.77
# 5 2019-04-01   5216.30
# 6 2019-05-01   8460.23
# probabilidade_zeros :0.0
# SCORE INICIAL : 712.8515151515152
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8
# 93886505000186
# ['2d4f11a3-c58e-4994-82fb-29ea1093a4be']
#         data  valor
# 0 2019-05-01    0.0
# 94029584000171
#         data  valor
# 0 2019-05-01    0.0
# 94044468000121
#         data  valor
# 0 2019-05-01    0.0
# 94240314000105
#         data  valor
# 0 2019-05-01    0.0
# 94261385000194
#         data  valor
# 0 2019-05-01    0.0
# 94528890000152
#         data  valor
# 0 2019-05-01    0.0
# 94580412000191
#         data    valor
# 0 2018-12-01  1542.16
# 1 2019-01-01     0.00
# 2 2019-02-01     0.00
# 3 2019-03-01     0.00
# 4 2019-04-01     0.00
# 5 2019-05-01     0.00
# probabilidade_zeros :0.0
# SCORE INICIAL : 0.0
# HISTORICO : 5
# CORRECAO HISTORICO : 1
# 95159166000161
#         data  valor
# 0 2019-05-01    0.0
# 96435722000148
#         data  valor
# 0 2019-05-01    0.0
# 97307102000196
#         data  valor
# 0 2019-05-01    0.0
# 97542416000173
# ['efd95696-c1bf-424b-8ae1-ba2784af7e32']
#         data    valor
# 0 2018-11-01  20818.4
# 1 2018-12-01  36132.9
# 2 2019-01-01  25006.4
# 3 2019-02-01  15247.2
# 4 2019-03-01  15742.2
# 5 2019-04-01  29339.8
# 6 2019-05-01  27971.5
# probabilidade_zeros :0.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8

# %%
resp = pd.concat(resp)

# %%
resp["data_consulta"] = resp.apply(lambda x : x["data_consulta"].date() if not x["data_consulta"] is None else x["data_consulta"], axis=1)

# %%
resp["flag_consulta"] = resp.apply(lambda x : int(x["data_consulta"] is None), axis=1)

# %%
df_consulta = resp[(resp["flag_consulta"]==1) & (resp["flag_faturamento"]==1)]

# %%
df_consulta.shape
# Out:
# (111, 7)

# %%
df_consulta.to_excel("atualizar_dividas_justa_201905.xlsx")

# %%
resp[resp["flag_faturamento"]==1]["cnpj"].unique().tolist().__len__()
# Out:
# 304

# %%
pre = resp[resp["flag_consulta"]==0]

# %%
pre["flag_aprovacao"] = pre["flag_faturamento"]*pre["flag_cheques"]*pre["flag_dividas"]
# Out:
# /home/lidi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pre[pre["flag_aprovacao"]==1].to_excel("consultar_trava_justa_201905.xlsx")

# %%
err.__len__()
# Out:
# 0

# %%
df[df['cnpj']=='00121514000103']
# Out:
#                 cnpj  numero_transacoes  valor        data  flag_cnpj  \
# 1801  00121514000103                  0    0.0  2019-05-01          1
#
#      data_posicao flag_aprovacao
# 1801   2019-06-11           None

# %%
pa = PreAnalysis(cnpj=el, produto='justa')
pa.analisa()
# Out:
# ['efd95696-c1bf-424b-8ae1-ba2784af7e32']
#         data    valor
# 0 2018-11-01  20818.4
# 1 2018-12-01  36132.9
# 2 2019-01-01  25006.4
# 3 2019-02-01  15247.2
# 4 2019-03-01  15742.2
# 5 2019-04-01  29339.8
# 6 2019-05-01  27971.5
# probabilidade_zeros :0.0
# HISTORICO : 7
# CORRECAO HISTORICO : 0.8

# %%
pa.flag_cheques
# Out:
# 1

# %%
pa.flag_dividas
# Out:
# 1

# %%
pa.flag_faturamento
# Out:
# 1

# %%
pa.flag_transacoes
